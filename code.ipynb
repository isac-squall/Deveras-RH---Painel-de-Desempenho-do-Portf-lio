# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Path to the file
file_path = '/data/chats/igk4wd/workspace/uploads/Teste Power BI - Deveras RH.xlsx'

# List all sheets in the Excel file
excel_file = pd.ExcelFile(file_path)
sheet_names = excel_file.sheet_names
print("Excel sheets:", sheet_names)

# Create a dictionary to store dataframes from each sheet
dfs = {}

# Read each sheet and store in the dictionary
for sheet in sheet_names:
    dfs[sheet] = pd.read_excel(file_path, sheet_name=sheet)
    print(f"\n--- Sheet: {sheet} ---")
    print(f"Shape: {dfs[sheet].shape}")
    print("Column names:", list(dfs[sheet].columns))
    print("Data types:\n", dfs[sheet].dtypes)
    
    # Display first few rows
    print("First 3 rows:\n", dfs[sheet].head(3))
    
    # Check for missing values
    missing_values = dfs[sheet].isnull().sum()
    if missing_values.sum() > 0:
        print("Missing values:\n", missing_values[missing_values > 0])
    else:
        print("No missing values found.")
    
    # Check for duplicates
    duplicates = dfs[sheet].duplicated().sum()
    print(f"Number of duplicate rows: {duplicates}")
# Out:
# Excel sheets: ['BASE DE DADOS', 'Orientações', 'Alphaville', 'BH', 'SJC', 'PAULINIA', 'CAMPINAS']
#
# --- Sheet: BASE DE DADOS ---
# Shape: (16, 2)
# Column names: ['CÓDIGO DO CLIENTE:', 'Unnamed: 1']
# Data types:
#  CÓDIGO DO CLIENTE:     object
# Unnamed: 1            float64
# dtype: object
# First 3 rows:
#            CÓDIGO DO CLIENTE:  Unnamed: 1
# 0  NOME COMPLETO DO CLIENTE:         NaN
# 1                       CPF:         NaN
# 2                  ENDEREÇO:         NaN
# Missing values:
#  Unnamed: 1    12
# dtype: int64
# Number of duplicate rows: 0
#
# --- Sheet: Orientações ---
# Shape: (17, 2)
# Column names: ['Unnamed: 0', 'Unnamed: 1']
# Data types:
#  Unnamed: 0    object
# Unnamed: 1    object
# dtype: object
# First 3 rows:
#    Unnamed: 0 Unnamed: 1
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# Missing values:
#  Unnamed: 0     9
# Unnamed: 1    11
# dtype: int64
# Number of duplicate rows: 8
#
# --- Sheet: Alphaville ---
# Shape: (1651, 45)
# Column names: ['Nº CONTRATO (SISTEMA GERA)', 'STATUS', 'CÓD CLIENTE', 'PACIENTYES', 'UNIDADE', 'OPERADORA', ' NF', 'DATA EMISSÃO NF', 'COMPETÊNCIA', 'QUINZENA', 'VALOR', 'Nº SESSÕES', 'STATUS PRÉVIO DA CONTA', 'SOLICITANTE', 'STATUS ANÁLISE DE CRÉDITO', 'STATUS JURÍDICO CLIENTE', '1ª APROVAÇÃO CLÍNICA GARANTIDORA', '2ª APROVAÇÃO FACTORING', 'CONTRATO ASSINADO', 'DATA DO CONTRATO', 'FINANCIADO', 'VALOR FINANCIADO', 'DATA FINANCIAMENTO', 'PAGAMENTO CLINICA', 'VALOR PAGAMENTO CLÍNICA', 'DATA PAGAMENTO CLÍNICA', 'TRANSMISSÃO DA CONTA', 'DATA PROTOCOLO ', 'DATA DE VENCIMENTO', 'STATUS CONTAS A RECEBER', 'VALOR PAGO', 'DATA DO PAGAMENTO REEMBOLSO', 'VALOR GLOSADO', 'DATA DO PAGAMENTO FACTORING', 'VALOR PAGAMENTO FACTORING', 'CONTAS A RECEBER', 'STATUS FINAL DA CONTA', 'LIGAÇÃO ', 'DATA DA LIGAÇÃO', 'RECLAMAÇÃO CHAT', 'DATA DA RECLAMAÇÃO', 'NIP', 'DATA DA NIP', 'ETAPAS DA JUDICILIAZAÇÃO', 'OBSERVAÇÕES']
# Data types:
#  Nº CONTRATO (SISTEMA GERA)                   int64
# STATUS                                      object
# CÓD CLIENTE                                  int64
# PACIENTYES                                  object
# UNIDADE                                     object
# OPERADORA                                   object
#  NF                                        float64
# DATA EMISSÃO NF                     datetime64[ns]
# COMPETÊNCIA                         datetime64[ns]
# QUINZENA                                   float64
# VALOR                                       object
# Nº SESSÕES                                   int64
# STATUS PRÉVIO DA CONTA                      object
# SOLICITANTE                                 object
# STATUS ANÁLISE DE CRÉDITO                   object
# STATUS JURÍDICO CLIENTE                     object
# 1ª APROVAÇÃO CLÍNICA GARANTIDORA            object
# 2ª APROVAÇÃO FACTORING                      object
# CONTRATO ASSINADO                           object
# DATA DO CONTRATO                            object
# FINANCIADO                                  object
# VALOR FINANCIADO                           float64
# DATA FINANCIAMENTO                          object
# PAGAMENTO CLINICA                           object
# VALOR PAGAMENTO CLÍNICA                     object
# DATA PAGAMENTO CLÍNICA              datetime64[ns]
# TRANSMISSÃO DA CONTA                        object
# DATA PROTOCOLO                      datetime64[ns]
# DATA DE VENCIMENTO                  datetime64[ns]
# STATUS CONTAS A RECEBER                     object
# VALOR PAGO                                  object
# DATA DO PAGAMENTO REEMBOLSO                 object
# VALOR GLOSADO                               object
# DATA DO PAGAMENTO FACTORING         datetime64[ns]
# VALOR PAGAMENTO FACTORING                  float64
# CONTAS A RECEBER                            object
# STATUS FINAL DA CONTA                       object
# LIGAÇÃO                                     object
# DATA DA LIGAÇÃO                     datetime64[ns]
# RECLAMAÇÃO CHAT                             object
# DATA DA RECLAMAÇÃO                  datetime64[ns]
# NIP                                         object
# DATA DA NIP                         datetime64[ns]
# ETAPAS DA JUDICILIAZAÇÃO                    object
# OBSERVAÇÕES                                 object
# dtype: object
# First 3 rows:
#     Nº CONTRATO (SISTEMA GERA)                   STATUS  CÓD CLIENTE  \
# 0                           1                    ATIVO           10
# 1                           2  INATIVO - TRANSPLANTADO           20
# 2                           3     INATIVO - TRANSFERID           30
#
#     PACIENTYES     UNIDADE OPERADORA      NF DATA EMISSÃO NF COMPETÊNCIA  \
# 0  PEDRO SILVA  ALPHAVILLE  BRADESCO  3270.0      2023-01-30  2023-03-01
# 1  PEDRO SILVA      alpha   BRADESCO  3271.0      2023-03-02  2023-04-01
# 2  PEDRO SILVA  ALPHAVILLE  BRADESCO  3302.0      2023-03-02  2023-04-01
#
#    QUINZENA  ... CONTAS A RECEBER  STATUS FINAL DA CONTA LIGAÇÃO   \
# 0       2.0  ...                0                REGULAR      SIM
# 1       1.0  ...                0         GLOSA INDEVIDA      NÃO
# 2       2.0  ...                0             EMPACOTADO      sim
#
#   DATA DA LIGAÇÃO RECLAMAÇÃO CHAT DATA DA RECLAMAÇÃO  NIP DATA DA NIP  \
# 0      2023-08-25             sim         2023-09-24  SIM  2023-10-20
# 1      2023-10-15             NÃO         2023-11-14  NÃO  2023-12-10
# 2      2023-08-25             sim         2023-09-24  sim  2023-10-20
#
#   ETAPAS DA JUDICILIAZAÇÃO                                        OBSERVAÇÕES
# 0              DOC ENVIADA  Liberado pagamento por OP pela operadora em 15...
# 1              PROTOCOLADO  Conta apresentada em 20/06/2024. Foi solicitad...
# 2        LIMINAR CONCEDIDA  Liberado pagamento por OP pela operadora em 20...
#
# [3 rows x 45 columns]
# Missing values:
#   NF                               5
# COMPETÊNCIA                       4
# QUINZENA                          4
# DATA DO CONTRATO                131
# DATA FINANCIAMENTO              131
# VALOR PAGAMENTO CLÍNICA        1642
# DATA PAGAMENTO CLÍNICA          140
# DATA PROTOCOLO                  135
# DATA DE VENCIMENTO               72
# STATUS CONTAS A RECEBER        1642
# VALOR PAGO                      385
# DATA DO PAGAMENTO REEMBOLSO     386
# VALOR GLOSADO                    36
# DATA DO PAGAMENTO FACTORING    1642
# VALOR PAGAMENTO FACTORING      1642
# CONTAS A RECEBER                 66
# OBSERVAÇÕES                    1648
# dtype: int64
# Number of duplicate rows: 0
#
# --- Sheet: BH ---
# Shape: (814, 45)
# Column names: ['STATUS', 'Nº CONTRATO (SISTEMA GERA)2', 'PACIENTE 2', 'CÓD CLIENTE', 'UNIDADE', 'OPERADORA', ' NF', 'DATA EMISSÃO NF', 'COMPETÊNCIA', 'QUINZENA', 'VALOR', 'Nº SESSÕES', 'STATUS PRÉVIO DA CONTA', 'SOLICITANTE', 'STATUS ANÁLISE DE CRÉDITO', 'STATUS JURÍDICO CLIENTE', '1ª APROVAÇÃO CLÍNICA GARANTIDORA', '2ª APROVAÇÃO FACTORING', 'CONTRATO ASSINADO', 'DATA DO CONTRATO', 'FINANCIADO', 'VALOR FINANCIADO', 'DATA FINANCIAMENTO', 'PAGAMENTO CLINICA', 'VALOR PAGAMENTO CLÍNICA', 'DATA PAGAMENTO CLÍNICA', 'TRANSMISSÃO DA CONTA', 'DATA PROTOCOLO ', 'DATA DE VENCIMENTO', 'STATUS CONTAS A RECEBER', 'VALOR PAGO', 'DATA DO PAGAMENTO REEMBOLSO', 'VALOR GLOSADO', 'DATA DO PAGAMENTO FACTORING', 'VALOR PAGAMENTO FACTORING', 'CONTAS A RECEBER', 'STATUS FINAL DA CONTA', 'LIGAÇÃO ', 'DATA DA LIGAÇÃO', 'RECLAMAÇÃO CHAT', 'DATA DA RECLAMAÇÃO', 'NIP', 'DATA DA NIP', 'ETAPAS DA JUDICILIAZAÇÃO', 'OBSERVAÇÕES']
# Data types:
#  STATUS                               object
# Nº CONTRATO (SISTEMA GERA)2           int64
# PACIENTE 2                           object
# CÓD CLIENTE                           int64
# UNIDADE                              object
# OPERADORA                            object
#  NF                                  object
# DATA EMISSÃO NF                       int64
# COMPETÊNCIA                         float64
# QUINZENA                            float64
# VALOR                                object
# Nº SESSÕES                            int64
# STATUS PRÉVIO DA CONTA               object
# SOLICITANTE                          object
# STATUS ANÁLISE DE CRÉDITO            object
# STATUS JURÍDICO CLIENTE              object
# 1ª APROVAÇÃO CLÍNICA GARANTIDORA     object
# 2ª APROVAÇÃO FACTORING               object
# CONTRATO ASSINADO                    object
# DATA DO CONTRATO                     object
# FINANCIADO                           object
# VALOR FINANCIADO                     object
# DATA FINANCIAMENTO                    int64
# PAGAMENTO CLINICA                    object
# VALOR PAGAMENTO CLÍNICA              object
# DATA PAGAMENTO CLÍNICA               object
# TRANSMISSÃO DA CONTA                 object
# DATA PROTOCOLO                      float64
# DATA DE VENCIMENTO                  float64
# STATUS CONTAS A RECEBER              object
# VALOR PAGO                           object
# DATA DO PAGAMENTO REEMBOLSO          object
# VALOR GLOSADO                        object
# DATA DO PAGAMENTO FACTORING          object
# VALOR PAGAMENTO FACTORING            object
# CONTAS A RECEBER                    float64
# STATUS FINAL DA CONTA                object
# LIGAÇÃO                              object
# DATA DA LIGAÇÃO                       int64
# RECLAMAÇÃO CHAT                      object
# DATA DA RECLAMAÇÃO                    int64
# NIP                                  object
# DATA DA NIP                           int64
# ETAPAS DA JUDICILIAZAÇÃO             object
# OBSERVAÇÕES                          object
# dtype: object
# First 3 rows:
#                      STATUS  Nº CONTRATO (SISTEMA GERA)2            PACIENTE 2  \
# 0                    ATIVO                           25  JOÃO GUIMARAES-único
# 1  INATIVO - TRANSPLANTADO                           67  JOÃO GUIMARAES-único
# 2     INATIVO - TRANSFERID                           45  JOÃO GUIMARAES-único
#
#    CÓD CLIENTE         UNIDADE OPERADORA   NF  DATA EMISSÃO NF  COMPETÊNCIA  \
# 0           25  BELO HORIZONTE      AMIL   68            44481      44501.0
# 1           36  BELO HORIZONTE      AMIL  111            44481      44501.0
# 2           96  BELO HORIZONTE      AMIL  178            44511      44531.0
#
#    QUINZENA  ... CONTAS A RECEBER  STATUS FINAL DA CONTA LIGAÇÃO   \
# 0       2.0  ...         -3024.96                REGULAR      SIM
# 1       1.0  ...           866.67         GLOSA INDEVIDA      NÃO
# 2       2.0  ...         -9575.45             EMPACOTADO        N
#
#   DATA DA LIGAÇÃO RECLAMAÇÃO CHAT DATA DA RECLAMAÇÃO  NIP DATA DA NIP  \
# 0           45118             SIM              45382  SIM       45412
# 1           45153             NÃO              45213  NÃO       45229
# 2           45118             SIM              45178  SIM       45194
#
#   ETAPAS DA JUDICILIAZAÇÃO                                        OBSERVAÇÕES
# 0              DOC ENVIADA  Liberado pagamento por OP pela operadora em 15...
# 1              PROTOCOLADO  Conta apresentada em 20/06/2024. Foi solicitad...
# 2        LIMINAR CONCEDIDA  Liberado pagamento por OP pela operadora em 20...
#
# [3 rows x 45 columns]
# Missing values:
#   NF                             56
# COMPETÊNCIA                      2
# QUINZENA                         4
# VALOR                           47
# DATA DO CONTRATO                37
# VALOR FINANCIADO                47
# VALOR PAGAMENTO CLÍNICA        240
# DATA PAGAMENTO CLÍNICA         212
# DATA PROTOCOLO                  49
# DATA DE VENCIMENTO               2
# VALOR PAGO                     240
# DATA DO PAGAMENTO REEMBOLSO    262
# VALOR GLOSADO                  232
# DATA DO PAGAMENTO FACTORING    262
# VALOR PAGAMENTO FACTORING      258
# CONTAS A RECEBER                10
# OBSERVAÇÕES                    811
# dtype: int64
# Number of duplicate rows: 0
#
# --- Sheet: SJC ---
# Shape: (2587, 45)
# Column names: ['Nº CONTRATO (SISTEMA GERA)', 'STATUS', 'CÓD CLIENTE', 'PACIENTE 2', 'UNIDADE', 'OPERADORA', ' NF', 'DATA EMISSÃO NF', 'COMPETÊNCIA', 'QUINZENA', 'VALOR', 'Nº SESSÕES', 'STATUS PRÉVIO DA CONTA', 'SOLICITANTE', 'STATUS ANÁLISE DE CRÉDITO', 'STATUS JURÍDICO CLIENTE', '1ª APROVAÇÃO CLÍNICA GARANTIDORA', '2ª APROVAÇÃO FACTORING', 'CONTRATO ASSINADO', 'DATA DO CONTRATO', 'FINANCIADO', 'VALOR FINANCIADO', 'DATA FINANCIAMENTO', 'PAGAMENTO CLINICA', 'VALOR PAGAMENTO CLÍNICA', 'DATA PAGAMENTO CLÍNICA', 'TRANSMISSÃO DA CONTA', 'DATA PROTOCOLO ', 'DATA DE VENCIMENTO', 'STATUS CONTAS A RECEBER', 'VALOR PAGO', 'DATA DO PAGAMENTO REEMBOLSO', 'VALOR GLOSADO', 'DATA DO PAGAMENTO FACTORING', 'VALOR PAGAMENTO FACTORING', 'CONTAS A RECEBER', 'STATUS FINAL DA CONTA', 'LIGAÇÃO ', 'DATA DA LIGAÇÃO', 'RECLAMAÇÃO CHAT', 'DATA DA RECLAMAÇÃO', 'NIP', 'DATA DA NIP', 'ETAPAS DA JUDICILIAZAÇÃO', 'OBSERVAÇÕES']
# Data types:
#  Nº CONTRATO (SISTEMA GERA)                  object
# STATUS                                      object
# CÓD CLIENTE                                  int64
# PACIENTE 2                                  object
# UNIDADE                                     object
# OPERADORA                                   object
#  NF                                         object
# DATA EMISSÃO NF                     datetime64[ns]
# COMPETÊNCIA                         datetime64[ns]
# QUINZENA                                   float64
# VALOR                                       object
# Nº SESSÕES                                   int64
# STATUS PRÉVIO DA CONTA                      object
# SOLICITANTE                                 object
# STATUS ANÁLISE DE CRÉDITO                   object
# STATUS JURÍDICO CLIENTE                     object
# 1ª APROVAÇÃO CLÍNICA GARANTIDORA            object
# 2ª APROVAÇÃO FACTORING                      object
# CONTRATO ASSINADO                           object
# DATA DO CONTRATO                            object
# FINANCIADO                                  object
# VALOR FINANCIADO                            object
# DATA FINANCIAMENTO                          object
# PAGAMENTO CLINICA                           object
# VALOR PAGAMENTO CLÍNICA                    float64
# DATA PAGAMENTO CLÍNICA              datetime64[ns]
# TRANSMISSÃO DA CONTA                        object
# DATA PROTOCOLO                      datetime64[ns]
# DATA DE VENCIMENTO                  datetime64[ns]
# STATUS CONTAS A RECEBER                     object
# VALOR PAGO                                  object
# DATA DO PAGAMENTO REEMBOLSO                 object
# VALOR GLOSADO                               object
# DATA DO PAGAMENTO FACTORING         datetime64[ns]
# VALOR PAGAMENTO FACTORING                   object
# CONTAS A RECEBER                            object
# STATUS FINAL DA CONTA                       object
# LIGAÇÃO                                     object
# DATA DA LIGAÇÃO                     datetime64[ns]
# RECLAMAÇÃO CHAT                             object
# DATA DA RECLAMAÇÃO                  datetime64[ns]
# NIP                                         object
# DATA DA NIP                         datetime64[ns]
# ETAPAS DA JUDICILIAZAÇÃO                    object
# OBSERVAÇÕES                                 object
# dtype: object
# First 3 rows:
#    Nº CONTRATO (SISTEMA GERA)                   STATUS  CÓD CLIENTE  \
# 0                      12354                    ATIVO           10
# 1                      12375  INATIVO - TRANSPLANTADO           20
# 2                      12429     INATIVO - TRANSFERID           30
#
#               PACIENTE 2     UNIDADE OPERADORA   NF DATA EMISSÃO NF  \
# 0  Miguel Oliveira Costa  DOMICILIAR  BRADESCO  246      2021-09-27
# 1  Miguel Oliveira Costa  DOMICILIAR      brad  276      2021-09-27
# 2  Miguel Oliveira Costa  DOMICILIAR      brad  310      2021-10-27
#
#   COMPETÊNCIA  QUINZENA  ... CONTAS A RECEBER  STATUS FINAL DA CONTA LIGAÇÃO   \
# 0  2021-11-01       2.0  ...              NaN                REGULAR      SIM
# 1  2021-11-01       1.0  ...              NaN         GLOSA INDEVIDA      NÃO
# 2  2021-12-01       2.0  ...              NaN             EMPACOTADO        N
#
#   DATA DA LIGAÇÃO RECLAMAÇÃO CHAT DATA DA RECLAMAÇÃO  NIP DATA DA NIP  \
# 0      2023-07-11             SIM         2024-03-31  SIM  2024-04-30
# 1      2023-08-15             NÃO         2023-10-14  NÃO  2023-10-30
# 2      2023-07-11             SIM         2023-09-09  SIM  2023-09-25
#
#   ETAPAS DA JUDICILIAZAÇÃO                                        OBSERVAÇÕES
# 0              DOC ENVIADA  Liberado pagamento por OP pela operadora em 15...
# 1              PROTOCOLADO  Conta apresentada em 20/06/2024. Foi solicitad...
# 2        LIMINAR CONCEDIDA  Liberado pagamento por OP pela operadora em 20...
#
# [3 rows x 45 columns]
# Missing values:
#   NF                               2
# COMPETÊNCIA                       2
# QUINZENA                        940
# DATA DO CONTRATO               1067
# DATA FINANCIAMENTO              234
# VALOR PAGAMENTO CLÍNICA        2578
# DATA PAGAMENTO CLÍNICA         1076
# DATA PROTOCOLO                 1071
# DATA DE VENCIMENTO               23
# VALOR PAGO                      438
# DATA DO PAGAMENTO REEMBOLSO    1322
# VALOR GLOSADO                   365
# DATA DO PAGAMENTO FACTORING    2578
# VALOR PAGAMENTO FACTORING      1286
# CONTAS A RECEBER                140
# DATA DA LIGAÇÃO                  23
# DATA DA RECLAMAÇÃO               23
# DATA DA NIP                      23
# OBSERVAÇÕES                    2584
# dtype: int64
# Number of duplicate rows: 0
#
# --- Sheet: PAULINIA ---
# Shape: (251, 45)
# Column names: [' NF', 'OPERADORA', 'Nº CONTRATO (SISTEMA GERA)', 'STATUS', 'CÓD CLIENTE', 'USUÁRIO', 'UNIDADE', 'DATA EMISSÃO NF', 'COMPETÊNCIA', 'QUINZENA', 'VALOR', 'Nº SESSÕES', 'STATUS PRÉVIO DA CONTA', 'SOLICITANTE', 'STATUS ANÁLISE DE CRÉDITO', 'STATUS JURÍDICO CLIENTE', '1ª APROVAÇÃO CLÍNICA GARANTIDORA', '2ª APROVAÇÃO FACTORING', 'CONTRATO ASSINADO', 'DATA DO CONTRATO', 'FINANCIADO', 'VALOR FINANCIADO', 'DATA FINANCIAMENTO', 'PAGAMENTO CLINICA', 'VALOR PAGAMENTO CLÍNICA', 'DATA PAGAMENTO CLÍNICA', 'TRANSMISSÃO DA CONTA', 'DATA PROTOCOLO ', 'DATA DE VENCIMENTO', 'STATUS CONTAS A RECEBER', 'VALOR PAGO', 'DATA DO PAGAMENTO REEMBOLSO', 'VALOR GLOSADO', 'DATA DO PAGAMENTO FACTORING', 'VALOR PAGAMENTO FACTORING', 'CONTAS A RECEBER', 'STATUS FINAL DA CONTA', 'LIGAÇÃO ', 'DATA DA LIGAÇÃO', 'RECLAMAÇÃO CHAT', 'DATA DA RECLAMAÇÃO', 'NIP', 'DATA DA NIP', 'ETAPAS DA JUDICILIAZAÇÃO', 'OBSERVAÇÕES']
# Data types:
#   NF                                          int64
# OPERADORA                                   object
# Nº CONTRATO (SISTEMA GERA)                   int64
# STATUS                                      object
# CÓD CLIENTE                                  int64
# USUÁRIO                                     object
# UNIDADE                                     object
# DATA EMISSÃO NF                     datetime64[ns]
# COMPETÊNCIA                         datetime64[ns]
# QUINZENA                                   float64
# VALOR                                       object
# Nº SESSÕES                                   int64
# STATUS PRÉVIO DA CONTA                      object
# SOLICITANTE                                 object
# STATUS ANÁLISE DE CRÉDITO                   object
# STATUS JURÍDICO CLIENTE                     object
# 1ª APROVAÇÃO CLÍNICA GARANTIDORA            object
# 2ª APROVAÇÃO FACTORING                      object
# CONTRATO ASSINADO                           object
# DATA DO CONTRATO                    datetime64[ns]
# FINANCIADO                                  object
# VALOR FINANCIADO                            object
# DATA FINANCIAMENTO                  datetime64[ns]
# PAGAMENTO CLINICA                           object
# VALOR PAGAMENTO CLÍNICA                    float64
# DATA PAGAMENTO CLÍNICA              datetime64[ns]
# TRANSMISSÃO DA CONTA                        object
# DATA PROTOCOLO                      datetime64[ns]
# DATA DE VENCIMENTO                          object
# STATUS CONTAS A RECEBER                     object
# VALOR PAGO                                  object
# DATA DO PAGAMENTO REEMBOLSO                 object
# VALOR GLOSADO                               object
# DATA DO PAGAMENTO FACTORING                 object
# VALOR PAGAMENTO FACTORING                   object
# CONTAS A RECEBER                           float64
# STATUS FINAL DA CONTA                       object
# LIGAÇÃO                                     object
# DATA DA LIGAÇÃO                     datetime64[ns]
# RECLAMAÇÃO CHAT                             object
# DATA DA RECLAMAÇÃO                  datetime64[ns]
# NIP                                         object
# DATA DA NIP                         datetime64[ns]
# ETAPAS DA JUDICILIAZAÇÃO                    object
# OBSERVAÇÕES                                 object
# dtype: object
# First 3 rows:
#      NF   OPERADORA  Nº CONTRATO (SISTEMA GERA)                   STATUS  \
# 0  252    BRADESCO                           1                    ATIVO
# 1  253    BRADESCO                           2  INATIVO - TRANSPLANTADO
# 2  251  SULAMERICA                           3     INATIVO - TRANSFERID
#
#    CÓD CLIENTE                  USUÁRIO   UNIDADE DATA EMISSÃO NF COMPETÊNCIA  \
# 0           25         João Marcos HM -  PAULINIA      2021-10-07  2021-11-01
# 1           35  JOAO MARCOS MAT E MED -  PAULINIA      2021-10-07  2021-11-01
# 2         4555         RENAN JULIO HM -  PAULINIA      2021-11-06  2021-12-01
#
#    QUINZENA  ... CONTAS A RECEBER  STATUS FINAL DA CONTA LIGAÇÃO   \
# 0       2.0  ...              0.0                REGULAR      SIM
# 1       1.0  ...              0.0         GLOSA INDEVIDA      NÃO
# 2       2.0  ...              0.0             EMPACOTADO        N
#
#   DATA DA LIGAÇÃO RECLAMAÇÃO CHAT DATA DA RECLAMAÇÃO  NIP DATA DA NIP  \
# 0      2023-07-11             SIM         2024-03-31  SIM  2024-04-30
# 1      2023-08-15             NÃO         2023-10-14  NÃO  2023-10-30
# 2      2023-07-11             SIM         2023-09-09  SIM  2023-09-25
#
#   ETAPAS DA JUDICILIAZAÇÃO                                        OBSERVAÇÕES
# 0              DOC ENVIADA  Liberado pagamento por OP pela operadora em 15...
# 1              PROTOCOLADO  Conta apresentada em 20/06/2024. Foi solicitad...
# 2        LIMINAR CONCEDIDA  Liberado pagamento por OP pela operadora em 20...
#
# [3 rows x 45 columns]
# Missing values:
#  QUINZENA                         4
# DATA DO CONTRATO                24
# DATA FINANCIAMENTO               5
# VALOR PAGAMENTO CLÍNICA        242
# DATA PAGAMENTO CLÍNICA           5
# DATA DE VENCIMENTO               9
# VALOR PAGO                      11
# DATA DO PAGAMENTO REEMBOLSO      3
# VALOR GLOSADO                   11
# DATA DO PAGAMENTO FACTORING     21
# VALOR PAGAMENTO FACTORING       12
# OBSERVAÇÕES                    248
# dtype: int64
# Number of duplicate rows: 0
#
# --- Sheet: CAMPINAS ---
# Shape: (194, 44)
# Column names: ['Nº CONTRATO (SISTEMA GERA)', 'STATUS', 'CÓD CLIENTE', 'CLIENTES', 'UNIDADE', 'OPERADORA', ' NF', 'DATA EMISSÃO NF', 'COMPETÊNCIA', 'QUINZENA', 'VALOR', 'Nº SESSÕES', 'STATUS PRÉVIO DA CONTA', 'SOLICITANTE', 'STATUS ANÁLISE DE CRÉDITO', 'STATUS JURÍDICO CLIENTE', '1ª APROVAÇÃO CLÍNICA GARANTIDORA', '2ª APROVAÇÃO FACTORING', 'CONTRATO ASSINADO', 'DATA DO CONTRATO', 'FINANCIADO', 'VALOR FINANCIADO', 'DATA FINANCIAMENTO', 'PAGAMENTO CLINICA', 'VALOR PAGAMENTO CLÍNICA', 'DATA PAGAMENTO CLÍNICA', 'TRANSMISSÃO DA CONTA', 'DATA DE VENCIMENTO', 'STATUS CONTAS A RECEBER', 'VALOR PAGO', 'DATA DO PAGAMENTO REEMBOLSO', 'VALOR GLOSADO', 'DATA DO PAGAMENTO FACTORING', 'VALOR PAGAMENTO FACTORING', 'CONTAS A RECEBER', 'STATUS FINAL DA CONTA', 'LIGAÇÃO ', 'DATA DA LIGAÇÃO', 'RECLAMAÇÃO CHAT', 'DATA DA RECLAMAÇÃO', 'NIP', 'DATA DA NIP', 'ETAPAS DA JUDICILIAZAÇÃO', 'OBSERVAÇÕES']
# Data types:
#  Nº CONTRATO (SISTEMA GERA)                   int64
# STATUS                                      object
# CÓD CLIENTE                                  int64
# CLIENTES                                    object
# UNIDADE                                     object
# OPERADORA                                   object
#  NF                                        float64
# DATA EMISSÃO NF                     datetime64[ns]
# COMPETÊNCIA                         datetime64[ns]
# QUINZENA                                   float64
# VALOR                                       object
# Nº SESSÕES                                   int64
# STATUS PRÉVIO DA CONTA                      object
# SOLICITANTE                                 object
# STATUS ANÁLISE DE CRÉDITO                   object
# STATUS JURÍDICO CLIENTE                     object
# 1ª APROVAÇÃO CLÍNICA GARANTIDORA            object
# 2ª APROVAÇÃO FACTORING                      object
# CONTRATO ASSINADO                           object
# DATA DO CONTRATO                    datetime64[ns]
# FINANCIADO                                  object
# VALOR FINANCIADO                            object
# DATA FINANCIAMENTO                          object
# PAGAMENTO CLINICA                           object
# VALOR PAGAMENTO CLÍNICA                     object
# DATA PAGAMENTO CLÍNICA              datetime64[ns]
# TRANSMISSÃO DA CONTA                        object
# DATA DE VENCIMENTO                  datetime64[ns]
# STATUS CONTAS A RECEBER                     object
# VALOR PAGO                                  object
# DATA DO PAGAMENTO REEMBOLSO         datetime64[ns]
# VALOR GLOSADO                               object
# DATA DO PAGAMENTO FACTORING                 object
# VALOR PAGAMENTO FACTORING                   object
# CONTAS A RECEBER                            object
# STATUS FINAL DA CONTA                       object
# LIGAÇÃO                                     object
# DATA DA LIGAÇÃO                     datetime64[ns]
# RECLAMAÇÃO CHAT                             object
# DATA DA RECLAMAÇÃO                  datetime64[ns]
# NIP                                         object
# DATA DA NIP                         datetime64[ns]
# ETAPAS DA JUDICILIAZAÇÃO                    object
# OBSERVAÇÕES                                 object
# dtype: object
# First 3 rows:
#     Nº CONTRATO (SISTEMA GERA)                   STATUS  CÓD CLIENTE  \
# 0                           1                    ATIVO           25
# 1                           2  INATIVO - TRANSPLANTADO           35
# 2                           3     INATIVO - TRANSFERID         4555
#
#                                 CLIENTES   UNIDADE   OPERADORA     NF  \
# 0  ANDRÉ TEIXEIRA SOUZA Honorário Médico  CAMPINAS    BRADESCO  564.0
# 1         ANDRÉ TEIXEIRA SOUZA Mat e Med  CAMPINAS      VIVEST  565.0
# 2         ANDRÉ TEIXEIRA SOUZA Mat & Med  CAMPINAS  SULAMERICA  576.0
#
#   DATA EMISSÃO NF COMPETÊNCIA  QUINZENA  ... CONTAS A RECEBER  \
# 0      2024-01-07  2024-02-01       2.0  ...        -29829.43
# 1      2024-01-07  2024-02-01       1.0  ...         -3095.66
# 2      2024-01-07  2024-02-01       2.0  ...         -36596.2
#
#    STATUS FINAL DA CONTA LIGAÇÃO  DATA DA LIGAÇÃO RECLAMAÇÃO CHAT  \
# 0                REGULAR      SIM      2023-07-11             SIM
# 1         GLOSA INDEVIDA      NÃO      2023-08-15             NÃO
# 2             EMPACOTADO        N      2023-07-11             SIM
#
#   DATA DA RECLAMAÇÃO  NIP DATA DA NIP ETAPAS DA JUDICILIAZAÇÃO  \
# 0         2024-03-31  SIM  2024-04-30              DOC ENVIADA
# 1         2023-10-14  NÃO  2023-10-30              PROTOCOLADO
# 2         2023-09-09  SIM  2023-09-25        LIMINAR CONCEDIDA
#
#                                          OBSERVAÇÕES
# 0  Liberado pagamento por OP pela operadora em 15...
# 1  Conta apresentada em 20/06/2024. Foi solicitad...
# 2  Liberado pagamento por OP pela operadora em 20...
#
# [3 rows x 44 columns]
# Missing values:
#   NF                             35
# QUINZENA                         4
# VALOR                           35
# DATA DO CONTRATO                23
# VALOR FINANCIADO                35
# DATA FINANCIAMENTO              35
# VALOR PAGAMENTO CLÍNICA         76
# DATA PAGAMENTO CLÍNICA          36
# DATA DE VENCIMENTO              36
# VALOR PAGO                      76
# DATA DO PAGAMENTO REEMBOLSO     36
# VALOR GLOSADO                   76
# DATA DO PAGAMENTO FACTORING     80
# VALOR PAGAMENTO FACTORING        2
# OBSERVAÇÕES                    191
# dtype: int64
# Number of duplicate rows: 0

# %%
# Now let's continue our analysis by focusing on the remaining sheets
# and convert the VALOR column to numeric for analysis

# Let's look at the remaining sheets in more depth
location_sheets = ['Alphaville', 'BH', 'SJC', 'PAULINIA', 'CAMPINAS']

# Dictionary to store cleaned data frames
cleaned_dfs = {}

for sheet in location_sheets:
    if sheet in dfs:
        print(f"\n--- Detailed analysis of {sheet} sheet ---")
        
        # Convert VALOR column to numeric (removing any currency symbols, etc.)
        if 'VALOR' in dfs[sheet].columns:
            # First, check the current format
            print(f"VALOR column sample values: {dfs[sheet]['VALOR'].head(3).tolist()}")
            
            # Try to convert to numeric, coercing errors to NaN
            dfs[sheet]['VALOR_NUMERIC'] = pd.to_numeric(
                dfs[sheet]['VALOR'].str.replace('R\$', '').str.replace('.', '').str.replace(',', '.'),
                errors='coerce'
            )
            
            # Check if the conversion worked
            print(f"Converted VALOR sample: {dfs[sheet]['VALOR_NUMERIC'].head(3).tolist()}")
            print(f"NaN values after conversion: {dfs[sheet]['VALOR_NUMERIC'].isna().sum()}")
        
        # Check for data consistency between sheets
        print(f"Column count: {dfs[sheet].shape[1]}")
        
        # Analyze key statistics
        numeric_columns = dfs[sheet].select_dtypes(include=[np.number])
        if not numeric_columns.empty:
            print("\nNumeric columns statistics:")
            print(numeric_columns.describe().T)
        
        # Analyze categorical columns
        categorical_columns = dfs[sheet].select_dtypes(include=['object'])
        if not categorical_columns.empty:
            print("\nCategorical columns unique values count:")
            for col in categorical_columns.columns[:5]:  # Limiting to first 5 columns to avoid too much output
                print(f"{col}: {categorical_columns[col].nunique()} unique values")
                print(f"Top 3 values: {categorical_columns[col].value_counts().nlargest(3)}")
        
        # Check date columns for temporal range
        date_columns = dfs[sheet].select_dtypes(include=['datetime64'])
        if not date_columns.empty:
            print("\nDate ranges:")
            for col in date_columns.columns:
                min_date = date_columns[col].min()
                max_date = date_columns[col].max()
                print(f"{col}: {min_date} to {max_date}")
        
        # Store the dataframe with converted values
        cleaned_dfs[sheet] = dfs[sheet]

# Check for inconsistencies between location sheets
print("\n--- Checking inconsistencies between sheets ---")
if len(location_sheets) > 1 and all(sheet in dfs for sheet in location_sheets):
    # Check if all sheets have the same columns
    all_columns = [set(dfs[sheet].columns) for sheet in location_sheets]
    common_columns = set.intersection(*all_columns)
    
    print(f"Common columns across all location sheets: {len(common_columns)}")
    
    # Check for differences in columns
    for sheet in location_sheets:
        diff_columns = set(dfs[sheet].columns) - common_columns
        if diff_columns:
            print(f"{sheet} has {len(diff_columns)} unique columns: {diff_columns}")
# Out:
# --- Detailed analysis of Alphaville sheet ---
# VALOR column sample values: [41545.78, 54270.99, 43074.45]
# Converted VALOR sample: [nan, nan, nan]
# NaN values after conversion: 1651
# Column count: 46
#
# Numeric columns statistics:
#                              count          mean           std      min  \
# Nº CONTRATO (SISTEMA GERA)  1651.0    826.000000    476.746963      1.0
# CÓD CLIENTE                 1651.0   8260.000000   4767.469629     10.0
#  NF                         1646.0   4019.770960    596.754145   2965.0
# QUINZENA                    1647.0      1.485124      0.499930      1.0
# Nº SESSÕES                  1651.0     14.933374      3.530188      9.0
# VALOR FINANCIADO            1651.0  47518.230999  21057.175113   3000.0
# VALOR PAGAMENTO FACTORING      9.0  37654.580000  14857.632211  10000.0
# VALOR_NUMERIC                  0.0           NaN           NaN      NaN
#
#                                  25%       50%        75%        max
# Nº CONTRATO (SISTEMA GERA)    413.50    826.00   1238.500    1651.00
# CÓD CLIENTE                  4135.00   8260.00  12385.000   16510.00
#  NF                          3511.50   4023.50   4538.750    5034.00
# QUINZENA                        1.00      1.00      2.000       2.00
# Nº SESSÕES                     13.00     15.00     19.000      20.00
# VALOR FINANCIADO            30608.21  50228.69  63148.495  124526.12
# VALOR PAGAMENTO FACTORING   30000.00  41545.78  50000.000   54270.99
# VALOR_NUMERIC                    NaN       NaN        NaN        NaN
#
# Categorical columns unique values count:
# STATUS: 9 unique values
# Top 3 values: STATUS
# ATIVO                      710
# INATIVO - TRANSPLANTADO    118
# INATIVO - TRANSFERID       118
# Name: count, dtype: int64
# PACIENTYES: 33 unique values
# Top 3 values: PACIENTYES
# Gabriel Souza Lima         188
# Daniel Teixeira Costa      166
# Leonardo Mendes Almeida    128
# Name: count, dtype: int64
# UNIDADE: 2 unique values
# Top 3 values: UNIDADE
# ALPHAVILLE    1633
# alpha           18
# Name: count, dtype: int64
# OPERADORA: 8 unique values
# Top 3 values: OPERADORA
# BRADESCO          695
# SUL AMERICA       502
# SEGUROS UNIMED    129
# Name: count, dtype: int64
# VALOR: 1492 unique values
# Top 3 values: VALOR
# 19500    23
# 16900    22
# 15600    19
# Name: count, dtype: int64
#
# Date ranges:
# DATA EMISSÃO NF: 1899-11-30 00:00:00 to 2024-07-02 00:00:00
# COMPETÊNCIA: 2023-01-01 00:00:00 to 2024-08-01 00:00:00
# DATA PAGAMENTO CLÍNICA: 2023-01-06 00:00:00 to 2024-08-29 00:00:00
# DATA PROTOCOLO : 2023-01-15 00:00:00 to 2024-08-29 00:00:00
# DATA DE VENCIMENTO: 1900-01-30 00:00:00 to 2024-09-29 00:00:00
# DATA DO PAGAMENTO FACTORING: 2023-06-26 00:00:00 to 2024-06-01 00:00:00
# DATA DA LIGAÇÃO: 1900-02-28 00:00:00 to 2024-07-31 00:00:00
# DATA DA RECLAMAÇÃO: 1900-03-30 00:00:00 to 2024-08-30 00:00:00
# DATA DA NIP: 1900-04-25 00:00:00 to 2024-09-25 00:00:00
#
# --- Detailed analysis of BH sheet ---
# VALOR column sample values: [51231.24, 47328.33, 57888.45]
# Converted VALOR sample: [nan, nan, nan]
# NaN values after conversion: 814
# Column count: 46
#
# Numeric columns statistics:
#                              count          mean           std      min  \
# Nº CONTRATO (SISTEMA GERA)2  814.0    401.980344    202.705094     25.0
# CÓD CLIENTE                  814.0    588.352580    314.332033     25.0
# DATA EMISSÃO NF              814.0  44985.426290   2253.224774    -20.0
# COMPETÊNCIA                  812.0  45116.277094    286.705472  44197.0
# QUINZENA                     810.0      1.492593      0.500254      1.0
# Nº SESSÕES                   814.0     12.566339      1.593312     10.0
# DATA FINANCIAMENTO           814.0  45281.986486    193.137820  44927.0
# DATA PROTOCOLO               765.0  45282.162092    175.922683  44944.0
# DATA DE VENCIMENTO           812.0  33436.859606  19939.932835     20.0
# CONTAS A RECEBER             804.0  20261.605224  17342.851594 -41740.0
# DATA DA LIGAÇÃO              814.0  42716.482801  10329.519296     56.0
# DATA DA RECLAMAÇÃO           814.0  42776.733415  10329.580108    116.0
# DATA DA NIP                  814.0  42792.750614  10329.584463    132.0
# VALOR_NUMERIC                  0.0           NaN           NaN      NaN
#
#                                    25%       50%       75%       max
# Nº CONTRATO (SISTEMA GERA)2    228.250    402.50    576.75    780.00
# CÓD CLIENTE                    317.000    588.00    859.25   1176.00
# DATA EMISSÃO NF              44891.000  45142.00  45347.00  45500.00
# COMPETÊNCIA                  44911.000  45170.00  45367.00  45520.00
# QUINZENA                         1.000      1.00      2.00      2.00
# Nº SESSÕES                      11.000     13.00     14.00     15.00
# DATA FINANCIAMENTO           45108.000  45346.00  45467.00  45528.00
# DATA PROTOCOLO               45125.000  45299.00  45448.00  45533.00
# DATA DE VENCIMENTO              20.000  45202.50  45429.50  45655.00
# CONTAS A RECEBER              6192.605  19498.22  35535.45  84354.34
# DATA DA LIGAÇÃO              44945.250  45208.00  45460.00  45590.00
# DATA DA RECLAMAÇÃO           45005.250  45268.00  45520.00  45650.00
# DATA DA NIP                  45021.250  45284.00  45536.00  45666.00
# VALOR_NUMERIC                      NaN       NaN       NaN       NaN
#
# Categorical columns unique values count:
# STATUS: 13 unique values
# Top 3 values: STATUS
# ATIVO                      352
# INATIVO - TRANSPLANTADO     82
# INATIVO - TRANSFERID        55
# Name: count, dtype: int64
# PACIENTE 2: 132 unique values
# Top 3 values: PACIENTE 2
# Julio Freitas-1ª        36
# CARLOS REIS-MAT MED     22
# JOÃO GUIMARAES-único    20
# Name: count, dtype: int64
# UNIDADE: 4 unique values
# Top 3 values: UNIDADE
# BELO HORIZONTE    807
# OSASCO              5
# ALPHAVILLE          1
# Name: count, dtype: int64
# OPERADORA: 11 unique values
# Top 3 values: OPERADORA
# BRADESCO REEMBOLSO      318
# SULAMÉRICA REEMBOLSO    206
# PETROBRAS                85
# Name: count, dtype: int64
#  NF: 546 unique values
# Top 3 values:  NF
# S/NF    25
# 222      3
# 582      3
# Name: count, dtype: int64
#
# --- Detailed analysis of SJC sheet ---
# VALOR column sample values: [datetime.datetime(2014, 1, 20, 9, 21, 36), datetime.datetime(2016, 5, 29, 18, 57, 36), datetime.datetime(2016, 8, 29, 9, 21, 36)]
# Converted VALOR sample: [nan, nan, nan]
# NaN values after conversion: 2587
# Column count: 46
#
# Numeric columns statistics:
#                           count          mean           std      min      25%  \
# CÓD CLIENTE              2587.0  14085.781214   8133.420106     10.0   7043.0
# QUINZENA                 1647.0      1.485124      0.499930      1.0      1.0
# Nº SESSÕES               2587.0     16.305760      3.358978     10.0     14.0
# VALOR PAGAMENTO CLÍNICA     9.0  37654.580000  14857.632211  10000.0  30000.0
# VALOR_NUMERIC               0.0           NaN           NaN      NaN      NaN
#
#                               50%      75%       max
# CÓD CLIENTE              14084.00  21125.0  28166.00
# QUINZENA                     1.00      2.0      2.00
# Nº SESSÕES                  18.00     19.0     20.00
# VALOR PAGAMENTO CLÍNICA  41545.78  50000.0  54270.99
# VALOR_NUMERIC                 NaN      NaN       NaN
#
# Categorical columns unique values count:
# Nº CONTRATO (SISTEMA GERA): 2587 unique values
# Top 3 values: Nº CONTRATO (SISTEMA GERA)
# 1.235400e+04    1
# 9.818527e+06    1
# 9.948261e+06    1
# Name: count, dtype: int64
# STATUS: 13 unique values
# Top 3 values: STATUS
# ATIVO                      1122
# INATIVO - TRANSPLANTADO     259
# INATIVO - TRANSFERID        173
# Name: count, dtype: int64
# PACIENTE 2: 22 unique values
# Top 3 values: PACIENTE 2
# CAMILA MOURA SILVA        316
# MaRcElO nuNeS FeRreiRa    232
# pAuLa AlMeIdA lOpEs       229
# Name: count, dtype: int64
# UNIDADE: 4 unique values
# Top 3 values: UNIDADE
# DOMICILIAR    1622
# SJC            841
# LINS            65
# Name: count, dtype: int64
# OPERADORA: 18 unique values
# Top 3 values: OPERADORA
# SULAMERICA     925
# BRADESCO       810
# SULAMERICA     534
# Name: count, dtype: int64
#
# Date ranges:
# DATA EMISSÃO NF: 1899-11-25 00:00:00 to 2024-07-12 00:00:00
# COMPETÊNCIA: 2021-01-01 00:00:00 to 2024-08-16 00:00:00
# DATA PAGAMENTO CLÍNICA: 2023-01-06 00:00:00 to 2024-08-29 00:00:00
# DATA PROTOCOLO : 2023-01-15 00:00:00 to 2024-08-29 00:00:00
# DATA DE VENCIMENTO: 1900-01-30 00:00:00 to 2024-09-29 00:00:00
# DATA DO PAGAMENTO FACTORING: 2023-06-26 00:00:00 to 2024-06-01 00:00:00
# DATA DA LIGAÇÃO: 1900-02-25 00:00:00 to 2024-10-25 00:00:00
# DATA DA RECLAMAÇÃO: 1900-04-25 00:00:00 to 2024-12-24 00:00:00
# DATA DA NIP: 1900-05-11 00:00:00 to 2025-01-09 00:00:00
#
# --- Detailed analysis of PAULINIA sheet ---
# VALOR column sample values: [78661.77, 55947.52, 54432.92]
# Converted VALOR sample: [nan, nan, nan]
# NaN values after conversion: 251
# Column count: 46
#
# Numeric columns statistics:
#                             count          mean           std      min  \
#  NF                         251.0    446.003984    126.564750    250.0
# Nº CONTRATO (SISTEMA GERA)  251.0    126.000000     72.601653      1.0
# CÓD CLIENTE                 251.0   1003.677291   1691.641176     25.0
# QUINZENA                    247.0      1.506073      0.500978      1.0
# Nº SESSÕES                  251.0     16.302789      3.366297     10.0
# VALOR PAGAMENTO CLÍNICA       9.0  37654.580000  14857.632211  10000.0
# CONTAS A RECEBER            251.0   2008.542908  10983.332963 -27341.9
# VALOR_NUMERIC                 0.0           NaN           NaN      NaN
#
#                                 25%       50%      75%        max
#  NF                           333.0    437.00    539.5     682.00
# Nº CONTRATO (SISTEMA GERA)     63.5    126.00    188.5     251.00
# CÓD CLIENTE                   165.0    292.00    415.0    4965.00
# QUINZENA                        1.0      2.00      2.0       2.00
# Nº SESSÕES                     14.0     18.00     19.0      20.00
# VALOR PAGAMENTO CLÍNICA     30000.0  41545.78  50000.0   54270.99
# CONTAS A RECEBER                0.0      0.00      0.0  101950.24
# VALOR_NUMERIC                   NaN       NaN      NaN        NaN
#
# Categorical columns unique values count:
# OPERADORA: 5 unique values
# Top 3 values: OPERADORA
# VIVEST        84
# BRADESCO      59
# SULAMERICA    51
# Name: count, dtype: int64
# STATUS: 13 unique values
# Top 3 values: STATUS
# ATIVO                      111
# INATIVO - TRANSPLANTADO     26
# INATIVO - TRANSFERID        17
# Name: count, dtype: int64
# USUÁRIO: 18 unique values
# Top 3 values: USUÁRIO
# Sebastião Reis HM -    40
# RENAN JULIO HM -       33
# Fábio braga            19
# Name: count, dtype: int64
# UNIDADE: 1 unique values
# Top 3 values: UNIDADE
# PAULINIA    251
# Name: count, dtype: int64
# VALOR: 250 unique values
# Top 3 values: VALOR
# 1951-03-27 10:04:48    2
# 78661.77               1
# 70,536,46              1
# Name: count, dtype: int64
#
# Date ranges:
# DATA EMISSÃO NF: 2021-10-07 00:00:00 to 2024-07-22 00:00:00
# COMPETÊNCIA: 2021-11-01 00:00:00 to 2024-08-16 00:00:00
# DATA DO CONTRATO: 2023-01-13 00:00:00 to 2024-08-28 00:00:00
# DATA FINANCIAMENTO: 2023-02-03 00:00:00 to 2024-08-23 00:00:00
# DATA PAGAMENTO CLÍNICA: 2023-02-03 00:00:00 to 2024-10-07 00:00:00
# DATA PROTOCOLO : 1900-01-10 00:00:00 to 2024-10-17 00:00:00
# DATA DA LIGAÇÃO: 1900-02-25 00:00:00 to 2024-10-23 00:00:00
# DATA DA RECLAMAÇÃO: 1900-04-25 00:00:00 to 2024-12-22 00:00:00
# DATA DA NIP: 1900-05-11 00:00:00 to 2025-01-07 00:00:00
#
# --- Detailed analysis of CAMPINAS sheet ---
# VALOR column sample values: [47620.67, 51408.02, 13345]
# Converted VALOR sample: [nan, nan, nan]
# NaN values after conversion: 194
# Column count: 45
#
# Numeric columns statistics:
#                             count        mean          std   min     25%  \
# Nº CONTRATO (SISTEMA GERA)  194.0   97.500000    56.147128   1.0   49.25
# CÓD CLIENTE                 194.0  945.298969  1680.175199  25.0  135.50
#  NF                         159.0  136.547170   143.890240   6.0   59.50
# QUINZENA                    190.0    1.505263     0.501293   1.0    1.00
# Nº SESSÕES                  194.0   16.298969     3.345912  10.0   14.00
# VALOR_NUMERIC                 0.0         NaN          NaN   NaN     NaN
#
#                               50%     75%     max
# Nº CONTRATO (SISTEMA GERA)   97.5  145.75   194.0
# CÓD CLIENTE                 235.0  330.75  4865.0
#  NF                         103.0  146.50   583.0
# QUINZENA                      2.0    2.00     2.0
# Nº SESSÕES                   18.0   19.00    20.0
# VALOR_NUMERIC                 NaN     NaN     NaN
#
# Categorical columns unique values count:
# STATUS: 13 unique values
# Top 3 values: STATUS
# ATIVO                      86
# INATIVO - TRANSPLANTADO    21
# INATIVO - TRANSFERID       14
# Name: count, dtype: int64
# CLIENTES: 28 unique values
# Top 3 values: CLIENTES
# nICoLe FeRrEiRa mEnDeS     40
# VINÍCIUS CASTRO MENDES     21
# Joana Reis                 18
# Name: count, dtype: int64
# UNIDADE: 1 unique values
# Top 3 values: UNIDADE
# CAMPINAS    194
# Name: count, dtype: int64
# OPERADORA: 5 unique values
# Top 3 values: OPERADORA
# SULAMERICA    70
# AMIL          59
# BRADESCO      28
# Name: count, dtype: int64
# VALOR: 118 unique values
# Top 3 values: VALOR
# 14130.0    8
# 13345.0    8
# 8702.4     5
# Name: count, dtype: int64
#
# Date ranges:
# DATA EMISSÃO NF: 2024-01-07 00:00:00 to 2024-07-07 00:00:00
# COMPETÊNCIA: 2024-02-01 00:00:00 to 2024-08-01 00:00:00
# DATA DO CONTRATO: 2023-01-13 00:00:00 to 2024-08-28 00:00:00
# DATA PAGAMENTO CLÍNICA: 2024-04-10 00:00:00 to 2024-09-29 00:00:00
# DATA DE VENCIMENTO: 2024-03-11 00:00:00 to 2024-08-30 00:00:00
# DATA DO PAGAMENTO REEMBOLSO: 2024-04-10 00:00:00 to 2024-09-29 00:00:00
# DATA DA LIGAÇÃO: 1900-02-25 00:00:00 to 2024-10-16 00:00:00
# DATA DA RECLAMAÇÃO: 1900-04-25 00:00:00 to 2024-12-15 00:00:00
# DATA DA NIP: 1900-05-11 00:00:00 to 2024-12-31 00:00:00
#
# --- Checking inconsistencies between sheets ---
# Common columns across all location sheets: 43
# Alphaville has 3 unique columns: {'PACIENTYES', 'DATA PROTOCOLO ', 'Nº CONTRATO (SISTEMA GERA)'}
# BH has 3 unique columns: {'PACIENTE 2', 'Nº CONTRATO (SISTEMA GERA)2', 'DATA PROTOCOLO '}
# SJC has 3 unique columns: {'PACIENTE 2', 'Nº CONTRATO (SISTEMA GERA)', 'DATA PROTOCOLO '}
# PAULINIA has 3 unique columns: {'Nº CONTRATO (SISTEMA GERA)', 'DATA PROTOCOLO ', 'USUÁRIO'}
# CAMPINAS has 2 unique columns: {'Nº CONTRATO (SISTEMA GERA)', 'CLIENTES'}

# %%
# Fix the VALOR conversion issue and complete the analysis of all sheets
import re

# Function to properly convert VALOR to numeric
def convert_to_numeric(value):
    if pd.isna(value):
        return np.nan
    if isinstance(value, (int, float)):
        return value
    
    # Remove non-numeric characters except for decimal separator
    # First, standardize the value format
    value_str = str(value)
    # Remove currency symbols, spaces, etc.
    cleaned = re.sub(r'[^\d,.]', '', value_str)
    # Convert Brazilian/European format (1.234,56) to US format (1234.56)
    if ',' in cleaned and '.' in cleaned:
        cleaned = cleaned.replace('.', '').replace(',', '.')
    elif ',' in cleaned:
        cleaned = cleaned.replace(',', '.')
    
    try:
        return float(cleaned)
    except:
        return np.nan

# Create a comprehensive comparison of all location sheets
location_sheets = ['Alphaville', 'BH', 'SJC', 'PAULINIA', 'CAMPINAS']
summary_data = {}

# Process each sheet
for sheet in location_sheets:
    if sheet in dfs:
        df = dfs[sheet].copy()
        
        print(f"\n--- Processing {sheet} sheet ---")
        
        # Convert VALOR to numeric
        if 'VALOR' in df.columns:
            # Apply the conversion function
            df['VALOR_NUMERIC'] = df['VALOR'].apply(convert_to_numeric)
            print(f"Converted VALOR sample: {df['VALOR_NUMERIC'].head(3).tolist()}")
            print(f"NaN values after conversion: {df['VALOR_NUMERIC'].isna().sum()}")
            
            # Basic statistics on VALOR
            if df['VALOR_NUMERIC'].notna().any():
                print(f"VALOR statistics: Min={df['VALOR_NUMERIC'].min()}, Max={df['VALOR_NUMERIC'].max()}, Mean={df['VALOR_NUMERIC'].mean()}")
        
        # Check for inconsistent column names (case, spacing, etc.)
        column_names = df.columns.tolist()
        cleaned_column_names = [col.strip().upper() for col in column_names]
        if len(set(cleaned_column_names)) != len(column_names):
            print("Warning: Potential inconsistent column naming (case or spacing)")
            duplicates = [col for col in cleaned_column_names if cleaned_column_names.count(col) > 1]
            if duplicates:
                print(f"Duplicate columns after normalization: {set(duplicates)}")
        
        # Check for inconsistencies in categorical data
        if 'UNIDADE' in df.columns:
            print(f"UNIDADE values in {sheet}: {df['UNIDADE'].unique()}")
        
        # Store sheet-specific data for summary
        summary_data[sheet] = {
            'row_count': df.shape[0],
            'column_count': df.shape[1],
            'missing_values': df.isnull().sum().sum(),
            'date_range': None
        }
        
        # Get date range if available
        date_cols = df.select_dtypes(include=['datetime64']).columns
        if len(date_cols) > 0:
            min_date = df[date_cols].min().min()
            max_date = df[date_cols].max().max()
            summary_data[sheet]['date_range'] = (min_date, max_date)
        
        # Store the cleaned dataframe
        cleaned_dfs[sheet] = df

# Summarize the findings
print("\n--- Summary of Data Analysis ---")
print(f"Total sheets analyzed: {len(location_sheets)}")
for sheet, data in summary_data.items():
    print(f"\n{sheet}:")
    print(f"  - Records: {data['row_count']}")
    print(f"  - Fields: {data['column_count']}")
    print(f"  - Missing values: {data['missing_values']}")
    if data['date_range']:
        print(f"  - Date range: {data['date_range'][0]} to {data['date_range'][1]}")

# Identify structure inconsistencies across sheets
print("\n--- Structural Inconsistencies ---")
all_columns = [set(dfs[sheet].columns) for sheet in location_sheets if sheet in dfs]
if all_columns:
    common_columns = set.intersection(*all_columns)
    all_columns_flat = set().union(*all_columns)
    
    print(f"Total unique columns across all sheets: {len(all_columns_flat)}")
    print(f"Common columns across all sheets: {len(common_columns)}")
    
    # Find columns unique to specific sheets
    for i, sheet in enumerate(location_sheets):
        if sheet in dfs:
            unique_cols = set(dfs[sheet].columns) - common_columns
            if unique_cols:
                print(f"{sheet} has {len(unique_cols)} unique columns: {unique_cols}")
    
    # Check type inconsistencies in common columns
    type_inconsistencies = []
    for col in common_columns:
        col_types = {}
        for sheet in location_sheets:
            if sheet in dfs and col in dfs[sheet].columns:
                col_type = str(dfs[sheet][col].dtype)
                if col_type not in col_types:
                    col_types[col_type] = []
                col_types[col_type].append(sheet)
        
        if len(col_types) > 1:
            type_inconsistencies.append((col, col_types))
    
    if type_inconsistencies:
        print("\nType inconsistencies in common columns:")
        for col, types in type_inconsistencies:
            print(f"Column '{col}' has different types:")
            for type_name, sheets in types.items():
                print(f"  - {type_name}: in sheets {', '.join(sheets)}")
# Out:
# --- Processing Alphaville sheet ---
# Converted VALOR sample: [41545.78, 54270.99, 43074.45]
# NaN values after conversion: 21
# VALOR statistics: Min=3000.0, Max=124526.12, Mean=47585.67782822086
# UNIDADE values in Alphaville: ['ALPHAVILLE' 'alpha ']
#
# --- Processing BH sheet ---
# Converted VALOR sample: [51231.24, 47328.33, 57888.45]
# NaN values after conversion: 52
# VALOR statistics: Min=8.0, Max=84354.34, Mean=28020.540530971128
# UNIDADE values in BH: ['BELO HORIZONTE' 'OSASCO' 'ALPHAVILLE' 'BSB']
#
# --- Processing SJC sheet ---
# Converted VALOR sample: [20140120092136.0, 20160529185736.0, 20160829092136.0]
# NaN values after conversion: 18
# VALOR statistics: Min=2600.0, Max=26030602074048.0, Mean=11384180980684.389
# UNIDADE values in SJC: ['DOMICILIAR' 'SJC' 'MORUMBI' 'LINS']
#
# --- Processing PAULINIA sheet ---
# Converted VALOR sample: [78661.77, 55947.52, 54432.92]
# NaN values after conversion: 10
# VALOR statistics: Min=6167.61, Max=21600212072624.0, Mean=1943374697564.2173
# UNIDADE values in PAULINIA: ['PAULINIA']
#
# --- Processing CAMPINAS sheet ---
# Converted VALOR sample: [47620.67, 51408.02, 13345.0]
# NaN values after conversion: 45
# VALOR statistics: Min=3681.72, Max=89595.06, Mean=36082.521073825505
# UNIDADE values in CAMPINAS: ['CAMPINAS']
#
# --- Summary of Data Analysis ---
# Total sheets analyzed: 5
#
# Alphaville:
#   - Records: 1651
#   - Fields: 46
#   - Missing values: 9732
#   - Date range: 1899-11-30 00:00:00 to 2024-09-29 00:00:00
#
# BH:
#   - Records: 814
#   - Fields: 46
#   - Missing values: 2823
#
# SJC:
#   - Records: 2587
#   - Fields: 46
#   - Missing values: 15793
#   - Date range: 1899-11-25 00:00:00 to 2025-01-09 00:00:00
#
# PAULINIA:
#   - Records: 251
#   - Fields: 46
#   - Missing values: 605
#   - Date range: 1900-01-10 00:00:00 to 2025-01-07 00:00:00
#
# CAMPINAS:
#   - Records: 194
#   - Fields: 45
#   - Missing values: 821
#   - Date range: 1900-02-25 00:00:00 to 2024-12-31 00:00:00
#
# --- Structural Inconsistencies ---
# Total unique columns across all sheets: 50
# Common columns across all sheets: 43
# Alphaville has 3 unique columns: {'PACIENTYES', 'DATA PROTOCOLO ', 'Nº CONTRATO (SISTEMA GERA)'}
# BH has 3 unique columns: {'PACIENTE 2', 'Nº CONTRATO (SISTEMA GERA)2', 'DATA PROTOCOLO '}
# SJC has 3 unique columns: {'PACIENTE 2', 'Nº CONTRATO (SISTEMA GERA)', 'DATA PROTOCOLO '}
# PAULINIA has 3 unique columns: {'Nº CONTRATO (SISTEMA GERA)', 'DATA PROTOCOLO ', 'USUÁRIO'}
# CAMPINAS has 2 unique columns: {'Nº CONTRATO (SISTEMA GERA)', 'CLIENTES'}
#
# Type inconsistencies in common columns:
# Column 'VALOR FINANCIADO' has different types:
#   - float64: in sheets Alphaville
#   - object: in sheets BH, SJC, PAULINIA, CAMPINAS
# Column 'COMPETÊNCIA' has different types:
#   - datetime64[ns]: in sheets Alphaville, SJC, PAULINIA, CAMPINAS
#   - float64: in sheets BH
# Column 'DATA FINANCIAMENTO' has different types:
#   - object: in sheets Alphaville, SJC, CAMPINAS
#   - int64: in sheets BH
#   - datetime64[ns]: in sheets PAULINIA
# Column 'CONTAS A RECEBER' has different types:
#   - object: in sheets Alphaville, SJC, CAMPINAS
#   - float64: in sheets BH, PAULINIA
# Column 'DATA DO PAGAMENTO FACTORING' has different types:
#   - datetime64[ns]: in sheets Alphaville, SJC
#   - object: in sheets BH, PAULINIA, CAMPINAS
# Column 'DATA DA RECLAMAÇÃO' has different types:
#   - datetime64[ns]: in sheets Alphaville, SJC, PAULINIA, CAMPINAS
#   - int64: in sheets BH
# Column 'DATA DO PAGAMENTO REEMBOLSO' has different types:
#   - object: in sheets Alphaville, BH, SJC, PAULINIA
#   - datetime64[ns]: in sheets CAMPINAS
# Column 'DATA PAGAMENTO CLÍNICA' has different types:
#   - datetime64[ns]: in sheets Alphaville, SJC, PAULINIA, CAMPINAS
#   - object: in sheets BH
# Column ' NF' has different types:
#   - float64: in sheets Alphaville, CAMPINAS
#   - object: in sheets BH, SJC
#   - int64: in sheets PAULINIA
# Column 'DATA DA NIP' has different types:
#   - datetime64[ns]: in sheets Alphaville, SJC, PAULINIA, CAMPINAS
#   - int64: in sheets BH
# Column 'VALOR PAGAMENTO CLÍNICA' has different types:
#   - object: in sheets Alphaville, BH, CAMPINAS
#   - float64: in sheets SJC, PAULINIA
# Column 'DATA DO CONTRATO' has different types:
#   - object: in sheets Alphaville, BH, SJC
#   - datetime64[ns]: in sheets PAULINIA, CAMPINAS
# Column 'VALOR PAGAMENTO FACTORING' has different types:
#   - float64: in sheets Alphaville
#   - object: in sheets BH, SJC, PAULINIA, CAMPINAS
# Column 'DATA DA LIGAÇÃO' has different types:
#   - datetime64[ns]: in sheets Alphaville, SJC, PAULINIA, CAMPINAS
#   - int64: in sheets BH
# Column 'DATA DE VENCIMENTO' has different types:
#   - datetime64[ns]: in sheets Alphaville, SJC, CAMPINAS
#   - float64: in sheets BH
#   - object: in sheets PAULINIA
# Column 'DATA EMISSÃO NF' has different types:
#   - datetime64[ns]: in sheets Alphaville, SJC, PAULINIA, CAMPINAS
#   - int64: in sheets BH

# %%
# Standardize and clean the datasets across all sheets
# 1. Create a mapping for column name standardization
# 2. Standardize data types
# 3. Consolidate all data into a single clean dataset

# Define standard column names mapping
# This will standardize names across sheets and fix inconsistencies
column_mapping = {
    # Contract and client info
    'Nº CONTRATO (SISTEMA GERA)': 'CONTRATO_ID',
    'Nº CONTRATO (SISTEMA GERA)2': 'CONTRATO_ID',
    'CÓD CLIENTE': 'CLIENTE_ID',
    'PACIENTYES': 'PACIENTE_NOME',
    'PACIENTE 2': 'PACIENTE_NOME',
    'CLIENTES': 'PACIENTE_NOME',
    'DATA DO CONTRATO': 'DATA_CONTRATO',
    
    # Location and operational info
    'UNIDADE': 'UNIDADE',
    'OPERADORA': 'OPERADORA',
    'STATUS': 'STATUS',
    
    # Financial data
    ' NF': 'NF',
    'VALOR': 'VALOR_BRUTO',
    'VALOR_NUMERIC': 'VALOR',
    'VALOR FINANCIADO': 'VALOR_FINANCIADO',
    'VALOR PAGAMENTO CLÍNICA': 'VALOR_PAGAMENTO_CLINICA',
    'VALOR PAGO': 'VALOR_PAGO',
    'VALOR GLOSADO': 'VALOR_GLOSADO',
    'VALOR PAGAMENTO FACTORING': 'VALOR_PAGAMENTO_FACTORING',
    'CONTAS A RECEBER': 'CONTAS_A_RECEBER',
    
    # Date information
    'DATA EMISSÃO NF': 'DATA_EMISSAO_NF',
    'COMPETÊNCIA': 'COMPETENCIA',
    'DATA FINANCIAMENTO': 'DATA_FINANCIAMENTO',
    'DATA PAGAMENTO CLÍNICA': 'DATA_PAGAMENTO_CLINICA',
    'DATA PROTOCOLO': 'DATA_PROTOCOLO',
    'DATA PROTOCOLO ': 'DATA_PROTOCOLO',
    'DATA DE VENCIMENTO': 'DATA_VENCIMENTO',
    'DATA DO PAGAMENTO REEMBOLSO': 'DATA_PAGAMENTO_REEMBOLSO',
    'DATA DO PAGAMENTO FACTORING': 'DATA_PAGAMENTO_FACTORING',
    'DATA DA LIGAÇÃO': 'DATA_LIGACAO',
    'DATA DA RECLAMAÇÃO': 'DATA_RECLAMACAO',
    'DATA DA NIP': 'DATA_NIP',
    
    # Sessions and service information
    'Nº SESSÕES': 'NUM_SESSOES',
    'QUINZENA': 'QUINZENA',
    
    # Status fields
    'STATUS PRÉVIO DA CONTA': 'STATUS_PREVIO_CONTA',
    'STATUS ANÁLISE DE CRÉDITO': 'STATUS_ANALISE_CREDITO',
    'STATUS JURÍDICO CLIENTE': 'STATUS_JURIDICO_CLIENTE',
    'STATUS CONTAS A RECEBER': 'STATUS_CONTAS_RECEBER',
    'STATUS FINAL DA CONTA': 'STATUS_FINAL_CONTA',
    
    # Other fields
    'SOLICITANTE': 'SOLICITANTE',
    'CONTRATO ASSINADO': 'CONTRATO_ASSINADO',
    'FINANCIADO': 'FINANCIADO',
    'PAGAMENTO CLINICA': 'PAGAMENTO_CLINICA',
    'TRANSMISSÃO DA CONTA': 'TRANSMISSAO_CONTA',
    'LIGAÇÃO': 'LIGACAO',
    'RECLAMAÇÃO CHAT': 'RECLAMACAO_CHAT',
    'NIP': 'NIP',
    'ETAPAS DA JUDICILIAZAÇÃO': 'ETAPAS_JUDICIALIZACAO',
    'OBSERVAÇÕES': 'OBSERVACOES',
    '1ª APROVAÇÃO CLÍNICA GARANTIDORA': 'APROVACAO_CLINICA_GARANTIDORA',
    '2ª APROVAÇÃO FACTORING': 'APROVACAO_FACTORING',
    'USUÁRIO': 'USUARIO'
}

# Function to standardize column names
def standardize_column_names(df):
    # Rename columns based on mapping
    df_cols = df.columns.tolist()
    rename_dict = {}
    
    for col in df_cols:
        if col in column_mapping:
            rename_dict[col] = column_mapping[col]
    
    return df.rename(columns=rename_dict)

# Function to standardize data types
def standardize_data_types(df):
    # Date columns to convert - some may not exist in all sheets
    date_columns = [
        'DATA_EMISSAO_NF', 'COMPETENCIA', 'DATA_FINANCIAMENTO', 
        'DATA_PAGAMENTO_CLINICA', 'DATA_PROTOCOLO', 'DATA_VENCIMENTO',
        'DATA_PAGAMENTO_REEMBOLSO', 'DATA_PAGAMENTO_FACTORING',
        'DATA_LIGACAO', 'DATA_RECLAMACAO', 'DATA_NIP', 'DATA_CONTRATO'
    ]
    
    # Numeric columns to convert
    numeric_columns = [
        'VALOR', 'VALOR_FINANCIADO', 'VALOR_PAGAMENTO_CLINICA', 
        'VALOR_PAGO', 'VALOR_GLOSADO', 'VALOR_PAGAMENTO_FACTORING', 
        'CONTAS_A_RECEBER', 'NF', 'NUM_SESSOES', 'QUINZENA'
    ]
    
    # Convert date columns to datetime
    for col in date_columns:
        if col in df.columns:
            try:
                # Handle different date formats
                df[col] = pd.to_datetime(df[col], errors='coerce')
                
                # Handle very old dates (likely errors)
                # Replace dates before 2000 with NaT
                if df[col].dt.year.min() < 2000:
                    df.loc[df[col].dt.year < 2000, col] = pd.NaT
            except:
                print(f"Could not convert {col} to datetime in current dataframe")
    
    # Convert numeric columns to float
    for col in numeric_columns:
        if col in df.columns:
            # If the column already has numeric values, keep them
            if pd.api.types.is_numeric_dtype(df[col]):
                continue
                
            try:
                # If not already numeric, try to convert to numeric
                if col == 'VALOR' and 'VALOR_BRUTO' in df.columns:
                    # Use the already converted VALOR_NUMERIC values
                    pass
                else:
                    df[col] = pd.to_numeric(df[col], errors='coerce')
            except:
                print(f"Could not convert {col} to numeric in current dataframe")
    
    # Convert ID columns to string to ensure consistent handling
    id_columns = ['CONTRATO_ID', 'CLIENTE_ID', 'NF']
    for col in id_columns:
        if col in df.columns:
            df[col] = df[col].astype(str)
    
    return df

# Function to standardize categorical values
def standardize_categorical_values(df):
    # Standardize UNIDADE values
    if 'UNIDADE' in df.columns:
        # Standardize case and remove extra spaces
        df['UNIDADE'] = df['UNIDADE'].str.strip().str.upper()
        
        # Map variations to standard names
        unit_mapping = {
            'ALPHA': 'ALPHAVILLE',
            'alpha': 'ALPHAVILLE',
            'BELO HORIZONTE': 'BH',
            'BSB': 'BRASILIA',
            'SJC': 'SAO JOSE DOS CAMPOS'
        }
        
        df['UNIDADE'] = df['UNIDADE'].replace(unit_mapping)
    
    # Standardize STATUS values
    if 'STATUS' in df.columns:
        df['STATUS'] = df['STATUS'].str.strip().str.upper()
    
    return df

# Function to add source sheet information
def add_sheet_info(df, sheet_name):
    df['FONTE_PLANILHA'] = sheet_name
    return df

# Process all location sheets and combine into a single dataframe
location_sheets = ['Alphaville', 'BH', 'SJC', 'PAULINIA', 'CAMPINAS']
all_data = []

for sheet in location_sheets:
    if sheet in dfs:
        print(f"Standardizing {sheet} sheet...")
        
        # Make a copy to avoid modifying original data
        df = dfs[sheet].copy()
        
        # Apply standardization steps
        df = standardize_column_names(df)
        df = standardize_data_types(df)
        df = standardize_categorical_values(df)
        df = add_sheet_info(df, sheet)
        
        # Append to list for later concatenation
        all_data.append(df)
        
        print(f"  Processed {df.shape[0]} rows with {df.shape[1]} columns")

# Combine all data into a single dataframe
if all_data:
    combined_df = pd.concat(all_data, ignore_index=True)
    
    # Final cleanup
    # 1. Remove duplicate rows
    initial_rows = combined_df.shape[0]
    combined_df = combined_df.drop_duplicates()
    duplicate_rows = initial_rows - combined_df.shape[0]
    
    # 2. Check if client IDs are consistent
    if 'CLIENTE_ID' in combined_df.columns and 'PACIENTE_NOME' in combined_df.columns:
        client_id_mapping = combined_df.groupby('CLIENTE_ID')['PACIENTE_NOME'].nunique()
        inconsistent_ids = client_id_mapping[client_id_mapping > 1]
        
        if not inconsistent_ids.empty:
            print("\nInconsistent client IDs (multiple names for the same ID):")
            for client_id in inconsistent_ids.index:
                print(f"  Client ID {client_id} has {inconsistent_ids[client_id]} different names:")
                names = combined_df[combined_df['CLIENTE_ID'] == client_id]['PACIENTE_NOME'].unique()
                for name in names:
                    print(f"    - {name}")
    
    # Summary of standardized data
    print("\n=== STANDARDIZED DATA SUMMARY ===")
    print(f"Total records: {combined_df.shape[0]}")
    print(f"Duplicate rows removed: {duplicate_rows}")
    print(f"Final columns: {combined_df.shape[1]}")
    print(f"Column names: {combined_df.columns.tolist()}")
    
    # Check for remaining missing values
    missing_values = combined_df.isnull().sum()
    significant_missing = missing_values[missing_values > combined_df.shape[0] * 0.2]  # More than 20% missing
    if not significant_missing.empty:
        print("\nColumns with significant missing values (>20%):")
        for col, count in significant_missing.items():
            print(f"  {col}: {count} missing values ({count/combined_df.shape[0]:.1%})")
    
    # Save the standardized data to CSV
    output_path = '/data/chats/igk4wd/workspace/processed_data.csv'
    combined_df.to_csv(output_path, index=False)
    print(f"\nStandardized data saved to {output_path}")
    
    # Basic portfolio analysis
    print("\n=== PORTFOLIO ANALYSIS ===")
    if 'UNIDADE' in combined_df.columns:
        unit_counts = combined_df['UNIDADE'].value_counts()
        print("Records by operating unit:")
        for unit, count in unit_counts.items():
            print(f"  {unit}: {count} records")
    
    if 'VALOR' in combined_df.columns:
        # Filter out extreme values for analysis
        value_df = combined_df[combined_df['VALOR'] < combined_df['VALOR'].quantile(0.99)]
        
        print("\nFinancial summary by unit:")
        for unit in combined_df['UNIDADE'].unique():
            unit_data = value_df[value_df['UNIDADE'] == unit]
            if not unit_data.empty and 'VALOR' in unit_data.columns:
                total = unit_data['VALOR'].sum()
                mean = unit_data['VALOR'].mean()
                count = unit_data['VALOR'].count()
                print(f"  {unit}: {count} transactions, Total: R$ {total:,.2f}, Average: R$ {mean:,.2f}")
else:
    print("No data to standardize!")
# Out:
# Standardizing Alphaville sheet...
#   Processed 1651 rows with 47 columns
# Standardizing BH sheet...
#   Processed 814 rows with 47 columns
# Standardizing SJC sheet...
#   Processed 2587 rows with 47 columns
# Standardizing PAULINIA sheet...
#   Processed 251 rows with 47 columns
# Standardizing CAMPINAS sheet...
#   Processed 194 rows with 46 columns
#
# Inconsistent client IDs (multiple names for the same ID):
#   Client ID 10 has 2 different names:
#     - PEDRO SILVA
#     - Miguel Oliveira Costa
#   Client ID 100 has 3 different names:
#     - PEDRO SILVA
#     - JOANA MARIA-1ª HM
#     - RUBENS FERREIRA-matmed
#   Client ID 1000 has 4 different names:
#     - Miguel costa
#     - Roberto Amorin-único
#     - Roberto Amorin-1ª HM
#     - Felipe Cardoso Nunes
#   Client ID 1001 has 2 different names:
#     - Roberto Amorin-1ª matmed
#     - Julio Freitas-1ª
#   Client ID 1004 has 2 different names:
#     - Roberto Amorin-1ª HM
#     - Julio Freitas-2º
#   Client ID 1008 has 2 different names:
#     - Roberto Amorin-0
#     - Julio Freitas-1ª HM
#   Client ID 1010 has 2 different names:
#     - Miguel costa
#     - Felipe Cardoso Nunes
#   Client ID 1012 has 2 different names:
#     - Roberto Amorin-1ª HM
#     - Julio Freitas-2º
#   Client ID 1016 has 2 different names:
#     - Roberto Amorin-0
#     - Julio Freitas-2º
#   Client ID 1020 has 3 different names:
#     - Miguel costa
#     - Julio Freitas-2º
#     - Felipe Cardoso Nunes
#   Client ID 1024 has 2 different names:
#     - Roberto Amorin-0
#     - Julio Freitas-2º
#   Client ID 1030 has 2 different names:
#     - Miguel costa
#     - Felipe Cardoso Nunes
#   Client ID 10300 has 2 different names:
#     - Amanda Lopes Ribeiro
#     - LaUrA nUnES rIbEirO
#   Client ID 10310 has 2 different names:
#     - Amanda Lopes Ribeiro
#     - LaUrA nUnES rIbEirO
#   Client ID 1032 has 2 different names:
#     - Roberto Amorin-0
#     - Julio Freitas-2º
#   Client ID 10320 has 2 different names:
#     - Amanda Lopes Ribeiro
#     - LaUrA nUnES rIbEirO
#   Client ID 10330 has 2 different names:
#     - Amanda Lopes Ribeiro
#     - LaUrA nUnES rIbEirO
#   Client ID 10340 has 2 different names:
#     - Amanda Lopes Ribeiro
#     - LaUrA nUnES rIbEirO
#   Client ID 10350 has 2 different names:
#     - Amanda Lopes Ribeiro
#     - LaUrA nUnES rIbEirO
#   Client ID 10360 has 2 different names:
#     - Amanda Lopes Ribeiro
#     - LaUrA nUnES rIbEirO
#   Client ID 10370 has 2 different names:
#     - Amanda Lopes Ribeiro
#     - LaUrA nUnES rIbEirO
#   Client ID 10380 has 2 different names:
#     - Amanda Lopes Ribeiro
#     - LaUrA nUnES rIbEirO
#   Client ID 104 has 2 different names:
#     - JOÃO GUIMARAES-único
#     - RUBENS FERREIRA-hdf
#   Client ID 1040 has 4 different names:
#     - Miguel costa
#     - Roberto Amorin-0
#     - Julio Freitas-2º
#     - Felipe Cardoso Nunes
#   Client ID 1041 has 2 different names:
#     - Julio Freitas-1ª
#     - Julio Freitas-único - hm
#   Client ID 1048 has 2 different names:
#     - Roberto Amorin-0
#     - Julio Freitas-2º
#   Client ID 105 has 4 different names:
#     - RUBENS FERREIRA-dp
#     - nan
#     - MaRcElO nuNeS FeRreiRa Mat e Med
#     - MaRcElO nuNeS FeRreiRa MAT & MED
#     - diEgO cArDoSo nuNeS mat e MED
#   Client ID 1050 has 2 different names:
#     - Miguel costa
#     - Felipe Cardoso Nunes
#   Client ID 1052 has 2 different names:
#     - Julio Freitas-2º
#     - Julio Freitas-hdf
#   Client ID 1056 has 2 different names:
#     - Roberto Amorin-0
#     - Julio Freitas-matmed
#   Client ID 1057 has 2 different names:
#     - Julio Freitas-único - hm
#     - Julio Freitas-1º
#   Client ID 1060 has 4 different names:
#     - Miguel costa
#     - Julio Freitas-hdf
#     - Julio Freitas-matmed
#     - Felipe Cardoso Nunes
#   Client ID 1064 has 2 different names:
#     - Julio Freitas-1ª
#     - Julio Freitas-hdf
#   Client ID 1065 has 2 different names:
#     - Julio Freitas-dp
#     - Julio Freitas-1º
#   Client ID 1068 has 2 different names:
#     - Julio Freitas-matmed
#     - Julio Freitas-1ª
#   Client ID 1070 has 2 different names:
#     - Miguel costa
#     - Felipe Cardoso Nunes
#   Client ID 1072 has 2 different names:
#     - Julio Freitas-1ª
#     - Julio Freitas-matmed
#   Client ID 1076 has 2 different names:
#     - Julio Freitas-hdf
#     - Julio Freitas-1ª
#   Client ID 10790 has 2 different names:
#     - Amanda Lopes Ribeiro
#     - LaUrA nUnES rIbEirO
#   Client ID 108 has 3 different names:
#     - JOANA MARIA-2º
#     - RUBENS FERREIRA-hdf
#     - Miguel Oliveira Costa
#   Client ID 1080 has 2 different names:
#     - Isabela lima
#     - Julio Freitas-1ª
#   Client ID 10800 has 2 different names:
#     - Amanda Lopes Ribeiro
#     - LaUrA nUnES rIbEirO
#   Client ID 10810 has 2 different names:
#     - Amanda Lopes Ribeiro
#     - LaUrA nUnES rIbEirO
#   Client ID 10820 has 2 different names:
#     - Amanda Lopes Ribeiro
#     - LaUrA nUnES rIbEirO
#   Client ID 10830 has 2 different names:
#     - Amanda Lopes Ribeiro
#     - LaUrA nUnES rIbEirO
#   Client ID 10840 has 2 different names:
#     - Amanda Lopes Ribeiro
#     - LaUrA nUnES rIbEirO
#   Client ID 10850 has 2 different names:
#     - Amanda Lopes Ribeiro
#     - LaUrA nUnES rIbEirO
#   Client ID 10860 has 2 different names:
#     - Amanda Lopes Ribeiro
#     - LaUrA nUnES rIbEirO
#   Client ID 10870 has 2 different names:
#     - Amanda Lopes Ribeiro
#     - LaUrA nUnES rIbEirO
#   Client ID 1088 has 2 different names:
#     - Julio Freitas-1ª
#     - Eduardo Silva Ramos
#   Client ID 1092 has 2 different names:
#     - Julio Freitas-1º
#     - Julio Freitas-1ª
#   Client ID 1100 has 2 different names:
#     - Isabela lima
#     - Julio Freitas-1ª
#   Client ID 1104 has 2 different names:
#     - Julio Freitas-único - hm
#     - Julio Freitas-1ª
#   Client ID 1108 has 2 different names:
#     - Julio Freitas-1ª
#     - Felipe Cardoso Nunes
#   Client ID 1112 has 2 different names:
#     - Julio Freitas-dp
#     - Julio Freitas-1ª
#   Client ID 112 has 3 different names:
#     - JOÃO GUIMARAES-único
#     - RUBENS FERREIRA-matmed
#     - nan
#     - nICoLe FeRrEiRa mEnDeS Honorário Médico
#   Client ID 1120 has 3 different names:
#     - Isabela lima
#     - Julio Freitas-único - hm
#     - Julio Freitas-1ª
#   Client ID 1128 has 2 different names:
#     - Julio Freitas-1º
#     - Eduardo Silva Ramos
#   Client ID 11280 has 2 different names:
#     - Guilherme Souza Carvalho
#     - LaUrA nUnES rIbEirO
#   Client ID 11290 has 2 different names:
#     - Guilherme Souza Carvalho
#     - LaUrA nUnES rIbEirO
#   Client ID 113 has 2 different names:
#     - RUBENS FERREIRA-único - hm
#     - MARCOS PAULO-1º
#   Client ID 11300 has 2 different names:
#     - Guilherme Souza Carvalho
#     - LaUrA nUnES rIbEirO
#   Client ID 11310 has 2 different names:
#     - Guilherme Souza Carvalho
#     - LaUrA nUnES rIbEirO
#   Client ID 11320 has 2 different names:
#     - Guilherme Souza Carvalho
#     - LaUrA nUnES rIbEirO
#   Client ID 11330 has 2 different names:
#     - Guilherme Souza Carvalho
#     - LaUrA nUnES rIbEirO
#   Client ID 11340 has 2 different names:
#     - Guilherme Souza Carvalho
#     - LaUrA nUnES rIbEirO
#   Client ID 11350 has 2 different names:
#     - Guilherme Souza Carvalho
#     - LaUrA nUnES rIbEirO
#   Client ID 11360 has 2 different names:
#     - Guilherme Souza Carvalho
#     - LaUrA nUnES rIbEirO
#   Client ID 115 has 3 different names:
#     - nan
#     - diEgO cArDoSo nuNeS Mat e Med
#     - diEgO cArDoSo nuNeS HONORÁRIO MÉDICO
#     - VINÍCIUS CASTRO MENDES
#   Client ID 116 has 2 different names:
#     - RUBENS FERREIRA-hdf
#     - RUBENS FERREIRA-matmed
#   Client ID 1160 has 2 different names:
#     - Isabela lima
#     - Julio Freitas-1º
#   Client ID 1168 has 2 different names:
#     - Julio Freitas-1º
#     - Eduardo Silva Ramos
#   Client ID 11770 has 2 different names:
#     - Guilherme Souza Carvalho
#     - LaUrA nUnES rIbEirO
#   Client ID 11780 has 2 different names:
#     - Guilherme Souza Carvalho
#     - LaUrA nUnES rIbEirO
#   Client ID 11790 has 2 different names:
#     - Guilherme Souza Carvalho
#     - LaUrA nUnES rIbEirO
#   Client ID 11800 has 2 different names:
#     - Guilherme Souza Carvalho
#     - LaUrA nUnES rIbEirO
#   Client ID 11810 has 2 different names:
#     - Guilherme Souza Carvalho
#     - LaUrA nUnES rIbEirO
#   Client ID 11820 has 2 different names:
#     - Guilherme Souza Carvalho
#     - LaUrA nUnES rIbEirO
#   Client ID 11830 has 2 different names:
#     - Guilherme Souza Carvalho
#     - LaUrA nUnES rIbEirO
#   Client ID 11840 has 2 different names:
#     - Guilherme Souza Carvalho
#     - LaUrA nUnES rIbEirO
#   Client ID 11850 has 2 different names:
#     - Guilherme Souza Carvalho
#     - LaUrA nUnES rIbEirO
#   Client ID 120 has 3 different names:
#     - PEDRO SILVA
#     - JOÃO GUIMARAES-matmed
#     - RUBENS FERREIRA-hdf
#   Client ID 121 has 2 different names:
#     - RUBENS FERREIRA-dp
#     - MARCOS PAULO-MAT MED
#   Client ID 12260 has 2 different names:
#     - Guilherme Souza Carvalho
#     - roDrIgO lOpEs olIvEiRa
#   Client ID 12270 has 2 different names:
#     - Guilherme Souza Carvalho
#     - roDrIgO lOpEs olIvEiRa
#   Client ID 12280 has 2 different names:
#     - Daniel Teixeira Costa
#     - roDrIgO lOpEs olIvEiRa
#   Client ID 12290 has 2 different names:
#     - Daniel Teixeira Costa
#     - roDrIgO lOpEs olIvEiRa
#   Client ID 12300 has 2 different names:
#     - Daniel Teixeira Costa
#     - roDrIgO lOpEs olIvEiRa
#   Client ID 12310 has 2 different names:
#     - Daniel Teixeira Costa
#     - roDrIgO lOpEs olIvEiRa
#   Client ID 12320 has 2 different names:
#     - Daniel Teixeira Costa
#     - roDrIgO lOpEs olIvEiRa
#   Client ID 12330 has 2 different names:
#     - Daniel Teixeira Costa
#     - roDrIgO lOpEs olIvEiRa
#   Client ID 12340 has 2 different names:
#     - Daniel Teixeira Costa
#     - roDrIgO lOpEs olIvEiRa
#   Client ID 124 has 2 different names:
#     - RUBENS FERREIRA-matmed
#     - MARCOS PAULO-1ª
#   Client ID 125 has 3 different names:
#     - nan
#     - VINÍCIUS CASTRO MENDES HONORÁRIO MÉDICO
#     - VINÍCIUS CASTRO MENDES
#     - nICoLe FeRrEiRa mEnDeS
#   Client ID 12750 has 2 different names:
#     - Daniel Teixeira Costa
#     - roDrIgO lOpEs olIvEiRa
#   Client ID 12760 has 2 different names:
#     - Daniel Teixeira Costa
#     - roDrIgO lOpEs olIvEiRa
#   Client ID 12770 has 2 different names:
#     - Daniel Teixeira Costa
#     - roDrIgO lOpEs olIvEiRa
#   Client ID 12780 has 2 different names:
#     - Daniel Teixeira Costa
#     - roDrIgO lOpEs olIvEiRa
#   Client ID 12790 has 2 different names:
#     - Daniel Teixeira Costa
#     - roDrIgO lOpEs olIvEiRa
#   Client ID 128 has 3 different names:
#     - JOANA MARIA-1ª matmed
#     - RUBENS FERREIRA-matmed
#     - Miguel Oliveira Costa
#   Client ID 12800 has 2 different names:
#     - Daniel Teixeira Costa
#     - roDrIgO lOpEs olIvEiRa
#   Client ID 12810 has 2 different names:
#     - Daniel Teixeira Costa
#     - roDrIgO lOpEs olIvEiRa
#   Client ID 12820 has 2 different names:
#     - Daniel Teixeira Costa
#     - roDrIgO lOpEs olIvEiRa
#   Client ID 12830 has 2 different names:
#     - Daniel Teixeira Costa
#     - roDrIgO lOpEs olIvEiRa
#   Client ID 132 has 3 different names:
#     - RUBENS FERREIRA-hdf
#     - MARCOS PAULO-1ª
#     - nan
#     - nICoLe FeRrEiRa mEnDeS
#   Client ID 13240 has 2 different names:
#     - Daniel Teixeira Costa
#     - roDrIgO lOpEs olIvEiRa
#   Client ID 13250 has 2 different names:
#     - Daniel Teixeira Costa
#     - roDrIgO lOpEs olIvEiRa
#   Client ID 13260 has 2 different names:
#     - Daniel Teixeira Costa
#     - roDrIgO lOpEs olIvEiRa
#   Client ID 13270 has 2 different names:
#     - Daniel Teixeira Costa
#     - roDrIgO lOpEs olIvEiRa
#   Client ID 13280 has 2 different names:
#     - Daniel Teixeira Costa
#     - roDrIgO lOpEs olIvEiRa
#   Client ID 13290 has 2 different names:
#     - Daniel Teixeira Costa
#     - roDrIgO lOpEs olIvEiRa
#   Client ID 13300 has 2 different names:
#     - Daniel Teixeira Costa
#     - roDrIgO lOpEs olIvEiRa
#   Client ID 13310 has 2 different names:
#     - Daniel Teixeira Costa
#     - roDrIgO lOpEs olIvEiRa
#   Client ID 13320 has 2 different names:
#     - Daniel Teixeira Costa
#     - roDrIgO lOpEs olIvEiRa
#   Client ID 135 has 3 different names:
#     - nan
#     - DANIELA MENDES SOUZA
#     - nICoLe FeRrEiRa mEnDeS
#     - nICoLe FeRrEiRa mEnDeS Honorário Médico
#   Client ID 136 has 2 different names:
#     - JOANA MARIA-1ª
#     - MARCOS PAULO-1ª
#   Client ID 137 has 2 different names:
#     - MARCOS PAULO-MAT MED
#     - nan
#     - MaRcElO nuNeS FeRreiRa HONORÁRIO MEDICO
#   Client ID 13730 has 2 different names:
#     - Daniel Teixeira Costa
#     - roDrIgO lOpEs olIvEiRa
#   Client ID 13740 has 2 different names:
#     - Daniel Teixeira Costa
#     - roDrIgO lOpEs olIvEiRa
#   Client ID 13750 has 2 different names:
#     - Daniel Teixeira Costa
#     - roDrIgO lOpEs olIvEiRa
#   Client ID 13760 has 2 different names:
#     - Daniel Teixeira Costa
#     - roDrIgO lOpEs olIvEiRa
#   Client ID 13770 has 2 different names:
#     - Daniel Teixeira Costa
#     - roDrIgO lOpEs olIvEiRa
#   Client ID 13780 has 2 different names:
#     - Daniel Teixeira Costa
#     - roDrIgO lOpEs olIvEiRa
#   Client ID 13790 has 2 different names:
#     - Daniel Teixeira Costa
#     - roDrIgO lOpEs olIvEiRa
#   Client ID 13800 has 2 different names:
#     - Daniel Teixeira Costa
#     - roDrIgO lOpEs olIvEiRa
#   Client ID 13810 has 2 different names:
#     - Daniel Teixeira Costa
#     - roDrIgO lOpEs olIvEiRa
#   Client ID 140 has 2 different names:
#     - PEDRO SILVA
#     - MARCOS PAULO-1ª
#   Client ID 14220 has 2 different names:
#     - JULIA FERNANDES
#     - pAuLa AlMeIdA lOpEs
#   Client ID 14230 has 2 different names:
#     - JULIA FERNANDES
#     - pAuLa AlMeIdA lOpEs
#   Client ID 14240 has 2 different names:
#     - JULIA FERNANDES
#     - pAuLa AlMeIdA lOpEs
#   Client ID 14250 has 2 different names:
#     - Miguel Oliveira Costa
#     - pAuLa AlMeIdA lOpEs
#   Client ID 14260 has 2 different names:
#     - Miguel Oliveira Costa
#     - pAuLa AlMeIdA lOpEs
#   Client ID 14270 has 2 different names:
#     - Miguel Oliveira Costa
#     - pAuLa AlMeIdA lOpEs
#   Client ID 14280 has 2 different names:
#     - Miguel Oliveira Costa
#     - pAuLa AlMeIdA lOpEs
#   Client ID 14290 has 2 different names:
#     - Miguel Oliveira
#     - pAuLa AlMeIdA lOpEs
#   Client ID 14300 has 2 different names:
#     - Miguel Oliveira Costa
#     - pAuLa AlMeIdA lOpEs
#   Client ID 144 has 2 different names:
#     - JOANA MARIA-1ª matmed
#     - MARCOS PAULO-1ª
#   Client ID 145 has 5 different names:
#     - MARCOS PAULO-MAT MED
#     - MARCOS PAULO-mat med
#     - nan
#     - nICoLe FeRrEiRa mEnDeS
#     - MaRcElO nuNeS FeRreiRa Mat e Med
#     - MaRcElO nuNeS FeRreiRa HONORÁRIO MÉDICO
#   Client ID 14710 has 2 different names:
#     - Miguel Oliveira
#     - pAuLa AlMeIdA lOpEs
#   Client ID 14720 has 2 different names:
#     - Miguel Oliveira
#     - pAuLa AlMeIdA lOpEs
#   Client ID 14730 has 2 different names:
#     - Miguel Oliveira
#     - pAuLa AlMeIdA lOpEs
#   Client ID 14740 has 2 different names:
#     - Miguel Oliveira
#     - pAuLa AlMeIdA lOpEs
#   Client ID 14750 has 2 different names:
#     - Miguel Oliveira
#     - pAuLa AlMeIdA lOpEs
#   Client ID 14760 has 2 different names:
#     - Miguel Oliveira
#     - pAuLa AlMeIdA lOpEs
#   Client ID 14770 has 2 different names:
#     - Miguel Oliveira
#     - pAuLa AlMeIdA lOpEs
#   Client ID 14780 has 2 different names:
#     - Miguel Oliveira
#     - pAuLa AlMeIdA lOpEs
#   Client ID 14790 has 2 different names:
#     - Miguel Oliveira
#     - pAuLa AlMeIdA lOpEs
#   Client ID 148 has 2 different names:
#     - MARCOS PAULO-1ª
#     - Miguel Oliveira Costa
#   Client ID 1480 has 2 different names:
#     - Thiago souza
#     - Felipe Cardoso Nunes
#   Client ID 1490 has 2 different names:
#     - Thiago souza
#     - Felipe Cardoso Nunes
#   Client ID 1500 has 2 different names:
#     - Thiago souza
#     - Felipe Cardoso Nunes
#   Client ID 1510 has 2 different names:
#     - Thiago souza
#     - Felipe Cardoso Nunes
#   Client ID 152 has 3 different names:
#     - JOANA MARIA-1ª
#     - MARCOS PAULO-1ª
#     - nan
#     - nICoLe FeRrEiRa mEnDeS
#   Client ID 1520 has 2 different names:
#     - Thiago souza
#     - Felipe Cardoso Nunes
#   Client ID 15200 has 2 different names:
#     - felipe cardoso
#     - pAuLa AlMeIdA lOpEs
#   Client ID 15210 has 2 different names:
#     - felipe cardoso
#     - pAuLa AlMeIdA lOpEs
#   Client ID 15220 has 2 different names:
#     - Felipe Cardoso Nunes
#     - pAuLa AlMeIdA lOpEs
#   Client ID 15230 has 2 different names:
#     - Felipe Cardoso Nunes
#     - pAuLa AlMeIdA lOpEs
#   Client ID 15240 has 2 different names:
#     - Felipe Cardoso Nunes
#     - pAuLa AlMeIdA lOpEs
#   Client ID 15250 has 2 different names:
#     - Felipe Cardoso Nunes
#     - pAuLa AlMeIdA lOpEs
#   Client ID 15260 has 2 different names:
#     - felipe cardoso
#     - pAuLa AlMeIdA lOpEs
#   Client ID 15270 has 2 different names:
#     - felipe cardoso
#     - pAuLa AlMeIdA lOpEs
#   Client ID 15280 has 2 different names:
#     - felipe cardoso
#     - pAuLa AlMeIdA lOpEs
#   Client ID 153 has 2 different names:
#     - MARCOS PAULO-MAT MED
#     - MARCOS PAULO-único
#   Client ID 1530 has 2 different names:
#     - Larissa pereira
#     - Felipe Cardoso Nunes
#   Client ID 1540 has 2 different names:
#     - Larissa pereira
#     - Felipe Cardoso Nunes
#   Client ID 155 has 3 different names:
#     - nan
#     - MaRcElO nuNeS FeRreiRa mat e MED
#     - MaRcElO nuNeS FeRreiRa
#     - diEgO cArDoSo nuNeS mat e MED
#   Client ID 1550 has 2 different names:
#     - Larissa pereira
#     - Felipe Cardoso Nunes
#   Client ID 156 has 2 different names:
#     - MARCOS PAULO-1ª
#     - MARCOS PAULO-único
#   Client ID 1560 has 2 different names:
#     - Larissa pereira
#     - Eduardo Silva Ramos
#   Client ID 15690 has 2 different names:
#     - felipe cardoso
#     - pAuLa AlMeIdA lOpEs
#   Client ID 15700 has 2 different names:
#     - felipe cardoso
#     - pAuLa AlMeIdA lOpEs
#   Client ID 15710 has 2 different names:
#     - Eduardo Silva Ramos
#     - pAuLa AlMeIdA lOpEs
#   Client ID 15720 has 2 different names:
#     - Eduardo Silva Ramos
#     - pAuLa AlMeIdA lOpEs
#   Client ID 15730 has 2 different names:
#     - Eduardo Silva Ramos
#     - pAuLa AlMeIdA lOpEs
#   Client ID 15740 has 2 different names:
#     - Eduardo Silva Ramos
#     - pAuLa AlMeIdA lOpEs
#   Client ID 15750 has 2 different names:
#     - Eduardo Silva Ramos
#     - pAuLa AlMeIdA lOpEs
#   Client ID 15760 has 2 different names:
#     - Eduardo Silva Ramos
#     - pAuLa AlMeIdA lOpEs
#   Client ID 15770 has 2 different names:
#     - Eduardo Silva Ramos
#     - pAuLa AlMeIdA lOpEs
#   Client ID 160 has 3 different names:
#     - PEDRO SILVA
#     - RUBENS FERREIRA-único - hm
#     - MARCOS PAULO-MAT MED
#   Client ID 16180 has 2 different names:
#     - Eduardo Silva
#     - pAuLa AlMeIdA lOpEs
#   Client ID 16190 has 2 different names:
#     - Eduardo Silva
#     - pAuLa AlMeIdA lOpEs
#   Client ID 16200 has 2 different names:
#     - Eduardo Silva
#     - pAuLa AlMeIdA lOpEs
#   Client ID 16210 has 2 different names:
#     - Eduardo Silva
#     - pAuLa AlMeIdA lOpEs
#   Client ID 16220 has 2 different names:
#     - Eduardo Silva
#     - pAuLa AlMeIdA lOpEs
#   Client ID 16230 has 2 different names:
#     - Eduardo Silva
#     - pAuLa AlMeIdA lOpEs
#   Client ID 16240 has 2 different names:
#     - Eduardo Silva
#     - pAuLa AlMeIdA lOpEs
#   Client ID 16250 has 2 different names:
#     - Eduardo Silva
#     - pAuLa AlMeIdA lOpEs
#   Client ID 16260 has 2 different names:
#     - Eduardo Silva
#     - pAuLa AlMeIdA lOpEs
#   Client ID 164 has 2 different names:
#     - MARCOS PAULO-1ª
#     - MARCOS PAULO-MAT MED
#   Client ID 165 has 3 different names:
#     - nan
#     - diEgO cArDoSo nuNeS Mat e Med
#     - diEgO cArDoSo nuNeS HONORÁRIO MÉDICO
#     - VINÍCIUS CASTRO MENDES
#   Client ID 168 has 3 different names:
#     - RUBENS FERREIRA-dp
#     - MARCOS PAULO-único
#     - Miguel Oliveira Costa
#   Client ID 169 has 2 different names:
#     - MARCOS PAULO-único
#     - SANTOS FILHO-0
#   Client ID 172 has 3 different names:
#     - MARCOS PAULO-MAT MED
#     - MARCOS PAULO-único
#     - nan
#     - diEgO cArDoSo nuNeS HONORÁRIO MEDICO
#   Client ID 175 has 3 different names:
#     - nan
#     - VINÍCIUS CASTRO MENDES HONORÁRIO MÉDICO
#     - VINÍCIUS CASTRO MENDES
#     - Joana Reis
#   Client ID 176 has 2 different names:
#     - RUBENS FERREIRA-único - hm
#     - MARCOS PAULO-MAT MED
#   Client ID 177 has 2 different names:
#     - SANTOS FILHO-0
#     - nan
#     - MaRcElO nuNeS FeRreiRa MAT & MED
#   Client ID 180 has 3 different names:
#     - PEDRO SILVA
#     - MARCOS PAULO-único
#     - SANTOS FILHO-matmed
#   Client ID 184 has 2 different names:
#     - MARCOS PAULO-MAT MED
#     - SANTOS FILHO-matmed
#   Client ID 185 has 3 different names:
#     - SANTOS FILHO-0
#     - nan
#     - Joana Reis
#     - nICoLe FeRrEiRa mEnDeS
#   Client ID 188 has 2 different names:
#     - SANTOS FILHO-matmed
#     - Miguel Oliveira Costa
#   Client ID 192 has 3 different names:
#     - MARCOS PAULO-MAT MED
#     - SANTOS FILHO-matmed
#     - nan
#     - Joana Reis
#   Client ID 195 has 2 different names:
#     - nan
#     - nICoLe FeRrEiRa mEnDeS
#     - MaRcElO nuNeS FeRreiRa Mat e Med
#   Client ID 1970 has 2 different names:
#     - Felipe nunes
#     - Eduardo Silva Ramos
#   Client ID 1980 has 2 different names:
#     - Felipe nunes
#     - Eduardo Silva Ramos
#   Client ID 1990 has 2 different names:
#     - Felipe nunes
#     - Eduardo Silva Ramos
#   Client ID 20 has 2 different names:
#     - PEDRO SILVA
#     - Miguel Oliveira Costa
#   Client ID 200 has 3 different names:
#     - PEDRO SILVA
#     - MARCOS PAULO-MAT MED
#     - SANTOS FILHO-matmed
#   Client ID 2000 has 2 different names:
#     - Felipe nunes
#     - PeDrO HenRiqUe SiLvA
#   Client ID 201 has 2 different names:
#     - SANTOS FILHO-0
#     - SANTOS FILHO-1ª matmed
#   Client ID 2010 has 2 different names:
#     - Felipe nunes
#     - Eduardo Silva Ramos
#   Client ID 2020 has 2 different names:
#     - Felipe nunes
#     - Eduardo Silva Ramos
#   Client ID 2030 has 2 different names:
#     - Felipe nunes
#     - Eduardo Silva Ramos
#   Client ID 204 has 2 different names:
#     - SANTOS FILHO-matmed
#     - SANTOS FILHO-1ª HM
#   Client ID 2040 has 2 different names:
#     - Felipe nunes
#     - PeDrO HenRiqUe SiLvA
#   Client ID 205 has 3 different names:
#     - nan
#     - MaRcElO nuNeS FeRreiRa MAT & MED
#     - MaRcElO nuNeS FeRreiRa mat e MED
#     - diEgO cArDoSo nuNeS HONORÁRIO MEDICO
#   Client ID 2050 has 2 different names:
#     - Felipe nunes
#     - Eduardo Silva Ramos
#   Client ID 208 has 2 different names:
#     - MARCOS PAULO-MAT MED
#     - SANTOS FILHO-matmed
#   Client ID 209 has 2 different names:
#     - SANTOS FILHO-1ª HM
#     - SANTOS FILHO-1ª matmed
#   Client ID 212 has 3 different names:
#     - SANTOS FILHO-matmed
#     - SANTOS FILHO-1ª HM
#     - nan
#     - MaRcElO nuNeS FeRreiRa Mat & Med
#   Client ID 215 has 3 different names:
#     - nan
#     - MaRcElO nuNeS FeRreiRa
#     - diEgO cArDoSo nuNeS Mat e Med
#     - nICoLe FeRrEiRa mEnDeS
#   Client ID 216 has 3 different names:
#     - MARCOS PAULO-único
#     - SANTOS FILHO-1ª HM
#     - Miguel Oliveira Costa
#   Client ID 217 has 3 different names:
#     - SANTOS FILHO-1ª matmed
#     - JORGE MATHEUS-1ª
#     - nan
#     - nICoLe FeRrEiRa mEnDeS
#   Client ID 220 has 2 different names:
#     - PEDRO SILVA
#     - SANTOS FILHO-1ª HM
#   Client ID 224 has 2 different names:
#     - MARCOS PAULO-mat med
#     - SANTOS FILHO-1ª HM
#   Client ID 225 has 4 different names:
#     - JORGE MATHEUS-1ª
#     - nan
#     - ANDRÉ TEIXEIRA SOUZA Mat e Med
#     - VINÍCIUS CASTRO MENDES HONORÁRIO MÉDICO
#     - Joana Reis
#   Client ID 228 has 2 different names:
#     - SANTOS FILHO-1ª HM
#     - JORGE MATHEUS-2º
#   Client ID 232 has 3 different names:
#     - MARCOS PAULO-único
#     - JORGE MATHEUS-2º
#     - nan
#     - nICoLe FeRrEiRa mEnDeS
#   Client ID 235 has 3 different names:
#     - nan
#     - DANIELA MENDES SOUZA
#     - Joana Reis
#     - nICoLe FeRrEiRa mEnDeS
#   Client ID 236 has 2 different names:
#     - JORGE MATHEUS-2º
#     - Miguel Oliveira Costa
#   Client ID 240 has 3 different names:
#     - PEDRO SILVA
#     - SANTOS FILHO-0
#     - JORGE MATHEUS-2º
#   Client ID 245 has 3 different names:
#     - nan
#     - Julia Guimarães Honorário Médico
#     - nICoLe FeRrEiRa mEnDeS
#     - nICoLe FeRrEiRa mEnDeS Honorário Médico
#   Client ID 2460 has 2 different names:
#     - Eduardo ramos
#     - PeDrO HenRiqUe SiLvA
#   Client ID 2470 has 2 different names:
#     - Eduardo ramos
#     - PeDrO HenRiqUe SiLvA
#   Client ID 248 has 2 different names:
#     - SANTOS FILHO-0
#     - JORGE MATHEUS-2º
#   Client ID 2480 has 2 different names:
#     - Eduardo ramos
#     - PeDrO HenRiqUe SiLvA
#   Client ID 2490 has 2 different names:
#     - Eduardo ramos
#     - PeDrO HenRiqUe SiLvA
#   Client ID 25 has 2 different names:
#     - JOÃO GUIMARAES-único
#     - nan
#     - ANDRÉ TEIXEIRA SOUZA Honorário Médico
#   Client ID 2500 has 2 different names:
#     - Eduardo ramos
#     - PeDrO HenRiqUe SiLvA
#   Client ID 2510 has 2 different names:
#     - Eduardo ramos
#     - PeDrO HenRiqUe SiLvA
#   Client ID 252 has 2 different names:
#     - JORGE MATHEUS-2º
#     - nan
#     - Joana Reis
#   Client ID 2520 has 2 different names:
#     - Eduardo ramos
#     - miGuEL oLiVeIrA coStA
#   Client ID 2530 has 2 different names:
#     - Eduardo ramos
#     - miGuEL oLiVeIrA coStA
#   Client ID 2540 has 2 different names:
#     - Eduardo ramos
#     - miGuEL oLiVeIrA coStA
#   Client ID 255 has 3 different names:
#     - nan
#     - nICoLe FeRrEiRa mEnDeS
#     - MaRcElO nuNeS FeRreiRa Mat e Med
#     - MaRcElO nuNeS FeRreiRa HONORÁRIO MÉDICO
#   Client ID 256 has 3 different names:
#     - SANTOS FILHO-0
#     - JORGE MATHEUS-2º
#     - Miguel Oliveira Costa
#   Client ID 257 has 3 different names:
#     - JORGE MATHEUS-1ª
#     - JORGE MATHEUS-dp
#     - nan
#     - VINÍCIUS CASTRO MENDES
#   Client ID 260 has 2 different names:
#     - PEDRO SILVA
#     - JORGE MATHEUS-2º
#   Client ID 264 has 2 different names:
#     - SANTOS FILHO-1ª HM
#     - JORGE MATHEUS-2º
#   Client ID 265 has 4 different names:
#     - JORGE MATHEUS-único - hm
#     - nan
#     - MaRcElO nuNeS FeRreiRa mat e MED
#     - MaRcElO nuNeS FeRreiRa
#     - Julia Guimarães Mat e Med
#   Client ID 268 has 2 different names:
#     - JORGE MATHEUS-2º
#     - JORGE MATHEUS-matmed
#   Client ID 272 has 3 different names:
#     - SANTOS FILHO-1ª matmed
#     - JORGE MATHEUS-hdf
#     - nan
#     - MaRcElO nuNeS FeRreiRa Mat e Med
#   Client ID 275 has 3 different names:
#     - nan
#     - diEgO cArDoSo nuNeS Mat e Med
#     - diEgO cArDoSo nuNeS mat e MED
#     - VINÍCIUS CASTRO MENDES HONORÁRIO MÉDICO
#   Client ID 276 has 3 different names:
#     - JORGE MATHEUS-2º
#     - JORGE MATHEUS-hdf
#     - Miguel Oliveira Costa
#   Client ID 280 has 3 different names:
#     - PEDRO SILVA
#     - JORGE MATHEUS-1ª
#     - JORGE MATHEUS-matmed
#   Client ID 281 has 2 different names:
#     - JORGE MATHEUS-único - hm
#     - CARLOS REIS-1º
#   Client ID 284 has 2 different names:
#     - JORGE MATHEUS-hdf
#     - JORGE MATHEUS-matmed
#   Client ID 285 has 3 different names:
#     - nan
#     - nICoLe FeRrEiRa mEnDeS
#     - VINÍCIUS CASTRO MENDES
#     - Joana Reis
#   Client ID 288 has 2 different names:
#     - JORGE MATHEUS-1ª
#     - JORGE MATHEUS-hdf
#   Client ID 289 has 2 different names:
#     - CARLOS REIS-1º
#     - CARLOS REIS-MAT MED
#   Client ID 292 has 3 different names:
#     - JORGE MATHEUS-matmed
#     - CARLOS REIS-1ª
#     - nan
#     - ANDRÉ TEIXEIRA SOUZA Mat e Med
#   Client ID 295 has 2 different names:
#     - nan
#     - Joana Reis
#     - nICoLe FeRrEiRa mEnDeS
#   Client ID 2950 has 2 different names:
#     - Renata mendes
#     - miGuEL oLiVeIrA coStA
#   Client ID 296 has 2 different names:
#     - JORGE MATHEUS-1ª
#     - CARLOS REIS-1º
#   Client ID 2960 has 2 different names:
#     - Renata mendes
#     - miGuEL oLiVeIrA coStA
#   Client ID 297 has 2 different names:
#     - CARLOS REIS-MAT MED
#     - nan
#     - MaRcElO nuNeS FeRreiRa
#   Client ID 2970 has 2 different names:
#     - Renata mendes
#     - miGuEL oLiVeIrA coStA
#   Client ID 2980 has 2 different names:
#     - Renata mendes
#     - miGuEL oLiVeIrA coStA
#   Client ID 2990 has 2 different names:
#     - Renata mendes
#     - miGuEL oLiVeIrA coStA
#   Client ID 30 has 2 different names:
#     - PEDRO SILVA
#     - Miguel Oliveira Costa
#   Client ID 300 has 3 different names:
#     - PEDRO SILVA
#     - CARLOS REIS-1º
#     - CARLOS REIS-MAT MED
#   Client ID 3000 has 2 different names:
#     - Renata mendes
#     - miGuEL oLiVeIrA coStA
#   Client ID 3010 has 2 different names:
#     - Renata mendes
#     - miGuEL oLiVeIrA coStA
#   Client ID 3020 has 2 different names:
#     - Renata mendes
#     - miGuEL oLiVeIrA coStA
#   Client ID 3030 has 2 different names:
#     - Renata mendes
#     - miGuEL oLiVeIrA coStA
#   Client ID 304 has 3 different names:
#     - JORGE MATHEUS-1ª
#     - CARLOS REIS-MAT MED
#     - Miguel Oliveira Costa
#   Client ID 305 has 3 different names:
#     - CARLOS REIS-MAT MED
#     - nan
#     - nICoLe FeRrEiRa mEnDeS
#     - MaRcElO nuNeS FeRreiRa Mat e Med
#   Client ID 312 has 3 different names:
#     - JORGE MATHEUS-1ª
#     - CARLOS REIS-MAT MED
#     - nan
#     - Julia Guimarães Honorário Médico
#   Client ID 313 has 2 different names:
#     - CARLOS REIS-MAT MED
#     - CARLOS REIS-mat med
#   Client ID 315 has 3 different names:
#     - nan
#     - nICoLe FeRrEiRa mEnDeS Honorário Médico
#     - MaRcElO nuNeS FeRreiRa Mat & Med
#     - MaRcElO nuNeS FeRreiRa
#   Client ID 320 has 3 different names:
#     - PEDRO SILVA
#     - JORGE MATHEUS-1ª
#     - CARLOS REIS-MAT MED
#   Client ID 321 has 2 different names:
#     - CARLOS REIS-MAT MED
#     - CARLOS REIS-mat med
#   Client ID 324 has 3 different names:
#     - CARLOS REIS-MAT MED
#     - CARLOS REIS-único
#     - Miguel Oliveira Costa
#   Client ID 325 has 3 different names:
#     - nan
#     - MaRcElO nuNeS FeRreiRa HONORÁRIO MÉDICO
#     - MaRcElO nuNeS FeRreiRa
#     - diEgO cArDoSo nuNeS mat e MED
#   Client ID 328 has 2 different names:
#     - JORGE MATHEUS-único - hm
#     - CARLOS REIS-MAT MED
#   Client ID 329 has 2 different names:
#     - CARLOS REIS-mat med
#     - CRISTINA LAGES-1ª matmed
#   Client ID 332 has 3 different names:
#     - CARLOS REIS-MAT MED
#     - MARILIA GOMES-matmed
#     - nan
#     - MaRcElO nuNeS FeRreiRa mat e MED
#   Client ID 335 has 3 different names:
#     - nan
#     - Julia Guimarães Mat e Med
#     - diEgO cArDoSo nuNeS HONORÁRIO MÉDICO
#     - VINÍCIUS CASTRO MENDES
#   Client ID 336 has 2 different names:
#     - JORGE MATHEUS-dp
#     - CARLOS REIS-mat med
#   Client ID 337 has 2 different names:
#     - CRISTINA LAGES-1ª matmed
#     - nan
#     - nICoLe FeRrEiRa mEnDeS
#   Client ID 340 has 3 different names:
#     - PEDRO SILVA
#     - CARLOS REIS-mat med
#     - CRISTINA LAGES-1ª HM
#   Client ID 344 has 3 different names:
#     - CARLOS REIS-1º
#     - CRISTINA LAGES-1ª HM
#     - Miguel Oliveira Costa
#   Client ID 3440 has 2 different names:
#     - Bruno alves
#     - rENAtA cARvALHo mENdEs
#   Client ID 345 has 5 different names:
#     - CRISTINA LAGES-1ª matmed
#     - CRISTINA LAGES-único - hm
#     - nan
#     - VINÍCIUS CASTRO MENDES HONORÁRIO MÉDICO
#     - VINÍCIUS CASTRO MENDES
#     - Joana Reis
#   Client ID 3450 has 2 different names:
#     - Bruno alves
#     - rENAtA cARvALHo mENdEs
#   Client ID 3460 has 2 different names:
#     - Bruno alves
#     - rENAtA cARvALHo mENdEs
#   Client ID 3470 has 2 different names:
#     - Bruno alves
#     - rENAtA cARvALHo mENdEs
#   Client ID 3480 has 2 different names:
#     - Bruno alves
#     - rENAtA cARvALHo mENdEs
#   Client ID 3490 has 2 different names:
#     - Bruno alves
#     - rENAtA cARvALHo mENdEs
#   Client ID 35 has 2 different names:
#     - nan
#     - ANDRÉ TEIXEIRA SOUZA Mat e Med
#     - VINÍCIUS CASTRO MENDES mat e MED
#   Client ID 3500 has 2 different names:
#     - Bruno alves
#     - rENAtA cARvALHo mENdEs
#   Client ID 3510 has 2 different names:
#     - Bruno alves
#     - rENAtA cARvALHo mENdEs
#   Client ID 352 has 3 different names:
#     - CARLOS REIS-MAT MED
#     - CRISTINA LAGES-1ª HM
#     - nan
#     - nICoLe FeRrEiRa mEnDeS
#   Client ID 3520 has 2 different names:
#     - Bruno alves
#     - rENAtA cARvALHo mENdEs
#   Client ID 360 has 3 different names:
#     - Ana oliveira
#     - CARLOS REIS-MAT MED
#     - CRISTINA LAGES-2º
#   Client ID 364 has 3 different names:
#     - CRISTINA LAGES-1ª HM
#     - CRISTINA LAGES-2º
#     - Miguel Oliveira Costa
#   Client ID 368 has 2 different names:
#     - CARLOS REIS-MAT MED
#     - CRISTINA LAGES-1ª HM
#   Client ID 369 has 2 different names:
#     - CRISTINA LAGES-1ª
#     - PEREIRA GOMES-1º
#   Client ID 372 has 2 different names:
#     - CRISTINA LAGES-2º
#     - ELISANGELA PATO-hdf
#     - nan
#   Client ID 376 has 2 different names:
#     - CARLOS REIS-MAT MED
#     - CRISTINA LAGES-2º
#   Client ID 377 has 3 different names:
#     - ELISANGELA PATO-dp
#     - PEREIRA GOMES-1º
#     - nan
#     - DANIELA MENDES SOUZA
#   Client ID 380 has 3 different names:
#     - Ana oliveira
#     - CRISTINA LAGES-1ª HM
#     - PEREIRA GOMES-1ª
#   Client ID 384 has 3 different names:
#     - CARLOS REIS-único
#     - ELISANGELA PATO-matmed
#     - Miguel Oliveira Costa
#   Client ID 388 has 2 different names:
#     - ELISANGELA PATO-hdf
#     - PEREIRA GOMES-1ª
#   Client ID 392 has 2 different names:
#     - CRISTINA LAGES-0
#     - PEREIRA GOMES-1ª
#     - nan
#   Client ID 393 has 2 different names:
#     - PEREIRA GOMES-1º
#     - PEREIRA GOMES-MAT MED
#   Client ID 3930 has 2 different names:
#     - Lucas rodrigues
#     - rENAtA cARvALHo mENdEs
#   Client ID 3940 has 2 different names:
#     - Lucas rodrigues
#     - rENAtA cARvALHo mENdEs
#   Client ID 3950 has 2 different names:
#     - Lucas rodrigues
#     - rENAtA cARvALHo mENdEs
#   Client ID 3960 has 2 different names:
#     - Lucas rodrigues
#     - rENAtA cARvALHo mENdEs
#   Client ID 3970 has 2 different names:
#     - Lucas rodrigues
#     - rENAtA cARvALHo mENdEs
#   Client ID 3980 has 2 different names:
#     - Lucas rodrigues
#     - rENAtA cARvALHo mENdEs
#   Client ID 3990 has 2 different names:
#     - Lucas rodrigues
#     - rENAtA cARvALHo mENdEs
#   Client ID 40 has 2 different names:
#     - PEDRO SILVA
#     - Miguel Oliveira Costa
#   Client ID 400 has 3 different names:
#     - Ana oliveira
#     - CRISTINA LAGES-1ª matmed
#     - PEREIRA GOMES-1ª
#   Client ID 4000 has 2 different names:
#     - Lucas rodrigues
#     - rENAtA cARvALHo mENdEs
#   Client ID 4010 has 2 different names:
#     - Camila silva
#     - rENAtA cARvALHo mENdEs
#   Client ID 408 has 2 different names:
#     - CRISTINA LAGES-1ª matmed
#     - PEREIRA GOMES-1ª
#   Client ID 412 has 2 different names:
#     - PEREIRA GOMES-1ª
#     - Miguel Oliveira Costa
#     - nan
#   Client ID 416 has 2 different names:
#     - CRISTINA LAGES-1ª
#     - PEREIRA GOMES-1ª
#   Client ID 420 has 2 different names:
#     - Ana oliveira
#     - PEREIRA GOMES-1ª
#   Client ID 424 has 2 different names:
#     - CRISTINA LAGES-único - hm
#     - PEREIRA GOMES-1ª
#   Client ID 428 has 2 different names:
#     - PEREIRA GOMES-1ª
#     - PEREIRA GOMES-mat med
#   Client ID 432 has 3 different names:
#     - ELISANGELA PATO-dp
#     - PEREIRA GOMES-único
#     - Miguel Oliveira Costa
#     - nan
#   Client ID 433 has 2 different names:
#     - PEREIRA GOMES-MAT MED
#     - ELIANA DANTAS-matmed
#   Client ID 436 has 2 different names:
#     - PEREIRA GOMES-mat med
#     - PEREIRA GOMES-único
#   Client ID 440 has 3 different names:
#     - Ana oliveira
#     - PEREIRA GOMES-1º
#     - PEREIRA GOMES-mat med
#   Client ID 441 has 2 different names:
#     - PEREIRA GOMES-único
#     - ELIANA DANTAS-matmed
#   Client ID 4420 has 2 different names:
#     - Gabriel Souza Lima
#     - rENAtA cARvALHo mENdEs
#   Client ID 4430 has 2 different names:
#     - Gabriel Souza Lima
#     - rENAtA cARvALHo mENdEs
#   Client ID 444 has 2 different names:
#     - PEREIRA GOMES-único
#     - ELIANA DANTAS-matmed
#   Client ID 4440 has 2 different names:
#     - Gabriel Souza Lima
#     - rENAtA cARvALHo mENdEs
#   Client ID 4450 has 2 different names:
#     - Gabriel Souza Lima
#     - rENAtA cARvALHo mENdEs
#   Client ID 4460 has 2 different names:
#     - Gabriel Souza Lima
#     - rENAtA cARvALHo mENdEs
#   Client ID 4470 has 2 different names:
#     - Gabriel Souza Lima
#     - rENAtA cARvALHo mENdEs
#   Client ID 448 has 2 different names:
#     - PEREIRA GOMES-1º
#     - PEREIRA GOMES-único
#   Client ID 4480 has 2 different names:
#     - Gabriel Souza Lima
#     - rENAtA cARvALHo mENdEs
#   Client ID 4490 has 2 different names:
#     - Gabriel Souza Lima
#     - rENAtA cARvALHo mENdEs
#   Client ID 45 has 3 different names:
#     - nan
#     - ANDRÉ TEIXEIRA SOUZA Mat e Med
#     - VINÍCIUS CASTRO MENDES HONORÁRIO MÉDICO
#     - DANIELA MENDES SOUZA
#   Client ID 4500 has 2 different names:
#     - Gabriel Souza Lima
#     - rENAtA cARvALHo mENdEs
#   Client ID 452 has 3 different names:
#     - PEREIRA GOMES-mat med
#     - ELIANA DANTAS-matmed
#     - Miguel Oliveira Costa
#     - nan
#   Client ID 456 has 2 different names:
#     - PEREIRA GOMES-1º
#     - ELIANA DANTAS-matmed
#   Client ID 460 has 2 different names:
#     - Ana oliveira
#     - ELIANA DANTAS-matmed
#   Client ID 464 has 2 different names:
#     - PEREIRA GOMES-MAT MED
#     - ELIANA DANTAS-matmed
#   Client ID 465 has 2 different names:
#     - ELIANA DANTAS-matmed
#     - FRED ENRICO-1ª matmed
#   Client ID 472 has 3 different names:
#     - PEREIRA GOMES-MAT MED
#     - ELIANA DANTAS-matmed
#     - Miguel Oliveira Costa
#   Client ID 473 has 2 different names:
#     - FRED ENRICO-0
#     - FRED ENRICO-1ª matmed
#   Client ID 476 has 2 different names:
#     - ELIANA DANTAS-matmed
#     - FRED ENRICO-1ª HM
#   Client ID 480 has 3 different names:
#     - Ana oliveira
#     - PEREIRA GOMES-MAT MED
#     - FRED ENRICO-1ª HM
#   Client ID 481 has 2 different names:
#     - FRED ENRICO-1ª HM
#     - FRED ENRICO-1ª
#   Client ID 484 has 2 different names:
#     - FRED ENRICO-0
#     - FRED ENRICO-1ª HM
#   Client ID 488 has 2 different names:
#     - PEREIRA GOMES-único
#     - FRED ENRICO-1ª HM
#   Client ID 49 has 2 different names:
#     - JOÃO GUIMARAES-único
#     - JOÃO GUIMARAES-matmed
#   Client ID 4910 has 2 different names:
#     - Gabriel Souza Lima
#     - rENAtA cARvALHo mENdEs
#   Client ID 492 has 2 different names:
#     - FRED ENRICO-1ª matmed
#     - FRED ENRICO-2º
#   Client ID 4920 has 2 different names:
#     - Gabriel Souza Lima
#     - Paula Almeida Lopes
#   Client ID 4930 has 2 different names:
#     - Gabriel Souza Lima
#     - rENAtA cARvALHo mENdEs
#   Client ID 4940 has 2 different names:
#     - Gabriel Souza Lima
#     - rENAtA cARvALHo mENdEs
#   Client ID 4950 has 2 different names:
#     - Gabriel Souza Lima
#     - rENAtA cARvALHo mENdEs
#   Client ID 496 has 2 different names:
#     - PEREIRA GOMES-MAT MED
#     - FRED ENRICO-1ª HM
#   Client ID 4960 has 2 different names:
#     - Gabriel Souza Lima
#     - Paula Almeida Lopes
#   Client ID 497 has 2 different names:
#     - FRED ENRICO-1ª
#     - JORGE LUIS-dp
#   Client ID 4970 has 2 different names:
#     - Gabriel Souza Lima
#     - rENAtA cARvALHo mENdEs
#   Client ID 4980 has 2 different names:
#     - Gabriel Souza Lima
#     - rENAtA cARvALHo mENdEs
#   Client ID 4990 has 2 different names:
#     - Gabriel Souza Lima
#     - rENAtA cARvALHo mENdEs
#   Client ID 50 has 2 different names:
#     - PEDRO SILVA
#     - Miguel Oliveira Costa
#   Client ID 500 has 4 different names:
#     - Ana oliveira
#     - FRED ENRICO-2º
#     - FRED ENRICO-1ª HM
#     - Miguel Oliveira Costa
#   Client ID 504 has 2 different names:
#     - ELIANA DANTAS-matmed
#     - FRED ENRICO-2º
#   Client ID 505 has 2 different names:
#     - FRED ENRICO-único - hm
#     - JORGE LUIS-1º
#   Client ID 508 has 2 different names:
#     - FRED ENRICO-1ª HM
#     - JORGE LUIS-matmed
#   Client ID 510 has 2 different names:
#     - Ana oliveira
#     - Miguel Oliveira Costa
#   Client ID 512 has 2 different names:
#     - ELIANA DANTAS-matmed
#     - JORGE LUIS-hdf
#   Client ID 513 has 2 different names:
#     - JORGE LUIS-dp
#     - paulo braga-mat med
#   Client ID 516 has 2 different names:
#     - FRED ENRICO-2º
#     - MARIA SANTOS-1ª
#   Client ID 52 has 2 different names:
#     - JOÃO GUIMARAES-único
#     - nan
#     - ANDRÉ TEIXEIRA SOUZA HONORÁRIO MEDICO
#   Client ID 520 has 4 different names:
#     - Ana oliveira
#     - ELIANA DANTAS-matmed
#     - JORGE LUIS-matmed
#     - Miguel Oliveira Costa
#   Client ID 521 has 2 different names:
#     - LEONARDO REEIS-MAT MED
#     - paulo braga-único
#   Client ID 524 has 2 different names:
#     - JORGE LUIS-hdf
#     - paulo braga-único
#   Client ID 528 has 2 different names:
#     - FRED ENRICO-0
#     - LEONARDO REEIS-MAT MED
#   Client ID 529 has 2 different names:
#     - paulo braga-único
#     - paulo braga-1ª HM
#   Client ID 530 has 2 different names:
#     - Ana oliveira
#     - Miguel Oliveira Costa
#   Client ID 532 has 2 different names:
#     - LEONARDO REEIS-MAT MED
#     - paulo braga-matmed
#   Client ID 536 has 2 different names:
#     - FRED ENRICO-1ª matmed
#     - paulo braga-matmed
#   Client ID 540 has 4 different names:
#     - Ana oliveira
#     - paulo braga-único
#     - paulo braga-matmed
#     - Miguel Oliveira Costa
#   Client ID 5400 has 2 different names:
#     - Gabriel Souza Lima
#     - rENAtA cARvALHo mENdEs
#   Client ID 5410 has 2 different names:
#     - Gabriel Souza Lima
#     - rENAtA cARvALHo mENdEs
#   Client ID 5420 has 2 different names:
#     - Gabriel Souza Lima
#     - rENAtA cARvALHo mENdEs
#   Client ID 5430 has 2 different names:
#     - Gabriel Souza Lima
#     - rENAtA cARvALHo mENdEs
#   Client ID 544 has 2 different names:
#     - FRED ENRICO-1ª
#     - paulo braga-0
#   Client ID 5440 has 2 different names:
#     - Gabriel Souza Lima
#     - Paula Almeida Lopes
#   Client ID 5450 has 2 different names:
#     - Gabriel Souza Lima
#     - Paula Almeida Lopes
#   Client ID 5460 has 2 different names:
#     - Gabriel Souza Lima
#     - Paula Almeida Lopes
#   Client ID 5470 has 2 different names:
#     - Gabriel Souza Lima
#     - Paula Almeida Lopes
#   Client ID 5480 has 2 different names:
#     - Gabriel Souza Lima
#     - Paula Almeida Lopes
#   Client ID 55 has 2 different names:
#     - nan
#     - DANIELA MENDES SOUZA
#     - diEgO cArDoSo nuNeS Mat & Med
#   Client ID 550 has 2 different names:
#     - Ana oliveira
#     - Miguel Oliveira Costa
#   Client ID 552 has 2 different names:
#     - FRED ENRICO-único - hm
#     - paulo braga-0
#   Client ID 553 has 2 different names:
#     - paulo braga-1ª HM
#     - paulo braga-1ª matmed
#   Client ID 560 has 4 different names:
#     - Ana oliveira
#     - FRED ENRICO-1ª
#     - paulo braga-0
#     - Miguel Oliveira Costa
#   Client ID 561 has 2 different names:
#     - paulo braga-1ª HM
#     - paulo braga-1ª
#   Client ID 564 has 2 different names:
#     - paulo braga-0
#     - paulo braga-1ª HM
#   Client ID 568 has 2 different names:
#     - JORGE LUIS-1º
#     - paulo braga-0
#   Client ID 57 has 2 different names:
#     - JOÃO GUIMARAES-único
#     - JOANA MARIA-1ª HM
#   Client ID 570 has 2 different names:
#     - Ana oliveira
#     - Miguel Oliveira Costa
#   Client ID 572 has 2 different names:
#     - paulo braga-0
#     - paulo braga-2º
#   Client ID 576 has 2 different names:
#     - MARIA SANTOS-1ª
#     - paulo braga-1ª HM
#   Client ID 577 has 2 different names:
#     - paulo braga-1ª
#     - luise fagundes-único - hm
#   Client ID 580 has 4 different names:
#     - Ana oliveira
#     - paulo braga-2º
#     - paulo braga-1ª HM
#     - Miguel Oliveira Costa
#   Client ID 584 has 2 different names:
#     - paulo braga-mat med
#     - paulo braga-2º
#   Client ID 588 has 2 different names:
#     - paulo braga-1ª HM
#     - luise fagundes-hdf
#   Client ID 5890 has 2 different names:
#     - Gabriel Souza Lima
#     - Paula Almeida Lopes
#   Client ID 5900 has 2 different names:
#     - Gabriel Souza Lima
#     - Paula Almeida Lopes
#   Client ID 5910 has 2 different names:
#     - Gabriel Souza Lima
#     - Paula Almeida Lopes
#   Client ID 592 has 2 different names:
#     - paulo braga-único
#     - luise fagundes-hdf
#   Client ID 5920 has 2 different names:
#     - Gabriel Souza Lima
#     - Paula Almeida Lopes
#   Client ID 593 has 2 different names:
#     - luise fagundes-único - hm
#     - jorge santiago-1ª
#   Client ID 5930 has 2 different names:
#     - Gabriel Souza Lima
#     - Paula Almeida Lopes
#   Client ID 5940 has 2 different names:
#     - Gabriel Souza Lima
#     - Paula Almeida Lopes
#   Client ID 5950 has 2 different names:
#     - Gabriel Souza Lima
#     - Paula Almeida Lopes
#   Client ID 596 has 2 different names:
#     - paulo braga-2º
#     - jorge santiago-dp
#   Client ID 5960 has 2 different names:
#     - Gabriel Souza Lima
#     - Paula Almeida Lopes
#   Client ID 5970 has 2 different names:
#     - Gabriel Souza Lima
#     - Paula Almeida Lopes
#   Client ID 60 has 3 different names:
#     - PEDRO SILVA
#     - JOÃO GUIMARAES-único
#     - Miguel Oliveira Costa
#   Client ID 600 has 3 different names:
#     - Ana oliveira
#     - paulo braga-1ª HM
#     - luise fagundes-hdf
#   Client ID 601 has 2 different names:
#     - jorge santiago-matmed
#     - jorge santiago-1ª
#   Client ID 604 has 2 different names:
#     - luise fagundes-hdf
#     - jorge santiago-MAT MED
#   Client ID 608 has 3 different names:
#     - paulo braga-1ª HM
#     - jorge santiago-1º
#     - Miguel Oliveira Costa
#   Client ID 609 has 2 different names:
#     - jorge santiago-1ª
#     - jorge santiago-MAT MED
#   Client ID 612 has 2 different names:
#     - jorge santiago-dp
#     - jorge santiago-MAT MED
#   Client ID 616 has 2 different names:
#     - paulo braga-1ª HM
#     - jorge santiago-MAT MED
#   Client ID 617 has 2 different names:
#     - jorge santiago-1ª
#     - jorge santiago-único
#   Client ID 620 has 3 different names:
#     - Ana oliveira
#     - jorge santiago-MAT MED
#     - jorge santiago-mat med
#   Client ID 624 has 2 different names:
#     - paulo braga-1ª
#     - jorge santiago-MAT MED
#   Client ID 628 has 3 different names:
#     - jorge santiago-MAT MED
#     - jorge santiago-único
#     - Miguel Oliveira Costa
#   Client ID 632 has 2 different names:
#     - paulo braga-1ª matmed
#     - jorge santiago-mat med
#   Client ID 633 has 2 different names:
#     - jorge santiago-único
#     - rena paulino-1ª HM
#   Client ID 636 has 2 different names:
#     - jorge santiago-único
#     - jorge santiago-mat med
#   Client ID 6380 has 2 different names:
#     - Laura Lopes Nunes
#     - Paula Almeida Lopes
#   Client ID 6390 has 2 different names:
#     - Laura Lopes Nunes
#     - Paula Almeida Lopes
#   Client ID 640 has 3 different names:
#     - Júlia santos
#     - paulo braga-1ª
#     - jorge santiago-único
#   Client ID 6400 has 2 different names:
#     - Laura Lopes Nunes
#     - Paula Almeida Lopes
#   Client ID 6410 has 2 different names:
#     - Laura Lopes Nunes
#     - Paula Almeida Lopes
#   Client ID 6420 has 2 different names:
#     - Laura Lopes Nunes
#     - Paula Almeida Lopes
#   Client ID 6430 has 2 different names:
#     - Laura Lopes Nunes
#     - Paula Almeida Lopes
#   Client ID 644 has 2 different names:
#     - jorge santiago-mat med
#     - rena paulino-1ª matmed
#   Client ID 6440 has 2 different names:
#     - Rafael Teixeira Oliveira
#     - Paula Almeida Lopes
#   Client ID 6450 has 2 different names:
#     - Rafael Teixeira Oliveira
#     - Paula Almeida Lopes
#   Client ID 6460 has 2 different names:
#     - Rafael Teixeira Oliveira
#     - Paula Almeida Lopes
#   Client ID 648 has 3 different names:
#     - luise fagundes-único - hm
#     - rena paulino-0
#     - Miguel Oliveira Costa
#   Client ID 65 has 5 different names:
#     - JOÃO GUIMARAES-matmed
#     - JOANA MARIA-1ª matmed
#     - nan
#     - diEgO cArDoSo nuNeS Mat e Med
#     - ANDRÉ TEIXEIRA SOUZA Honorário Médico
#     - nICoLe FeRrEiRa mEnDeS
#   Client ID 652 has 2 different names:
#     - jorge santiago-único
#     - rena paulino-0
#   Client ID 656 has 2 different names:
#     - jorge santiago-matmed
#     - rena paulino-1ª matmed
#   Client ID 657 has 2 different names:
#     - rena paulino-matmed
#     - joney frios-1ª HM
#   Client ID 660 has 3 different names:
#     - Júlia santos
#     - rena paulino-0
#     - rena paulino-1ª matmed
#   Client ID 664 has 2 different names:
#     - jorge santiago-1ª
#     - rena paulino-0
#   Client ID 665 has 2 different names:
#     - rena paulino-1ª HM
#     - joney frios-1ª HM
#   Client ID 668 has 3 different names:
#     - rena paulino-1ª matmed
#     - joney frios-1ª
#     - Miguel Oliveira Costa
#   Client ID 672 has 2 different names:
#     - jorge santiago-1ª
#     - rena paulino-1ª matmed
#   Client ID 676 has 2 different names:
#     - rena paulino-0
#     - joney frios-1ª
#   Client ID 68 has 2 different names:
#     - JOÃO GUIMARAES-único
#     - JOANA MARIA-1ª HM
#   Client ID 680 has 3 different names:
#     - Júlia santos
#     - jorge santiago-único
#     - joney frios-1ª
#   Client ID 6870 has 2 different names:
#     - Rafael Teixeira Oliveira
#     - Marcelo Nunes Ferreira
#   Client ID 688 has 2 different names:
#     - jorge santiago-MAT MED
#     - joney frios-1ª
#   Client ID 6880 has 2 different names:
#     - Rafael Teixeira Oliveira
#     - Marcelo Nunes Ferreira
#   Client ID 6890 has 2 different names:
#     - Rafael Teixeira Oliveira
#     - Marcelo Nunes Ferreira
#   Client ID 6900 has 2 different names:
#     - Rafael Teixeira Oliveira
#     - Marcelo Nunes Ferreira
#   Client ID 6910 has 2 different names:
#     - Rafael Teixeira Oliveira
#     - Marcelo Nunes Ferreira
#   Client ID 6920 has 2 different names:
#     - Rafael Teixeira Oliveira
#     - Marcelo Nunes Ferreira
#   Client ID 6930 has 2 different names:
#     - Rafael Teixeira Oliveira
#     - Marcelo Nunes Ferreira
#   Client ID 6940 has 2 different names:
#     - Rafael Teixeira Oliveira
#     - Marcelo Nunes Ferreira
# ...
#   Client ID 7370 has 2 different names:
#     - Rafael Teixeira Oliveira
#     - Marcelo Nunes Ferreira
#   Client ID 7380 has 2 different names:
#     - Rafael Teixeira Oliveira
#     - Marcelo Nunes Ferreira
#   Client ID 7390 has 2 different names:
#     - Rafael Teixeira Oliveira
#     - Marcelo Nunes Ferreira
#   Client ID 740 has 3 different names:
#     - Miguel costa
#     - joney frios-único - hm
#     - josé araujo-MAT MED
#   Client ID 7400 has 2 different names:
#     - Rafael Teixeira Oliveira
#     - Marcelo Nunes Ferreira
#   Client ID 7410 has 2 different names:
#     - Rafael Teixeira Oliveira
#     - Marcelo Nunes Ferreira
#   Client ID 7420 has 2 different names:
#     - Rafael Teixeira Oliveira
#     - Marcelo Nunes Ferreira
#   Client ID 7430 has 2 different names:
#     - Rafael Teixeira Oliveira
#     - Marcelo Nunes Ferreira
#   Client ID 744 has 2 different names:
#     - joney frios-1ª HM
#     - josé araujo-1º
#   Client ID 7440 has 2 different names:
#     - Rafael Teixeira Oliveira
#     - Marcelo Nunes Ferreira
#   Client ID 745 has 2 different names:
#     - josé araujo-MAT MED
#     - josé araujo-0
#   Client ID 748 has 2 different names:
#     - josé araujo-1º
#     - josé araujo-mat med
#   Client ID 75 has 3 different names:
#     - nan
#     - diEgO cArDoSo nuNeS HONORÁRIO MÉDICO
#     - ANDRÉ TEIXEIRA SOUZA Mat e Med
#     - VINÍCIUS CASTRO MENDES
#   Client ID 752 has 2 different names:
#     - joney frios-1ª HM
#     - josé araujo-mat med
#   Client ID 756 has 3 different names:
#     - josé araujo-MAT MED
#     - josé araujo-1ª HM
#     - Miguel Oliveira Costa
#   Client ID 76 has 2 different names:
#     - JOÃO GUIMARAES-único
#     - JOANA MARIA-1ª HM
#   Client ID 760 has 3 different names:
#     - Miguel costa
#     - joney frios-1ª HM
#     - josé araujo-matmed
#   Client ID 764 has 2 different names:
#     - josé araujo-mat med
#     - josé araujo-matmed
#   Client ID 768 has 2 different names:
#     - joney frios-2º
#     - josé araujo-2º
#   Client ID 772 has 2 different names:
#     - josé araujo-1ª HM
#     - josé araujo-2º
#   Client ID 776 has 3 different names:
#     - joney frios-hdf
#     - josé araujo-único
#     - Felipe Cardoso Nunes
#   Client ID 777 has 2 different names:
#     - josé araujo-1ª
#     - Luana Mariana-único - hm
#   Client ID 780 has 3 different names:
#     - Miguel costa
#     - josé araujo-2º
#     - josé araujo-único
#   Client ID 784 has 2 different names:
#     - joney frios-2º
#     - josé araujo-2º
#   Client ID 785 has 2 different names:
#     - josé araujo-matmed
#     - Luana Mariana-único - hm
#   Client ID 7850 has 2 different names:
#     - Alice Nascimento Costa
#     - Marcelo Nunes Ferreira
#   Client ID 7860 has 2 different names:
#     - Alice Nascimento Costa
#     - Marcelo Nunes Ferreira
#   Client ID 7870 has 2 different names:
#     - Alice Nascimento Costa
#     - Marcelo Nunes Ferreira
#   Client ID 788 has 2 different names:
#     - josé araujo-único
#     - Luana Mariana-hdf
#   Client ID 7880 has 2 different names:
#     - Alice Nascimento Costa
#     - Gabriel Nunes Almeida
#   Client ID 7890 has 2 different names:
#     - Alice Nascimento Costa
#     - Marcelo Nunes Ferreira
#   Client ID 7900 has 2 different names:
#     - Alice Nascimento Costa
#     - Marcelo Nunes Ferreira
#   Client ID 7910 has 2 different names:
#     - Alice Nascimento Costa
#     - Marcelo Nunes Ferreira
#   Client ID 792 has 2 different names:
#     - josé araujo-matmed
#     - josé araujo-único
#   Client ID 7920 has 2 different names:
#     - Alice Nascimento Costa
#     - Gabriel Nunes Almeida
#   Client ID 793 has 2 different names:
#     - Luana Mariana-único - hm
#     - Luana Mariana-1º
#   Client ID 7930 has 2 different names:
#     - Alice Nascimento Costa
#     - Marcelo Nunes Ferreira
#   Client ID 796 has 2 different names:
#     - josé araujo-2º
#     - Luana Mariana-hdf
#   Client ID 80 has 3 different names:
#     - PEDRO SILVA
#     - JOANA MARIA-2º
#     - Miguel Oliveira Costa
#   Client ID 800 has 3 different names:
#     - Miguel costa
#     - josé araujo-MAT MED
#     - Luana Mariana-hdf
#   Client ID 801 has 2 different names:
#     - Luana Mariana-dp
#     - Luana Mariana-MAT MED
#   Client ID 804 has 3 different names:
#     - Luana Mariana-hdf
#     - Luana Mariana-matmed
#     - Felipe Cardoso Nunes
#   Client ID 808 has 2 different names:
#     - josé araujo-único
#     - Luana Mariana-matmed
#   Client ID 809 has 2 different names:
#     - Luana Mariana-1º
#     - Luana Mariana-mat med
#   Client ID 812 has 2 different names:
#     - Luana Mariana-hdf
#     - Luana Mariana-MAT MED
#   Client ID 816 has 2 different names:
#     - josé araujo-1ª matmed
#     - Luana Mariana-1ª
#   Client ID 817 has 2 different names:
#     - Luana Mariana-mat med
#     - Tatiana Prieto-único
#   Client ID 820 has 3 different names:
#     - Miguel costa
#     - Luana Mariana-matmed
#     - Luana Mariana-MAT MED
#   Client ID 824 has 3 different names:
#     - josé araujo-1ª
#     - Luana Mariana-MAT MED
#     - Felipe Cardoso Nunes
#   Client ID 825 has 2 different names:
#     - Luana Mariana-mat med
#     - Tatiana Prieto-0
#   Client ID 828 has 2 different names:
#     - Luana Mariana-MAT MED
#     - Tatiana Prieto-matmed
#   Client ID 832 has 2 different names:
#     - josé araujo-matmed
#     - Tatiana Prieto-único
#   Client ID 8340 has 2 different names:
#     - Alice Nascimento Costa
#     - Marcelo Nunes Ferreira
#   Client ID 8350 has 2 different names:
#     - Alice Nascimento Costa
#     - Marcelo Nunes Ferreira
#   Client ID 836 has 2 different names:
#     - Luana Mariana-MAT MED
#     - Tatiana Prieto-1ª HM
#   Client ID 8360 has 2 different names:
#     - Alice Nascimento Costa
#     - Marcelo Nunes Ferreira
#   Client ID 8370 has 2 different names:
#     - Alice Nascimento Costa
#     - Gabriel Nunes Almeida
#   Client ID 8380 has 2 different names:
#     - Alice Nascimento Costa
#     - Gabriel Nunes Almeida
#   Client ID 8390 has 2 different names:
#     - Alice Nascimento Costa
#     - Gabriel Nunes Almeida
#   Client ID 84 has 2 different names:
#     - JOANA MARIA-1ª HM
#     - JOANA MARIA-2º
#   Client ID 840 has 3 different names:
#     - Miguel costa
#     - josé araujo-1ª
#     - Tatiana Prieto-matmed
#   Client ID 8400 has 2 different names:
#     - Alice Nascimento Costa
#     - Gabriel Nunes Almeida
#   Client ID 841 has 2 different names:
#     - Tatiana Prieto-0
#     - Osvaldo Frias-1ª
#   Client ID 8410 has 2 different names:
#     - Alice Nascimento Costa
#     - Gabriel Nunes Almeida
#   Client ID 8420 has 2 different names:
#     - Alice Nascimento Costa
#     - Gabriel Nunes Almeida
#   Client ID 844 has 3 different names:
#     - Tatiana Prieto-1ª HM
#     - Osvaldo Frias-1ª HM
#     - Felipe Cardoso Nunes
#   Client ID 848 has 2 different names:
#     - Luana Mariana-único - hm
#     - Tatiana Prieto-1ª HM
#   Client ID 85 has 3 different names:
#     - nan
#     - VINÍCIUS CASTRO MENDES
#     - DANIELA MENDES SOUZA
#     - nICoLe FeRrEiRa mEnDeS
#   Client ID 852 has 2 different names:
#     - Tatiana Prieto-matmed
#     - Osvaldo Frias-1ª HM
#   Client ID 856 has 2 different names:
#     - Luana Mariana-único - hm
#     - Osvaldo Frias-1ª HM
#   Client ID 860 has 2 different names:
#     - Miguel costa
#     - Osvaldo Frias-1ª HM
#   Client ID 864 has 3 different names:
#     - Luana Mariana-1º
#     - Osvaldo Frias-1ª HM
#     - Felipe Cardoso Nunes
#   Client ID 872 has 2 different names:
#     - Luana Mariana-mat med
#     - Osvaldo Frias-1ª HM
#   Client ID 880 has 3 different names:
#     - Miguel costa
#     - Luana Mariana-mat med
#     - Osvaldo Frias-1ª HM
#   Client ID 881 has 2 different names:
#     - Osvaldo Frias-1ª
#     - Osvaldo Frias-dp
#   Client ID 8830 has 2 different names:
#     - Leonardo Mendes Almeida
#     - João Pedro Santos
#   Client ID 8840 has 2 different names:
#     - Leonardo Mendes Almeida
#     - João Pedro Santos
#   Client ID 8850 has 2 different names:
#     - Leonardo Mendes Almeida
#     - João Pedro Santos
#   Client ID 8860 has 2 different names:
#     - Leonardo Mendes Almeida
#     - João Pedro Santos
#   Client ID 8870 has 2 different names:
#     - Leonardo Mendes Almeida
#     - João Pedro Santos
#   Client ID 888 has 2 different names:
#     - Tatiana Prieto-0
#     - Osvaldo Frias-1ª HM
#   Client ID 8880 has 2 different names:
#     - Leonardo Mendes Almeida
#     - João Pedro Santos
#   Client ID 8890 has 2 different names:
#     - Leonardo Mendes Almeida
#     - João Pedro Santos
#   Client ID 89 has 2 different names:
#     - JOANA MARIA-1ª
#     - RUBENS FERREIRA-dp
#   Client ID 8900 has 2 different names:
#     - Leonardo Mendes Almeida
#     - João Pedro Santos
#   Client ID 8910 has 2 different names:
#     - Leonardo Mendes Almeida
#     - João Pedro Santos
#   Client ID 892 has 3 different names:
#     - Osvaldo Frias-1ª HM
#     - Osvaldo Frias-2º
#     - Felipe Cardoso Nunes
#   Client ID 896 has 2 different names:
#     - Tatiana Prieto-1ª matmed
#     - Osvaldo Frias-hdf
#   Client ID 90 has 2 different names:
#     - PEDRO SILVA
#     - Miguel Oliveira Costa
#   Client ID 900 has 3 different names:
#     - Miguel costa
#     - Osvaldo Frias-2º
#     - Osvaldo Frias-hdf
#   Client ID 904 has 2 different names:
#     - Osvaldo Frias-1ª
#     - Osvaldo Frias-2º
#   Client ID 905 has 2 different names:
#     - Osvaldo Frias-único - hm
#     - Roberto Amorin-1º
#   Client ID 908 has 2 different names:
#     - Osvaldo Frias-hdf
#     - Roberto Amorin-matmed
#   Client ID 912 has 3 different names:
#     - Osvaldo Frias-1ª
#     - Osvaldo Frias-hdf
#     - Felipe Cardoso Nunes
#   Client ID 916 has 2 different names:
#     - Osvaldo Frias-2º
#     - Roberto Amorin-matmed
#   Client ID 92 has 3 different names:
#     - JOANA MARIA-2º
#     - JOANA MARIA-1ª HM
#     - nan
#     - VINÍCIUS CASTRO MENDES
#   Client ID 920 has 3 different names:
#     - Miguel costa
#     - Osvaldo Frias-1ª
#     - Roberto Amorin-matmed
#   Client ID 921 has 2 different names:
#     - Roberto Amorin-1º
#     - Roberto Amorin-mat med
#   Client ID 924 has 2 different names:
#     - Roberto Amorin-matmed
#     - Roberto Amorin-1º
#   Client ID 928 has 2 different names:
#     - Osvaldo Frias-1ª
#     - Roberto Amorin-matmed
#   Client ID 929 has 2 different names:
#     - Roberto Amorin-MAT MED
#     - Roberto Amorin-único
#   Client ID 932 has 3 different names:
#     - Roberto Amorin-matmed
#     - Roberto Amorin-único
#     - Felipe Cardoso Nunes
#   Client ID 9320 has 2 different names:
#     - Leonardo Mendes Almeida
#     - Isabela Carvalho Souza
#   Client ID 9330 has 2 different names:
#     - Leonardo Mendes Almeida
#     - Isabela Carvalho Souza
#   Client ID 9340 has 2 different names:
#     - Leonardo Mendes Almeida
#     - Isabela Carvalho Souza
#   Client ID 9350 has 2 different names:
#     - Leonardo Mendes Almeida
#     - Isabela Carvalho Souza
#   Client ID 936 has 2 different names:
#     - Osvaldo Frias-1ª
#     - Roberto Amorin-MAT MED
#   Client ID 9360 has 2 different names:
#     - Leonardo Mendes Almeida
#     - Isabela Carvalho Souza
#   Client ID 937 has 2 different names:
#     - Roberto Amorin-mat med
#     - Roberto Amorin-único
#   Client ID 9370 has 2 different names:
#     - Leonardo Mendes Almeida
#     - Isabela Carvalho Souza
#   Client ID 9380 has 2 different names:
#     - Leonardo Mendes Almeida
#     - Isabela Carvalho Souza
#   Client ID 9390 has 2 different names:
#     - Leonardo Mendes Almeida
#     - Isabela Carvalho Souza
#   Client ID 940 has 3 different names:
#     - Miguel costa
#     - Roberto Amorin-1ª
#     - Roberto Amorin-matmed
#   Client ID 9400 has 2 different names:
#     - Leonardo Mendes Almeida
#     - Isabela Carvalho Souza
#   Client ID 944 has 2 different names:
#     - Osvaldo Frias-1ª
#     - Roberto Amorin-único
#   Client ID 945 has 2 different names:
#     - Roberto Amorin-único
#     - Roberto Amorin-0
#   Client ID 948 has 2 different names:
#     - Roberto Amorin-MAT MED
#     - Roberto Amorin-matmed
#   Client ID 95 has 2 different names:
#     - nan
#     - nICoLe FeRrEiRa mEnDeS
#     - MaRcElO nuNeS FeRreiRa Mat & Med
#   Client ID 952 has 3 different names:
#     - Osvaldo Frias-único - hm
#     - Roberto Amorin-matmed
#     - Felipe Cardoso Nunes
#   Client ID 956 has 2 different names:
#     - Roberto Amorin-matmed
#     - Roberto Amorin-1ª HM
#   Client ID 96 has 2 different names:
#     - JOÃO GUIMARAES-único
#     - JOANA MARIA-2º
#   Client ID 960 has 3 different names:
#     - Miguel costa
#     - Osvaldo Frias-dp
#     - Roberto Amorin-1ª HM
#   Client ID 968 has 2 different names:
#     - Roberto Amorin-1º
#     - Roberto Amorin-1ª HM
#   Client ID 97 has 2 different names:
#     - RUBENS FERREIRA-único - hm
#     - nan
#     - diEgO cArDoSo nuNeS Mat e Med
#   Client ID 972 has 2 different names:
#     - Roberto Amorin-1ª HM
#     - Felipe Cardoso Nunes
#   Client ID 976 has 2 different names:
#     - Roberto Amorin-1º
#     - Roberto Amorin-1ª HM
#   Client ID 980 has 2 different names:
#     - Miguel costa
#     - Roberto Amorin-1ª HM
#   Client ID 9810 has 2 different names:
#     - Amanda Lopes Ribeiro
#     - Isabela Carvalho Souza
#   Client ID 9820 has 2 different names:
#     - Amanda Lopes Ribeiro
#     - Isabela Carvalho Souza
#   Client ID 9830 has 2 different names:
#     - Amanda Lopes Ribeiro
#     - Isabela Carvalho Souza
#   Client ID 984 has 2 different names:
#     - Roberto Amorin-matmed
#     - Roberto Amorin-1ª HM
#   Client ID 9840 has 2 different names:
#     - Amanda Lopes Ribeiro
#     - Isabela Carvalho Souza
#   Client ID 9850 has 2 different names:
#     - Amanda Lopes Ribeiro
#     - Isabela Carvalho Souza
#   Client ID 9860 has 2 different names:
#     - Amanda Lopes Ribeiro
#     - Isabela Carvalho Souza
#   Client ID 9870 has 2 different names:
#     - Amanda Lopes Ribeiro
#     - Isabela Carvalho Souza
#   Client ID 9880 has 2 different names:
#     - Amanda Lopes Ribeiro
#     - Isabela Carvalho Souza
#   Client ID 9890 has 2 different names:
#     - Amanda Lopes Ribeiro
#     - Isabela Carvalho Souza
#   Client ID 990 has 2 different names:
#     - Miguel costa
#     - Felipe Cardoso Nunes
#   Client ID 992 has 2 different names:
#     - Roberto Amorin-MAT MED
#     - Roberto Amorin-1ª HM
#   Client ID 993 has 2 different names:
#     - Roberto Amorin-0
#     - Julio Freitas-1ª
#
# === STANDARDIZED DATA SUMMARY ===
# Total records: 5497
# Duplicate rows removed: 0
# Final columns: 48
# Column names: ['CONTRATO_ID', 'STATUS', 'CLIENTE_ID', 'PACIENTE_NOME', 'UNIDADE', 'OPERADORA', 'NF', 'DATA_EMISSAO_NF', 'COMPETENCIA', 'QUINZENA', 'VALOR_BRUTO', 'NUM_SESSOES', 'STATUS_PREVIO_CONTA', 'SOLICITANTE', 'STATUS_ANALISE_CREDITO', 'STATUS_JURIDICO_CLIENTE', 'APROVACAO_CLINICA_GARANTIDORA', 'APROVACAO_FACTORING', 'CONTRATO_ASSINADO', 'DATA_CONTRATO', 'FINANCIADO', 'VALOR_FINANCIADO', 'DATA_FINANCIAMENTO', 'PAGAMENTO_CLINICA', 'VALOR_PAGAMENTO_CLINICA', 'DATA_PAGAMENTO_CLINICA', 'TRANSMISSAO_CONTA', 'DATA_PROTOCOLO', 'DATA_VENCIMENTO', 'STATUS_CONTAS_RECEBER', 'VALOR_PAGO', 'DATA_PAGAMENTO_REEMBOLSO', 'VALOR_GLOSADO', 'DATA_PAGAMENTO_FACTORING', 'VALOR_PAGAMENTO_FACTORING', 'CONTAS_A_RECEBER', 'STATUS_FINAL_CONTA', 'LIGAÇÃO ', 'DATA_LIGACAO', 'RECLAMACAO_CHAT', 'DATA_RECLAMACAO', 'NIP', 'DATA_NIP', 'ETAPAS_JUDICIALIZACAO', 'OBSERVACOES', 'VALOR', 'FONTE_PLANILHA', 'USUARIO']
#
# Columns with significant missing values (>20%):
#   DATA_CONTRATO: 2061 missing values (37.5%)
#   VALOR_FINANCIADO: 1736 missing values (31.6%)
#   DATA_FINANCIAMENTO: 1220 missing values (22.2%)
#   VALOR_PAGAMENTO_CLINICA: 4794 missing values (87.2%)
#   DATA_PAGAMENTO_CLINICA: 1908 missing values (34.7%)
#   DATA_PROTOCOLO: 2219 missing values (40.4%)
#   DATA_VENCIMENTO: 1228 missing values (22.3%)
#   STATUS_CONTAS_RECEBER: 1642 missing values (29.9%)
#   VALOR_PAGO: 1648 missing values (30.0%)
#   DATA_PAGAMENTO_REEMBOLSO: 2397 missing values (43.6%)
#   VALOR_GLOSADO: 2989 missing values (54.4%)
#   DATA_PAGAMENTO_FACTORING: 4983 missing values (90.6%)
#   VALOR_PAGAMENTO_FACTORING: 4151 missing values (75.5%)
#   DATA_LIGACAO: 2697 missing values (49.1%)
#   DATA_RECLAMACAO: 2697 missing values (49.1%)
#   DATA_NIP: 2697 missing values (49.1%)
#   OBSERVACOES: 5482 missing values (99.7%)
#   VALOR: 5497 missing values (100.0%)
#   USUARIO: 5246 missing values (95.4%)
#
# Standardized data saved to /data/chats/igk4wd/workspace/processed_data.csv
#
# === PORTFOLIO ANALYSIS ===
# Records by operating unit:
#   ALPHAVILLE: 1652 records
#   DOMICILIAR: 1622 records
#   SAO JOSE DOS CAMPOS: 841 records
#   BH: 807 records
#   PAULINIA: 251 records
#   CAMPINAS: 194 records
#   LINS: 65 records
#   MORUMBI: 59 records
#   OSASCO: 5 records
#   BRASILIA: 1 records
#
# Financial summary by unit:

# %%
# Further analyze the portfolio performance by operating unit
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import FuncFormatter
import pandas as pd
import numpy as np
from datetime import datetime

# Load the processed data
processed_data_path = '/data/chats/igk4wd/workspace/processed_data.csv'
df = pd.read_csv(processed_data_path)

# Convert date columns to datetime
date_columns = [col for col in df.columns if col.startswith('DATA_')]
for col in date_columns:
    df[col] = pd.to_datetime(df[col], errors='coerce')

# Add month and year columns for time-based analysis
if 'DATA_EMISSAO_NF' in df.columns:
    df['MES'] = df['DATA_EMISSAO_NF'].dt.month
    df['ANO'] = df['DATA_EMISSAO_NF'].dt.year
    df['MES_ANO'] = df['DATA_EMISSAO_NF'].dt.strftime('%m-%Y')

# Set plotting style
sns.set(style="whitegrid")
plt.rcParams.update({'font.size': 12})

# Create a folder for visualizations
import os
viz_path = '/data/chats/igk4wd/workspace/vizualizacoes'
os.makedirs(viz_path, exist_ok=True)

# Filter out extreme values for visualization
df_viz = df.copy()
# Filter out extreme values (above 99th percentile) for better visualization
if 'VALOR' in df_viz.columns:
    valor_threshold = df_viz['VALOR'].quantile(0.99)
    df_viz = df_viz[df_viz['VALOR'] <= valor_threshold]

# 1. Portfolio Analysis by Unit - Total Value
plt.figure(figsize=(12, 8))
unit_values = df_viz.groupby('UNIDADE')['VALOR'].sum().sort_values(ascending=False)

# Bar plot for total values by unit
ax = sns.barplot(x=unit_values.index, y=unit_values.values, palette='viridis')
plt.title('Total Portfolio Value by Operating Unit', fontsize=16)
plt.xlabel('Operating Unit', fontsize=14)
plt.ylabel('Total Value (R$)', fontsize=14)
plt.xticks(rotation=45)

# Add value labels on top of bars
for i, v in enumerate(unit_values):
    ax.text(i, v + (unit_values.max() * 0.02), f'R$ {v:,.0f}', ha='center', fontsize=12)

plt.tight_layout()
plt.savefig(f'{viz_path}/total_portfolio_by_unit.png', dpi=300)
plt.close()

# 2. Average Contract Value by Unit
plt.figure(figsize=(12, 8))
avg_values = df_viz.groupby('UNIDADE')['VALOR'].mean().sort_values(ascending=False)

# Bar plot for average values by unit
ax = sns.barplot(x=avg_values.index, y=avg_values.values, palette='rocket')
plt.title('Average Contract Value by Operating Unit', fontsize=16)
plt.xlabel('Operating Unit', fontsize=14)
plt.ylabel('Average Value (R$)', fontsize=14)
plt.xticks(rotation=45)

# Add value labels on top of bars
for i, v in enumerate(avg_values):
    ax.text(i, v + (avg_values.max() * 0.02), f'R$ {v:,.0f}', ha='center', fontsize=12)

plt.tight_layout()
plt.savefig(f'{viz_path}/avg_contract_by_unit.png', dpi=300)
plt.close()

# 3. Contract Count by Operating Unit
plt.figure(figsize=(12, 8))
contract_counts = df.groupby('UNIDADE').size().sort_values(ascending=False)

# Bar plot for contract counts by unit
ax = sns.barplot(x=contract_counts.index, y=contract_counts.values, palette='mako')
plt.title('Number of Contracts by Operating Unit', fontsize=16)
plt.xlabel('Operating Unit', fontsize=14)
plt.ylabel('Number of Contracts', fontsize=14)
plt.xticks(rotation=45)

# Add value labels on top of bars
for i, v in enumerate(contract_counts):
    ax.text(i, v + (contract_counts.max() * 0.02), f'{v:,}', ha='center', fontsize=12)

plt.tight_layout()
plt.savefig(f'{viz_path}/contract_count_by_unit.png', dpi=300)
plt.close()

# 4. Time Series Analysis - Monthly Portfolio Value by Unit
# Filter data from the last 12 months for clearer visualization
if 'DATA_EMISSAO_NF' in df.columns:
    # Get last 12 months of data with valid dates and values
    df_recent = df[df['DATA_EMISSAO_NF'].notna() & df['VALOR'].notna()].copy()
    
    if not df_recent.empty:
        # Sort by date
        df_recent = df_recent.sort_values('DATA_EMISSAO_NF')
        
        # Group by month-year and unit
        monthly_values = df_recent.groupby(['MES_ANO', 'UNIDADE'])['VALOR'].sum().reset_index()
        
        # Create pivot table for easier plotting
        pivot_monthly = monthly_values.pivot(index='MES_ANO', columns='UNIDADE', values='VALOR')
        
        # Sort chronologically
        try:
            # Convert index to datetime for proper sorting
            pivot_monthly.index = pd.to_datetime(pivot_monthly.index, format='%m-%Y')
            pivot_monthly = pivot_monthly.sort_index()
            # Convert back to string format for display
            pivot_monthly.index = pivot_monthly.index.strftime('%m-%Y')
        except:
            pass
        
        # Plot time series
        plt.figure(figsize=(14, 10))
        pivot_monthly.plot(kind='line', marker='o', linewidth=2, figsize=(14, 10))
        plt.title('Monthly Portfolio Value by Operating Unit', fontsize=16)
        plt.xlabel('Month-Year', fontsize=14)
        plt.ylabel('Total Value (R$)', fontsize=14)
        plt.grid(True, linestyle='--', alpha=0.7)
        plt.legend(title='Operating Unit', fontsize=12, title_fontsize=14)
        plt.xticks(rotation=45)
        
        # Format y-axis to show currency
        def currency_formatter(x, pos):
            return f'R$ {x:,.0f}'
        plt.gca().yaxis.set_major_formatter(FuncFormatter(currency_formatter))
        
        plt.tight_layout()
        plt.savefig(f'{viz_path}/monthly_value_by_unit.png', dpi=300)
        plt.close()

# 5. Status Distribution by Unit
if 'STATUS' in df.columns:
    # Get top 5 statuses
    top_statuses = df['STATUS'].value_counts().nlargest(5).index.tolist()
    df_status = df[df['STATUS'].isin(top_statuses)].copy()
    
    plt.figure(figsize=(14, 10))
    status_counts = pd.crosstab(df_status['UNIDADE'], df_status['STATUS'])
    status_counts.plot(kind='bar', stacked=True, figsize=(14, 10), colormap='tab10')
    plt.title('Contract Status Distribution by Operating Unit', fontsize=16)
    plt.xlabel('Operating Unit', fontsize=14)
    plt.ylabel('Number of Contracts', fontsize=14)
    plt.legend(title='Status', fontsize=12, title_fontsize=14)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig(f'{viz_path}/status_distribution_by_unit.png', dpi=300)
    plt.close()

# 6. Operator Distribution by Unit
if 'OPERADORA' in df.columns:
    # Get top operators
    top_operators = df['OPERADORA'].value_counts().nlargest(5).index.tolist()
    df_operator = df[df['OPERADORA'].isin(top_operators)].copy()
    
    plt.figure(figsize=(14, 10))
    operator_counts = pd.crosstab(df_operator['UNIDADE'], df_operator['OPERADORA'])
    operator_counts.plot(kind='bar', stacked=True, figsize=(14, 10), colormap='Set3')
    plt.title('Insurance Operator Distribution by Operating Unit', fontsize=16)
    plt.xlabel('Operating Unit', fontsize=14)
    plt.ylabel('Number of Contracts', fontsize=14)
    plt.legend(title='Operator', fontsize=12, title_fontsize=14)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig(f'{viz_path}/operator_distribution_by_unit.png', dpi=300)
    plt.close()

# 7. Session Count Analysis
if 'NUM_SESSOES' in df.columns:
    plt.figure(figsize=(12, 8))
    session_avg = df.groupby('UNIDADE')['NUM_SESSOES'].mean().sort_values(ascending=False)
    
    ax = sns.barplot(x=session_avg.index, y=session_avg.values, palette='Blues_d')
    plt.title('Average Number of Sessions by Operating Unit', fontsize=16)
    plt.xlabel('Operating Unit', fontsize=14)
    plt.ylabel('Average Number of Sessions', fontsize=14)
    plt.xticks(rotation=45)
    
    # Add value labels on top of bars
    for i, v in enumerate(session_avg):
        ax.text(i, v + 0.1, f'{v:.1f}', ha='center', fontsize=12)
    
    plt.tight_layout()
    plt.savefig(f'{viz_path}/avg_sessions_by_unit.png', dpi=300)
    plt.close()

# 8. Payment Status Analysis
if 'STATUS_FINAL_CONTA' in df.columns:
    plt.figure(figsize=(14, 10))
    payment_status = pd.crosstab(df['UNIDADE'], df['STATUS_FINAL_CONTA'])
    payment_status.plot(kind='bar', stacked=True, figsize=(14, 10), colormap='RdYlGn')
    plt.title('Payment Status by Operating Unit', fontsize=16)
    plt.xlabel('Operating Unit', fontsize=14)
    plt.ylabel('Number of Contracts', fontsize=14)
    plt.legend(title='Payment Status', fontsize=12, title_fontsize=14)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig(f'{viz_path}/payment_status_by_unit.png', dpi=300)
    plt.close()

# 9. Create a comprehensive summary report with key metrics
summary_report = {}
for unit in df['UNIDADE'].unique():
    unit_data = df[df['UNIDADE'] == unit]
    
    summary_report[unit] = {
        'contracts': len(unit_data),
        'total_value': unit_data['VALOR'].sum(),
        'avg_value': unit_data['VALOR'].mean(),
        'avg_sessions': unit_data['NUM_SESSOES'].mean() if 'NUM_SESSOES' in unit_data.columns else None,
        'top_status': unit_data['STATUS'].value_counts().nlargest(1).index[0] if 'STATUS' in unit_data.columns else None,
        'top_operator': unit_data['OPERADORA'].value_counts().nlargest(1).index[0] if 'OPERADORA' in unit_data.columns else None
    }

# Convert summary to DataFrame for easier display and save to CSV
summary_df = pd.DataFrame.from_dict(summary_report, orient='index')
summary_df.to_csv(f'{viz_path}/portfolio_summary.csv')

# Display key performance indicators
print("=== KEY PORTFOLIO METRICS ===")
print(f"Total portfolio value: R$ {df['VALOR'].sum():,.2f}")
print(f"Total number of contracts: {len(df)}")
print(f"Average contract value: R$ {df['VALOR'].mean():,.2f}")
print("\nUnit Performance Summary:")
for unit, metrics in summary_report.items():
    print(f"\n{unit}:")
    print(f"  - Contracts: {metrics['contracts']:,}")
    print(f"  - Total value: R$ {metrics['total_value']:,.2f}")
    print(f"  - Average value: R$ {metrics['avg_value']:,.2f}")
    if metrics['avg_sessions']:
        print(f"  - Average sessions: {metrics['avg_sessions']:.1f}")
    if metrics['top_status']:
        print(f"  - Main status: {metrics['top_status']}")
    if metrics['top_operator']:
        print(f"  - Main operator: {metrics['top_operator']}")

print(f"\nVisualization files saved to: {viz_path}")
print(f"Processed data saved to: {processed_data_path}")
# Out:
# === KEY PORTFOLIO METRICS ===
# Total portfolio value: R$ 0.00
# Total number of contracts: 5497
# Average contract value: R$ nan
#
# Unit Performance Summary:
#
# ALPHAVILLE:
#   - Contracts: 1,652
#   - Total value: R$ 0.00
#   - Average value: R$ nan
#   - Average sessions: 14.9
#   - Main status: ATIVO
#   - Main operator: BRADESCO
#
# BH:
#   - Contracts: 807
#   - Total value: R$ 0.00
#   - Average value: R$ nan
#   - Average sessions: 12.6
#   - Main status: ATIVO
#   - Main operator: BRADESCO REEMBOLSO
#
# OSASCO:
#   - Contracts: 5
#   - Total value: R$ 0.00
#   - Average value: R$ nan
#   - Average sessions: 12.2
#   - Main status: ATIVO
#   - Main operator: AMIL
#
# BRASILIA:
#   - Contracts: 1
#   - Total value: R$ 0.00
#   - Average value: R$ nan
#   - Average sessions: 13.0
#   - Main status: ATIVO
#   - Main operator: AMIL
#
# DOMICILIAR:
#   - Contracts: 1,622
#   - Total value: R$ 0.00
#   - Average value: R$ nan
#   - Average sessions: 16.3
#   - Main status: ATIVO
#   - Main operator: BRADESCO
#
# SAO JOSE DOS CAMPOS:
#   - Contracts: 841
#   - Total value: R$ 0.00
#   - Average value: R$ nan
#   - Average sessions: 16.3
#   - Main status: ATIVO
#   - Main operator: SULAMERICA
#
# MORUMBI:
#   - Contracts: 59
#   - Total value: R$ 0.00
#   - Average value: R$ nan
#   - Average sessions: 16.0
#   - Main status: ATIVO
#   - Main operator: SULAMERICA
#
# LINS:
#   - Contracts: 65
#   - Total value: R$ 0.00
#   - Average value: R$ nan
#   - Average sessions: 16.5
#   - Main status: ATIVO
#   - Main operator: SULAMERICA
#
# PAULINIA:
#   - Contracts: 251
#   - Total value: R$ 0.00
#   - Average value: R$ nan
#   - Average sessions: 16.3
#   - Main status: ATIVO
#   - Main operator: VIVEST
#
# CAMPINAS:
#   - Contracts: 194
#   - Total value: R$ 0.00
#   - Average value: R$ nan
#   - Average sessions: 16.3
#   - Main status: ATIVO
#   - Main operator: SULAMERICA
#
# Visualization files saved to: /data/chats/igk4wd/workspace/vizualizacoes
# Processed data saved to: /data/chats/igk4wd/workspace/processed_data.csv

# %%
# Fix the VALOR conversion issue and create a comprehensive portfolio analysis report
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import FuncFormatter
import re

# Load the original Excel file again
file_path = '/data/chats/igk4wd/workspace/uploads/Teste Power BI - Deveras RH.xlsx'
location_sheets = ['Alphaville', 'BH', 'SJC', 'PAULINIA', 'CAMPINAS']

# Create standardized dataframes
standardized_dfs = {}

# Define an improved function to convert VALOR to numeric
def convert_valor_to_numeric(valor):
    if pd.isna(valor):
        return np.nan
    if isinstance(valor, (int, float)):
        return float(valor)
    
    # Convert string to string format
    valor_str = str(valor)
    
    # Remove any non-numeric characters except . and ,
    clean_valor = re.sub(r'[^\d.,]', '', valor_str)
    
    # Handle Brazilian/European format (e.g. 1.234,56)
    if ',' in clean_valor and '.' in clean_valor:
        # If there are both dots and commas, assume Brazilian/European format
        clean_valor = clean_valor.replace('.', '').replace(',', '.')
    elif ',' in clean_valor:
        # If only commas, replace with dots
        clean_valor = clean_valor.replace(',', '.')
    
    # Convert to float
    try:
        return float(clean_valor)
    except:
        return np.nan

# Process each sheet and standardize them
for sheet in location_sheets:
    print(f"Processing {sheet} sheet...")
    
    # Read the sheet
    df = pd.read_excel(file_path, sheet_name=sheet)
    
    # Process VALOR column
    if 'VALOR' in df.columns:
        # Save original values for reference
        df['VALOR_ORIGINAL'] = df['VALOR']
        
        # Convert to numeric
        df['VALOR'] = df['VALOR'].apply(convert_valor_to_numeric)
        
        # Check conversion results
        print(f"  - Sample original values: {df['VALOR_ORIGINAL'].head(3).tolist()}")
        print(f"  - Sample converted values: {df['VALOR'].head(3).tolist()}")
        print(f"  - NaN values after conversion: {df['VALOR'].isna().sum()}")
        print(f"  - VALOR statistics: Min={df['VALOR'].min()}, Max={df['VALOR'].max()}, Mean={df['VALOR'].mean():.2f}")
    
    # Standardize UNIDADE column
    if 'UNIDADE' in df.columns:
        df['UNIDADE'] = df['UNIDADE'].str.strip().str.upper()
        # Map variations to standard names
        unit_mapping = {
            'ALPHA': 'ALPHAVILLE',
            'alpha ': 'ALPHAVILLE',
            'SJC': 'SAO JOSE DOS CAMPOS',
            'BELO HORIZONTE': 'BH',
            'BSB': 'BRASILIA'
        }
        df['UNIDADE'] = df['UNIDADE'].replace(unit_mapping)
    
    # Store the standardized dataframe
    standardized_dfs[sheet] = df

# Combine all sheets into a single dataframe
combined_df = pd.concat(standardized_dfs.values(), ignore_index=True)

# Create a directory for visualizations
import os
viz_path = '/data/chats/igk4wd/workspace/visualizations'
os.makedirs(viz_path, exist_ok=True)

# Set visualization style
sns.set(style="whitegrid")
plt.rcParams.update({'font.size': 12})

# Filter extreme values for better visualization (excluding top 1%)
df_viz = combined_df.copy()
if 'VALOR' in df_viz.columns:
    valor_threshold = df_viz['VALOR'].quantile(0.99)
    df_viz = df_viz[df_viz['VALOR'] <= valor_threshold]

# 1. Portfolio Value by Operating Unit
plt.figure(figsize=(12, 8))
unit_values = df_viz.groupby('UNIDADE')['VALOR'].sum().sort_values(ascending=False)

ax = sns.barplot(x=unit_values.index, y=unit_values.values, palette='viridis')
plt.title('Total Portfolio Value by Operating Unit', fontsize=16)
plt.xlabel('Operating Unit', fontsize=14)
plt.ylabel('Total Value (R$)', fontsize=14)
plt.xticks(rotation=45)

# Add value labels on bars
for i, v in enumerate(unit_values):
    ax.text(i, v + (unit_values.max() * 0.02), f'R$ {v:,.0f}', ha='center', fontsize=11)

plt.tight_layout()
plt.savefig(f'{viz_path}/total_portfolio_by_unit.png', dpi=300)
plt.close()

# 2. Average Contract Value by Unit
plt.figure(figsize=(12, 8))
avg_values = df_viz.groupby('UNIDADE')['VALOR'].mean().sort_values(ascending=False)

ax = sns.barplot(x=avg_values.index, y=avg_values.values, palette='rocket')
plt.title('Average Contract Value by Operating Unit', fontsize=16)
plt.xlabel('Operating Unit', fontsize=14)
plt.ylabel('Average Value (R$)', fontsize=14)
plt.xticks(rotation=45)

# Add value labels on bars
for i, v in enumerate(avg_values):
    ax.text(i, v + (avg_values.max() * 0.02), f'R$ {v:,.0f}', ha='center', fontsize=11)

plt.tight_layout()
plt.savefig(f'{viz_path}/avg_contract_by_unit.png', dpi=300)
plt.close()

# 3. Number of Contracts by Unit
plt.figure(figsize=(12, 8))
contract_counts = combined_df.groupby('UNIDADE').size().sort_values(ascending=False)

ax = sns.barplot(x=contract_counts.index, y=contract_counts.values, palette='mako')
plt.title('Number of Contracts by Operating Unit', fontsize=16)
plt.xlabel('Operating Unit', fontsize=14)
plt.ylabel('Number of Contracts', fontsize=14)
plt.xticks(rotation=45)

# Add value labels on bars
for i, v in enumerate(contract_counts):
    ax.text(i, v + (contract_counts.max() * 0.02), f'{v:,}', ha='center', fontsize=11)

plt.tight_layout()
plt.savefig(f'{viz_path}/contract_count_by_unit.png', dpi=300)
plt.close()

# 4. Status Distribution by Unit
if 'STATUS' in combined_df.columns:
    # Get top 5 statuses
    top_statuses = combined_df['STATUS'].value_counts().nlargest(5).index.tolist()
    df_status = combined_df[combined_df['STATUS'].isin(top_statuses)].copy()
    
    plt.figure(figsize=(14, 10))
    status_counts = pd.crosstab(df_status['UNIDADE'], df_status['STATUS'])
    status_counts.plot(kind='bar', stacked=True, figsize=(14, 10), colormap='tab10')
    plt.title('Contract Status Distribution by Operating Unit', fontsize=16)
    plt.xlabel('Operating Unit', fontsize=14)
    plt.ylabel('Number of Contracts', fontsize=14)
    plt.legend(title='Status', fontsize=12, title_fontsize=14)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig(f'{viz_path}/status_distribution_by_unit.png', dpi=300)
    plt.close()

# 5. Operator Distribution by Unit
if 'OPERADORA' in combined_df.columns:
    # Get top operators
    top_operators = combined_df['OPERADORA'].value_counts().nlargest(5).index.tolist()
    df_operator = combined_df[combined_df['OPERADORA'].isin(top_operators)].copy()
    
    plt.figure(figsize=(14, 10))
    operator_counts = pd.crosstab(df_operator['UNIDADE'], df_operator['OPERADORA'])
    operator_counts.plot(kind='bar', stacked=True, figsize=(14, 10), colormap='Set3')
    plt.title('Insurance Operator Distribution by Operating Unit', fontsize=16)
    plt.xlabel('Operating Unit', fontsize=14)
    plt.ylabel('Number of Contracts', fontsize=14)
    plt.legend(title='Operator', fontsize=12, title_fontsize=14)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig(f'{viz_path}/operator_distribution_by_unit.png', dpi=300)
    plt.close()

# 6. Sessions Distribution by Unit
if 'Nº SESSÕES' in combined_df.columns:
    plt.figure(figsize=(12, 8))
    session_avg = combined_df.groupby('UNIDADE')['Nº SESSÕES'].mean().sort_values(ascending=False)
    
    ax = sns.barplot(x=session_avg.index, y=session_avg.values, palette='Blues_d')
    plt.title('Average Number of Sessions by Operating Unit', fontsize=16)
    plt.xlabel('Operating Unit', fontsize=14)
    plt.ylabel('Average Number of Sessions', fontsize=14)
    plt.xticks(rotation=45)
    
    # Add value labels on bars
    for i, v in enumerate(session_avg):
        ax.text(i, v + 0.1, f'{v:.1f}', ha='center', fontsize=11)
    
    plt.tight_layout()
    plt.savefig(f'{viz_path}/avg_sessions_by_unit.png', dpi=300)
    plt.close()

# 7. Boxplot of VALOR by Unit
plt.figure(figsize=(14, 10))
sns.boxplot(x='UNIDADE', y='VALOR', data=df_viz, palette='Set2')
plt.title('Distribution of Contract Values by Unit', fontsize=16)
plt.xlabel('Operating Unit', fontsize=14)
plt.ylabel('Contract Value (R$)', fontsize=14)
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig(f'{viz_path}/valor_distribution_by_unit.png', dpi=300)
plt.close()

# Create the comprehensive summary report
summary_data = {}

for unit in combined_df['UNIDADE'].unique():
    unit_data = combined_df[combined_df['UNIDADE'] == unit]
    
    # Calculate key metrics
    summary_data[unit] = {
        'n_contracts': len(unit_data),
        'total_value': unit_data['VALOR'].sum(),
        'avg_value': unit_data['VALOR'].mean(),
        'max_value': unit_data['VALOR'].max(),
        'min_value': unit_data['VALOR'].min()
    }
    
    # Add sessions data if available
    if 'Nº SESSÕES' in unit_data.columns:
        summary_data[unit]['avg_sessions'] = unit_data['Nº SESSÕES'].mean()
    
    # Add status distribution if available
    if 'STATUS' in unit_data.columns and not unit_data['STATUS'].isna().all():
        top_status = unit_data['STATUS'].value_counts().index[0] if not unit_data['STATUS'].value_counts().empty else 'N/A'
        summary_data[unit]['top_status'] = top_status
    
    # Add operator distribution if available
    if 'OPERADORA' in unit_data.columns and not unit_data['OPERADORA'].isna().all():
        top_operator = unit_data['OPERADORA'].value_counts().index[0] if not unit_data['OPERADORA'].value_counts().empty else 'N/A'
        summary_data[unit]['top_operator'] = top_operator

# Convert to DataFrame and save
summary_df = pd.DataFrame.from_dict(summary_data, orient='index')
summary_df.to_csv(f'{viz_path}/portfolio_summary.csv')

# Display key portfolio metrics
print("\n=== PORTFOLIO PERFORMANCE ANALYSIS ===")
print(f"Total portfolio value: R$ {combined_df['VALOR'].sum():,.2f}")
print(f"Total number of contracts: {len(combined_df):,}")
print(f"Average contract value: R$ {combined_df['VALOR'].mean():,.2f}")

# Display unit performance summary
print("\n=== UNIT PERFORMANCE SUMMARY ===")
for unit, metrics in summary_data.items():
    print(f"\n{unit}:")
    print(f"  - Contracts: {metrics['n_contracts']:,}")
    print(f"  - Total value: R$ {metrics['total_value']:,.2f}")
    print(f"  - Average value: R$ {metrics['avg_value']:,.2f}")
    
    if 'avg_sessions' in metrics:
        print(f"  - Average sessions: {metrics['avg_sessions']:.1f}")
    
    if 'top_status' in metrics:
        print(f"  - Main status: {metrics['top_status']}")
    
    if 'top_operator' in metrics:
        print(f"  - Main operator: {metrics['top_operator']}")

# Save the processed data
processed_data_path = '/data/chats/igk4wd/workspace/processed_data.csv'
combined_df.to_csv(processed_data_path, index=False)
print(f"\nProcessed data saved to: {processed_data_path}")
print(f"Visualization files saved to: {viz_path}")

# List the identified data inconsistencies
print("\n=== DATA INCONSISTENCIES ===")
print("1. Inconsistent column naming across sheets")
print("2. Inconsistent UNIDADE names (e.g., 'ALPHAVILLE', 'alpha ')")
print("3. Multiple patient names assigned to the same client ID")
print("4. Inconsistent data types for common columns across sheets")
print("5. Unusual date values (dates before 2000 likely errors)")
print("6. Extreme values in VALOR column that required filtering")
print("7. Missing values in critical columns")
# Out:
# Processing Alphaville sheet...
#   - Sample original values: [41545.78, 54270.99, 43074.45]
#   - Sample converted values: [41545.78, 54270.99, 43074.45]
#   - NaN values after conversion: 21
#   - VALOR statistics: Min=3000.0, Max=124526.12, Mean=47585.68
# Processing BH sheet...
#   - Sample original values: [51231.24, 47328.33, 57888.45]
#   - Sample converted values: [51231.24, 47328.33, 57888.45]
#   - NaN values after conversion: 52
#   - VALOR statistics: Min=8.0, Max=84354.34, Mean=28020.54
# Processing SJC sheet...
#   - Sample original values: [datetime.datetime(2014, 1, 20, 9, 21, 36), datetime.datetime(2016, 5, 29, 18, 57, 36), datetime.datetime(2016, 8, 29, 9, 21, 36)]
#   - Sample converted values: [20140120092136.0, 20160529185736.0, 20160829092136.0]
#   - NaN values after conversion: 18
#   - VALOR statistics: Min=2600.0, Max=26030602074048.0, Mean=11384180980684.39
# Processing PAULINIA sheet...
#   - Sample original values: [78661.77, 55947.52, 54432.92]
#   - Sample converted values: [78661.77, 55947.52, 54432.92]
#   - NaN values after conversion: 10
#   - VALOR statistics: Min=6167.61, Max=21600212072624.0, Mean=1943374697564.22
# Processing CAMPINAS sheet...
#   - Sample original values: [47620.67, 51408.02, 13345]
#   - Sample converted values: [47620.67, 51408.02, 13345.0]
#   - NaN values after conversion: 45
#   - VALOR statistics: Min=3681.72, Max=89595.06, Mean=36082.52
#
# === PORTFOLIO PERFORMANCE ANALYSIS ===
# Total portfolio value: R$ 29,714,314,345,783,776.00
# Total number of contracts: 5,497
# Average contract value: R$ 5,553,039,496,502.29
#
# === UNIT PERFORMANCE SUMMARY ===
#
# ALPHAVILLE:
#   - Contracts: 1,652
#   - Total value: R$ 77,569,468.39
#   - Average value: R$ 47,559.45
#   - Average sessions: 14.9
#   - Main status: ATIVO
#   - Main operator: BRADESCO
#
# BH:
#   - Contracts: 807
#   - Total value: R$ 21,331,388.35
#   - Average value: R$ 28,178.85
#   - Average sessions: 12.6
#   - Main status: ATIVO
#   - Main operator: BRADESCO REEMBOLSO
#
# OSASCO:
#   - Contracts: 5
#   - Total value: R$ 15,450.00
#   - Average value: R$ 3,862.50
#   - Average sessions: 12.2
#   - Main status: ATIVO
#   - Main operator: AMIL
#
# BRASILIA:
#   - Contracts: 1
#   - Total value: R$ 0.00
#   - Average value: R$ nan
#   - Average sessions: 13.0
#   - Main status: ATIVO
#   - Main operator: AMIL
#
# DOMICILIAR:
#   - Contracts: 1,622
#   - Total value: R$ 24,989,226,432,150,044.00
#   - Average value: R$ 15,473,205,221,145.54
#   - Average sessions: 16.3
#   - Main status: ATIVO
#   - Main operator: BRADESCO
#
# SAO JOSE DOS CAMPOS:
#   - Contracts: 841
#   - Total value: R$ 2,001,415,196,885,614.75
#   - Average value: R$ 2,408,441,873,508.56
#   - Average sessions: 16.3
#   - Main status: ATIVO
#   - Main operator: SULAMERICA
#
# MORUMBI:
#   - Contracts: 59
#   - Total value: R$ 1,180,853,629,471,216.00
#   - Average value: R$ 20,359,545,335,710.62
#   - Average sessions: 16.0
#   - Main status: ATIVO
#   - Main operator: SULAMERICA
#
# LINS:
#   - Contracts: 65
#   - Total value: R$ 1,074,465,680,871,320.50
#   - Average value: R$ 16,530,241,244,174.16
#   - Average sessions: 16.5
#   - Main status: ATIVO
#   - Main operator: SULAMERICA
#
# PAULINIA:
#   - Contracts: 251
#   - Total value: R$ 468,353,302,112,976.38
#   - Average value: R$ 1,943,374,697,564.22
#   - Average sessions: 16.3
#   - Main status: ATIVO
#   - Main operator: VIVEST
#
# CAMPINAS:
#   - Contracts: 194
#   - Total value: R$ 5,376,295.64
#   - Average value: R$ 36,082.52
#   - Average sessions: 16.3
#   - Main status: ATIVO
#   - Main operator: SULAMERICA
#
# Processed data saved to: /data/chats/igk4wd/workspace/processed_data.csv
# Visualization files saved to: /data/chats/igk4wd/workspace/visualizations
#
# === DATA INCONSISTENCIES ===
# 1. Inconsistent column naming across sheets
# 2. Inconsistent UNIDADE names (e.g., 'ALPHAVILLE', 'alpha ')
# 3. Multiple patient names assigned to the same client ID
# 4. Inconsistent data types for common columns across sheets
# 5. Unusual date values (dates before 2000 likely errors)
# 6. Extreme values in VALOR column that required filtering
# 7. Missing values in critical columns

# %%
# Fix the extreme VALOR values in SJC and PAULINIA sheets 
# and create a final comprehensive portfolio analysis report
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import FuncFormatter
import re
import os
from datetime import datetime

# Load the original Excel file again to fix the data issues
file_path = '/data/chats/igk4wd/workspace/uploads/Teste Power BI - Deveras RH.xlsx'
location_sheets = ['Alphaville', 'BH', 'SJC', 'PAULINIA', 'CAMPINAS']

# Create standardized dataframes
standardized_dfs = {}

# Improved function to convert VALOR to numeric, handling special cases
def convert_valor_to_numeric(valor):
    if pd.isna(valor):
        return np.nan
    
    # If it's already a number, but actually a date
    if isinstance(valor, (int, float)) and valor > 1000000:  # Very large numbers are likely date formats
        return np.nan
    
    # If it's already a reasonable number
    if isinstance(valor, (int, float)) and valor < 1000000:
        return float(valor)
    
    # If it's a datetime object (common issue in some sheets)
    if isinstance(valor, datetime):
        return np.nan
    
    # Convert string to string format for processing
    valor_str = str(valor)
    
    # Check if it might be a date in disguise
    if len(valor_str) > 10 and re.match(r'\d{10,}', valor_str):
        return np.nan
    
    # Remove any non-numeric characters except . and ,
    clean_valor = re.sub(r'[^\d.,]', '', valor_str)
    
    # Handle Brazilian/European format (e.g. 1.234,56)
    if ',' in clean_valor and '.' in clean_valor:
        clean_valor = clean_valor.replace('.', '').replace(',', '.')
    elif ',' in clean_valor:
        clean_valor = clean_valor.replace(',', '.')
    
    # Convert to float
    try:
        val = float(clean_valor)
        # Additional sanity check - extreme values are likely errors
        if val > 500000:  # Assuming no contract should be above 500,000
            return np.nan
        return val
    except:
        return np.nan

# Process each sheet and standardize them
print("=== DATA CLEANING AND STANDARDIZATION ===")
for sheet in location_sheets:
    print(f"\nProcessing {sheet} sheet...")
    
    # Read the sheet
    df = pd.read_excel(file_path, sheet_name=sheet)
    
    # Process VALOR column
    if 'VALOR' in df.columns:
        # Save original values for reference
        df['VALOR_ORIGINAL'] = df['VALOR']
        
        # Convert to numeric with improved function
        df['VALOR'] = df['VALOR'].apply(convert_valor_to_numeric)
        
        # Check conversion results
        print(f"  - Original values (sample): {df['VALOR_ORIGINAL'].head(3).tolist()}")
        print(f"  - Converted values (sample): {df['VALOR'].head(3).tolist()}")
        print(f"  - NaN values after conversion: {df['VALOR'].isna().sum()} out of {len(df)}")
        print(f"  - VALOR statistics: Min={df['VALOR'].min():.2f}, Max={df['VALOR'].max():.2f}, Mean={df['VALOR'].mean():.2f}")
    
    # Clean and standardize column names
    df.columns = [col.strip() for col in df.columns]
    
    # Standardize UNIDADE column
    if 'UNIDADE' in df.columns:
        df['UNIDADE'] = df['UNIDADE'].str.strip().str.upper()
        # Map variations to standard names
        unit_mapping = {
            'ALPHA': 'ALPHAVILLE',
            'alpha ': 'ALPHAVILLE',
            'SJC': 'SAO JOSE DOS CAMPOS',
            'BELO HORIZONTE': 'BH',
            'BSB': 'BRASILIA'
        }
        df['UNIDADE'] = df['UNIDADE'].replace(unit_mapping)
    
    # Add source sheet information
    df['FONTE_PLANILHA'] = sheet
    
    # Store the cleaned dataframe
    standardized_dfs[sheet] = df

# Combine all sheets into a single dataframe
combined_df = pd.concat(standardized_dfs.values(), ignore_index=True)

# Further cleaning: Remove rows with NaN VALOR and filter extreme values
valid_valor_df = combined_df[combined_df['VALOR'].notna()].copy()
print(f"\nRows with valid VALOR: {len(valid_valor_df)} out of {len(combined_df)} total rows")

# Create directory for visualizations and reports
viz_path = '/data/chats/igk4wd/workspace/visualizations'
os.makedirs(viz_path, exist_ok=True)

# Set visualization style
sns.set(style="whitegrid")
plt.rcParams.update({'font.size': 12})

# ====== PORTFOLIO ANALYSIS VISUALIZATIONS ======

# 1. Portfolio Value by Operating Unit
plt.figure(figsize=(12, 8))
# Group by UNIDADE and sum the VALOR, handling NaN values
unit_values = valid_valor_df.groupby('UNIDADE')['VALOR'].sum().sort_values(ascending=False)

ax = sns.barplot(x=unit_values.index, y=unit_values.values, palette='viridis')
plt.title('Total Portfolio Value by Operating Unit', fontsize=16)
plt.xlabel('Operating Unit', fontsize=14)
plt.ylabel('Total Value (R$)', fontsize=14)
plt.xticks(rotation=45)

# Add value labels on bars
for i, v in enumerate(unit_values):
    ax.text(i, v + (unit_values.max() * 0.02), f'R$ {v:,.0f}', ha='center', fontsize=11)

plt.tight_layout()
plt.savefig(f'{viz_path}/total_portfolio_by_unit.png', dpi=300)
plt.close()

# 2. Average Contract Value by Unit
plt.figure(figsize=(12, 8))
avg_values = valid_valor_df.groupby('UNIDADE')['VALOR'].mean().sort_values(ascending=False)

ax = sns.barplot(x=avg_values.index, y=avg_values.values, palette='rocket')
plt.title('Average Contract Value by Operating Unit', fontsize=16)
plt.xlabel('Operating Unit', fontsize=14)
plt.ylabel('Average Value (R$)', fontsize=14)
plt.xticks(rotation=45)

# Add value labels on bars
for i, v in enumerate(avg_values):
    ax.text(i, v + (avg_values.max() * 0.02), f'R$ {v:,.0f}', ha='center', fontsize=11)

plt.tight_layout()
plt.savefig(f'{viz_path}/avg_contract_by_unit.png', dpi=300)
plt.close()

# 3. Number of Contracts by Unit
plt.figure(figsize=(12, 8))
contract_counts = combined_df.groupby('UNIDADE').size().sort_values(ascending=False)

ax = sns.barplot(x=contract_counts.index, y=contract_counts.values, palette='mako')
plt.title('Number of Contracts by Operating Unit', fontsize=16)
plt.xlabel('Operating Unit', fontsize=14)
plt.ylabel('Number of Contracts', fontsize=14)
plt.xticks(rotation=45)

# Add value labels on bars
for i, v in enumerate(contract_counts):
    ax.text(i, v + (contract_counts.max() * 0.02), f'{v:,}', ha='center', fontsize=11)

plt.tight_layout()
plt.savefig(f'{viz_path}/contract_count_by_unit.png', dpi=300)
plt.close()

# 4. Status Distribution by Unit (Top 5)
if 'STATUS' in combined_df.columns:
    # Get top 5 statuses
    top_statuses = combined_df['STATUS'].value_counts().nlargest(5).index.tolist()
    df_status = combined_df[combined_df['STATUS'].isin(top_statuses)].copy()
    
    plt.figure(figsize=(14, 10))
    status_counts = pd.crosstab(df_status['UNIDADE'], df_status['STATUS'])
    status_counts.plot(kind='bar', stacked=True, figsize=(14, 10), colormap='tab10')
    plt.title('Contract Status Distribution by Operating Unit', fontsize=16)
    plt.xlabel('Operating Unit', fontsize=14)
    plt.ylabel('Number of Contracts', fontsize=14)
    plt.legend(title='Status', fontsize=12, title_fontsize=14)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig(f'{viz_path}/status_distribution_by_unit.png', dpi=300)
    plt.close()

# 5. Operator Distribution by Unit (Top 5)
if 'OPERADORA' in combined_df.columns:
    # Get top operators
    top_operators = combined_df['OPERADORA'].value_counts().nlargest(5).index.tolist()
    df_operator = combined_df[combined_df['OPERADORA'].isin(top_operators)].copy()
    
    plt.figure(figsize=(14, 10))
    operator_counts = pd.crosstab(df_operator['UNIDADE'], df_operator['OPERADORA'])
    operator_counts.plot(kind='bar', stacked=True, figsize=(14, 10), colormap='Set3')
    plt.title('Insurance Operator Distribution by Operating Unit', fontsize=16)
    plt.xlabel('Operating Unit', fontsize=14)
    plt.ylabel('Number of Contracts', fontsize=14)
    plt.legend(title='Operator', fontsize=12, title_fontsize=14)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig(f'{viz_path}/operator_distribution_by_unit.png', dpi=300)
    plt.close()

# 6. Sessions Distribution by Unit
if 'Nº SESSÕES' in combined_df.columns:
    plt.figure(figsize=(12, 8))
    session_avg = combined_df.groupby('UNIDADE')['Nº SESSÕES'].mean().sort_values(ascending=False)
    
    ax = sns.barplot(x=session_avg.index, y=session_avg.values, palette='Blues_d')
    plt.title('Average Number of Sessions by Operating Unit', fontsize=16)
    plt.xlabel('Operating Unit', fontsize=14)
    plt.ylabel('Average Number of Sessions', fontsize=14)
    plt.xticks(rotation=45)
    
    # Add value labels on bars
    for i, v in enumerate(session_avg):
        ax.text(i, v + 0.1, f'{v:.1f}', ha='center', fontsize=11)
    
    plt.tight_layout()
    plt.savefig(f'{viz_path}/avg_sessions_by_unit.png', dpi=300)
    plt.close()

# 7. Boxplot of VALOR by Unit
plt.figure(figsize=(14, 10))
sns.boxplot(x='UNIDADE', y='VALOR', data=valid_valor_df, palette='Set2')
plt.title('Distribution of Contract Values by Unit', fontsize=16)
plt.xlabel('Operating Unit', fontsize=14)
plt.ylabel('Contract Value (R$)', fontsize=14)
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig(f'{viz_path}/valor_distribution_by_unit.png', dpi=300)
plt.close()

# Create a comprehensive summary report for each operating unit
summary_data = {}

for unit in combined_df['UNIDADE'].unique():
    unit_data = combined_df[combined_df['UNIDADE'] == unit]
    unit_valid_valor = unit_data[unit_data['VALOR'].notna()]
    
    # Calculate key metrics
    summary_data[unit] = {
        'n_contracts': len(unit_data),
        'n_valid_contracts': len(unit_valid_valor),
        'total_value': unit_valid_valor['VALOR'].sum(),
        'avg_value': unit_valid_valor['VALOR'].mean(),
        'max_value': unit_valid_valor['VALOR'].max(),
        'min_value': unit_valid_valor['VALOR'].min(),
        'data_completeness': len(unit_valid_valor) / len(unit_data) if len(unit_data) > 0 else 0,
    }
    
    # Add sessions data if available
    if 'Nº SESSÕES' in unit_data.columns:
        summary_data[unit]['avg_sessions'] = unit_data['Nº SESSÕES'].mean()
    
    # Add status distribution if available
    if 'STATUS' in unit_data.columns and not unit_data['STATUS'].isna().all():
        status_counts = unit_data['STATUS'].value_counts()
        top_status = status_counts.index[0] if not status_counts.empty else 'N/A'
        top_status_pct = status_counts.iloc[0] / len(unit_data) if not status_counts.empty else 0
        summary_data[unit]['top_status'] = top_status
        summary_data[unit]['top_status_pct'] = top_status_pct
    
    # Add operator distribution if available
    if 'OPERADORA' in unit_data.columns and not unit_data['OPERADORA'].isna().all():
        operator_counts = unit_data['OPERADORA'].value_counts()
        top_operator = operator_counts.index[0] if not operator_counts.empty else 'N/A'
        top_operator_pct = operator_counts.iloc[0] / len(unit_data) if not operator_counts.empty else 0
        summary_data[unit]['top_operator'] = top_operator
        summary_data[unit]['top_operator_pct'] = top_operator_pct

# Convert to DataFrame for reporting
summary_df = pd.DataFrame.from_dict(summary_data, orient='index')
summary_df.to_csv(f'{viz_path}/portfolio_summary.csv')

# Create a comprehensive final report
report_path = f'{viz_path}/portfolio_analysis_report.md'
with open(report_path, 'w') as f:
    f.write("# Portfolio Analysis Report - Deveras RH\n\n")
    
    f.write("## Data Overview\n")
    f.write(f"- Total contracts analyzed: {len(combined_df):,}\n")
    f.write(f"- Contracts with valid financial data: {len(valid_valor_df):,} ({len(valid_valor_df)/len(combined_df):.1%})\n")
    f.write(f"- Operating units: {', '.join(combined_df['UNIDADE'].unique())}\n")
    f.write(f"- Total portfolio value: R$ {valid_valor_df['VALOR'].sum():,.2f}\n\n")
    
    f.write("## Key Portfolio Metrics by Operating Unit\n\n")
    
    for unit, metrics in summary_data.items():
        f.write(f"### {unit}\n")
        f.write(f"- Contracts: {metrics['n_contracts']:,}\n")
        f.write(f"- Contracts with valid financial data: {metrics['n_valid_contracts']:,} ({metrics['data_completeness']:.1%})\n")
        f.write(f"- Total value: R$ {metrics['total_value']:,.2f}\n")
        f.write(f"- Average value per contract: R$ {metrics['avg_value']:,.2f}\n")
        f.write(f"- Value range: R$ {metrics['min_value']:,.2f} to R$ {metrics['max_value']:,.2f}\n")
        
        if 'avg_sessions' in metrics:
            f.write(f"- Average sessions: {metrics['avg_sessions']:.1f}\n")
        
        if 'top_status' in metrics:
            f.write(f"- Primary status: {metrics['top_status']} ({metrics['top_status_pct']:.1%} of contracts)\n")
        
        if 'top_operator' in metrics:
            f.write(f"- Primary operator: {metrics['top_operator']} ({metrics['top_operator_pct']:.1%} of contracts)\n")
        
        f.write("\n")
    
    f.write("## Data Inconsistencies Identified\n\n")
    f.write("1. **Inconsistent Column Naming**: Different sheets used varied naming conventions for the same data.\n")
    f.write("2. **Inconsistent Location Names**: The same operating unit appeared under different names (e.g., 'ALPHAVILLE', 'alpha').\n")
    f.write("3. **Client ID Inconsistencies**: Multiple patient names were assigned to the same client ID.\n")
    f.write("4. **Data Type Inconsistencies**: The same columns had different data types across sheets.\n")
    f.write("5. **Problematic Date Values**: Some sheets contained unusual date values (dates before 2000).\n")
    f.write("6. **Extreme Values in VALOR Column**: SJC and PAULINIA sheets contained datetime values incorrectly interpreted as currency.\n")
    f.write("7. **Missing Values**: Critical columns contained significant numbers of missing values.\n\n")
    
    f.write("## Recommendations for Dashboard Creation\n\n")
    f.write("1. Use the standardized processed data provided in the CSV file for consistent analysis.\n")
    f.write("2. Implement filters by operating unit, status, and insurance operator.\n")
    f.write("3. Include time series visualizations to track portfolio growth over time.\n")
    f.write("4. Create separate panels for individual operating unit performance and consolidated views.\n")
    f.write("5. Consider implementing alerts for contracts with unusual values or statuses.\n")
    f.write("6. Include data quality metrics to monitor completeness and consistency.\n")

# Save the processed data with fixed values
processed_data_path = '/data/chats/igk4wd/workspace/processed_data.csv'
combined_df.to_csv(processed_data_path, index=False)

# Display summary of the analysis
print("\n=== PORTFOLIO PERFORMANCE ANALYSIS ===")
print(f"Total portfolio value: R$ {valid_valor_df['VALOR'].sum():,.2f}")
print(f"Total number of contracts: {len(combined_df):,}")
print(f"Contracts with valid financial data: {len(valid_valor_df):,} ({len(valid_valor_df)/len(combined_df):.1%})")
print(f"Average contract value: R$ {valid_valor_df['VALOR'].mean():,.2f}")

# Display unit performance summary
print("\n=== UNIT PERFORMANCE SUMMARY ===")
for unit, metrics in summary_data.items():
    print(f"\n{unit}:")
    print(f"  - Contracts: {metrics['n_contracts']:,}")
    print(f"  - Valid financial data: {metrics['n_valid_contracts']:,} ({metrics['data_completeness']:.1%})")
    print(f"  - Total value: R$ {metrics['total_value']:,.2f}")
    print(f"  - Average value: R$ {metrics['avg_value']:,.2f}")
    
    if 'avg_sessions' in metrics:
        print(f"  - Average sessions: {metrics['avg_sessions']:.1f}")
    
    if 'top_status' in metrics:
        print(f"  - Main status: {metrics['top_status']}")
    
    if 'top_operator' in metrics:
        print(f"  - Main operator: {metrics['top_operator']}")

print(f"\nDetailed report saved to: {report_path}")
print(f"Processed data saved to: {processed_data_path}")
print(f"Visualization files saved to: {viz_path}")
# Out:
# === DATA CLEANING AND STANDARDIZATION ===
#
# Processing Alphaville sheet...
#   - Original values (sample): [41545.78, 54270.99, 43074.45]
#   - Converted values (sample): [41545.78, 54270.99, 43074.45]
#   - NaN values after conversion: 21 out of 1651
#   - VALOR statistics: Min=3000.00, Max=124526.12, Mean=47585.68
#
# Processing BH sheet...
#   - Original values (sample): [51231.24, 47328.33, 57888.45]
#   - Converted values (sample): [51231.24, 47328.33, 57888.45]
#   - NaN values after conversion: 52 out of 814
#   - VALOR statistics: Min=8.00, Max=84354.34, Mean=28020.54
#
# Processing SJC sheet...
#   - Original values (sample): [datetime.datetime(2014, 1, 20, 9, 21, 36), datetime.datetime(2016, 5, 29, 18, 57, 36), datetime.datetime(2016, 8, 29, 9, 21, 36)]
#   - Converted values (sample): [nan, nan, nan]
#   - NaN values after conversion: 1458 out of 2587
#   - VALOR statistics: Min=2600.00, Max=158214.06, Mean=44010.50
#
# Processing PAULINIA sheet...
#   - Original values (sample): [78661.77, 55947.52, 54432.92]
#   - Converted values (sample): [78661.77, 55947.52, 54432.92]
#   - NaN values after conversion: 33 out of 251
#   - VALOR statistics: Min=6167.61, Max=101950.24, Mean=53151.71
#
# Processing CAMPINAS sheet...
#   - Original values (sample): [47620.67, 51408.02, 13345]
#   - Converted values (sample): [47620.67, 51408.02, 13345.0]
#   - NaN values after conversion: 45 out of 194
#   - VALOR statistics: Min=3681.72, Max=89595.06, Mean=36082.52
#
# Rows with valid VALOR: 3888 out of 5497 total rows
#
# === PORTFOLIO PERFORMANCE ANALYSIS ===
# Total portfolio value: R$ 165,567,533.31
# Total number of contracts: 5,497
# Contracts with valid financial data: 3,888 (70.7%)
# Average contract value: R$ 42,584.24
#
# === UNIT PERFORMANCE SUMMARY ===
#
# ALPHAVILLE:
#   - Contracts: 1,652
#   - Valid financial data: 1,631 (98.7%)
#   - Total value: R$ 77,569,468.39
#   - Average value: R$ 47,559.45
#   - Average sessions: 14.9
#   - Main status: ATIVO
#   - Main operator: BRADESCO
#
# BH:
#   - Contracts: 807
#   - Valid financial data: 757 (93.8%)
#   - Total value: R$ 21,331,388.35
#   - Average value: R$ 28,178.85
#   - Average sessions: 12.6
#   - Main status: ATIVO
#   - Main operator: BRADESCO REEMBOLSO
#
# OSASCO:
#   - Contracts: 5
#   - Valid financial data: 4 (80.0%)
#   - Total value: R$ 15,450.00
#   - Average value: R$ 3,862.50
#   - Average sessions: 12.2
#   - Main status: ATIVO
#   - Main operator: AMIL
#
# BRASILIA:
#   - Contracts: 1
#   - Valid financial data: 0 (0.0%)
#   - Total value: R$ 0.00
#   - Average value: R$ nan
#   - Average sessions: 13.0
#   - Main status: ATIVO
#   - Main operator: AMIL
#
# DOMICILIAR:
#   - Contracts: 1,622
#   - Valid financial data: 386 (23.8%)
#   - Total value: R$ 16,678,035.16
#   - Average value: R$ 43,207.34
#   - Average sessions: 16.3
#   - Main status: ATIVO
#   - Main operator: BRADESCO
#
# SAO JOSE DOS CAMPOS:
#   - Contracts: 841
#   - Valid financial data: 731 (86.9%)
#   - Total value: R$ 32,521,622.85
#   - Average value: R$ 44,489.22
#   - Average sessions: 16.3
#   - Main status: ATIVO
#   - Main operator: SULAMERICA
#
# MORUMBI:
#   - Contracts: 59
#   - Valid financial data: 0 (0.0%)
#   - Total value: R$ 0.00
#   - Average value: R$ nan
#   - Average sessions: 16.0
#   - Main status: ATIVO
#   - Main operator: SULAMERICA
#
# LINS:
#   - Contracts: 65
#   - Valid financial data: 12 (18.5%)
#   - Total value: R$ 488,200.57
#   - Average value: R$ 40,683.38
#   - Average sessions: 16.5
#   - Main status: ATIVO
#   - Main operator: SULAMERICA
#
# PAULINIA:
#   - Contracts: 251
#   - Valid financial data: 218 (86.9%)
#   - Total value: R$ 11,587,072.35
#   - Average value: R$ 53,151.71
#   - Average sessions: 16.3
#   - Main status: ATIVO
#   - Main operator: VIVEST
#
# CAMPINAS:
#   - Contracts: 194
#   - Valid financial data: 149 (76.8%)
#   - Total value: R$ 5,376,295.64
#   - Average value: R$ 36,082.52
#   - Average sessions: 16.3
#   - Main status: ATIVO
#   - Main operator: SULAMERICA
#
# Detailed report saved to: /data/chats/igk4wd/workspace/visualizations/portfolio_analysis_report.md
# Processed data saved to: /data/chats/igk4wd/workspace/processed_data.csv
# Visualization files saved to: /data/chats/igk4wd/workspace/visualizations
